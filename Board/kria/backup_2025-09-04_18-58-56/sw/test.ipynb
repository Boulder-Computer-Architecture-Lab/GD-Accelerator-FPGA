# %%
#/root/jupyter_notebooks/mvm-accelerator/test.ipynb

import pynq
from pynq import Overlay, allocate, MMIO, PL
import time, re, threading
import numpy as np

# %% [markdown]
# ### Config

# %%
DEBUG = 1 # (0, 1, 2, 3)

# %%
PROJ_DIR  = "/home/ubuntu/mvm-accelerator/hw/"
BIT       = PROJ_DIR + "design_1.bit"
MTRX_PATH = "/home/ubuntu/mvm-accelerator/trmult_reduced.bin"

# %% [markdown]
# The following values are fixed in hardware:

# %%
CDMA_BASE = 0xA0000000 
BRAM_BASE = 0x80000000 

AXIS_CLK_HZ = 200e6

NUM_ROWS = 1024
NUM_CHANNELS = 1 
ROWS_PER_CHANNEL = NUM_ROWS // NUM_CHANNELS

WORD_WIDTH = 64
ELEMENT_WIDTH = 64
ELEMENTS_PER_WORD = WORD_WIDTH // ELEMENT_WIDTH
BYTES_PER_WORD = WORD_WIDTH // 8

ELEMENTS_PER_ROW = 8192
WORDS_PER_ROW = ELEMENTS_PER_ROW // ELEMENTS_PER_WORD
BYTES_PER_ROW = WORDS_PER_ROW * BYTES_PER_WORD

NUM_PARTITIONS = NUM_CHANNELS

ELEMENTS_PER_PARTITION = ELEMENTS_PER_ROW // NUM_PARTITIONS
WORDS_PER_PARTITION = WORDS_PER_ROW // NUM_PARTITIONS
BYTES_PER_PARTITION = WORDS_PER_PARTITION * BYTES_PER_WORD

# %%
assert WORD_WIDTH % ELEMENT_WIDTH == 0
assert ELEMENTS_PER_ROW % NUM_CHANNELS == 0
assert NUM_ROWS % NUM_CHANNELS == 0

# %% [markdown]
# ### Helpers

# %%
#https://github.com/iamNCJ/PYNQ-CDMA-Driver/blob/main/pynq_cdma/cdma.py

from pynq import DefaultIP
from pynq.buffer import PynqBuffer

class CDMA(DefaultIP):
    def __init__(self, description):
        super().__init__(description=description)

    bindto = ['xilinx.com:ip:axi_cdma:4.1']

    @property
    def idle(self):
        """
        `transfer` can only be called when the DMA is idle
        :return: True if the DMA engine is idle
        """
        return self.register_map.CDMASR.Idle

    def _do_transfer(self, source: int, dest: int, bytes_count: int):
        """
        Execute DMA transfer
        :param source: source address
        :param dest: destination address
        :param bytes_count: bytes to transfer
        :return: None
        """
        if not self.idle:
            raise Exception('DMA transfer can only start when engine is idle')

        assert source > 0
        if source > 0xFFFF_FFFF:
            self.register_map.SA_MSB[:] = source >> 8
        self.register_map.SA[:] = source & 0xFFFF_FFFF

        assert dest > 0
        if dest > 0xFFFF_FFFF:
            self.register_map.DA_MSB[:] = dest >> 8
        self.register_map.DA[:] = dest & 0xFFFF_FFFF

        assert bytes_count > 0
        self.register_map.BTT = bytes_count

        # Spin
        while not self.idle:
            pass

    def transfer(self, source, dest, bytes_count=None):
        """
        Transfer data through DMA
        :param source:
        :param dest:
        :param bytes_count:
        :return:
        """
        # Set source
        bytes_source = None
        if isinstance(source, PynqBuffer):
            source_addr = source.device_address
            bytes_source = source.nbytes
        elif isinstance(source, int):
            source_addr = source
        else:
            raise TypeError(f'Type {type(source)} not supported as source')

        bytes_dest = None
        if isinstance(dest, PynqBuffer):
            dest_addr = dest.device_address
            bytes_dest = dest.nbytes
        elif isinstance(dest, int):
            dest_addr = dest
        else:
            raise TypeError(f'Type {type(source)} not supported as dest')

        if bytes_count is None:
            if bytes_source is not None and bytes_dest is not None:
                bytes_count = min(bytes_source, bytes_dest)
            elif bytes_source is not None:
                bytes_count = bytes_source
            elif bytes_dest is not None:
                bytes_count = bytes_dest
            else:
                raise RuntimeError(f'Bytes to transfer is not set and cannot be inferred')

        self._do_transfer(source_addr, dest_addr, bytes_count)

# %%
from typing import Tuple, Dict, Any

try:
    from pynq import Overlay, MMIO
except ImportError:
    Overlay = None
    MMIO = None


class AxisDmaProfiler:
    """
    Address map:
    
        +0x00: STATUS [0]=have_result, [1]=running
        
        +0x04: CYCLES    [31:0]   +0x08: CYCLES    [63:32]
        +0x0C: BEATS     [31:0]   +0x10: BEATS     [63:32]
        +0x14: BYTES     [31:0]   +0x18: BYTES     [63:32]
        +0x1C: PKTS      [31:0]
        
        +0x20: GAP_LAST  [31:0]   +0x24: GAP_LAST  [63:32]
        +0x28: GAP_TOTAL [31:0]   +0x2C: GAP_TOTAL [63:32]
        +0x30: GAP_MIN   [31:0]   +0x34: GAP_MIN   [63:32]
        +0x38: GAP_MAX   [31:0]   +0x3C: GAP_MAX   [63:32]
        +0x40: GAP_COUNT [31:0]
        
        +0x44: GAP_STATUS [0]=gap_valid, [1]=armed
        
        +0x48: BUSY_TOTAL[31:0]   +0x4C: BUSY_TOTAL[63:32]
    """
    
    OFF_STATUS = 0x00
    OFF_CYCLES = 0x04
    OFF_BEATS  = 0x0C
    OFF_BYTES  = 0x14
    OFF_PKTS   = 0x1C
    
    OFF_GAP_LAST   = 0x20
    OFF_GAP_TOTAL  = 0x28
    OFF_GAP_MIN    = 0x30
    OFF_GAP_MAX    = 0x38
    OFF_GAP_COUNT  = 0x40
    OFF_GAP_STATUS = 0x44
    OFF_BUSY_TOTAL = 0x48
    
    CH_WINDOW = 0x100 # 0x100 bytes per channel

    def __init__(self, overlay, channels=NUM_CHANNELS, ip_name_contains="axis_dma_profiler"):
        self.channels = channels
        self.overlay = overlay

        key = next((k for k in overlay.ip_dict if ip_name_contains in k), None)
        
        if key is None:
            raise ValueError(
                f"Could not find IP containing '{ip_name_contains}' in overlay.ip_dict. "
                f"Pass base=... explicitly or adjust ip_name_contains."
            )
        ip = overlay.ip_dict[key]
        base = int(ip["phys_addr"])
        size = int(ip["addr_range"])

        if base is None: raise ValueError("Profiler base address is unknown.")
        if size is None: raise ValueError("Profiler size address is unknown.")

        self.base = base
        self.size = size
        self.mmio = MMIO(self.base, self.size)
        
        if DEBUG: print(f"    {self.__repr__()}")

    def _rd32(self, off):
        return self.mmio.read(off)

    def _rd64_stable(self, off, attempts=4):
        for _ in range(attempts):
            hi1 = self._rd32(off + 4)
            lo  = self._rd32(off)
            hi2 = self._rd32(off + 4)
            if hi1 == hi2:
                return (hi1 << 32) | lo
        return -1

    def _ch_base(self, ch: int) -> int:
        if not (0 <= ch < self.channels):
            raise ValueError(f"Channel out of range: {ch} (channels={self.channels})")
        return ch * self.CH_WINDOW

    # ========== Public ==========

    def stats(self, ch) -> Dict[str, int]:
        """
        Reads (cycles, beats, bytes, pkts). Prefer calling when have_result=1 and running=0.
        """
        b = self._ch_base(ch)
        cycles = self._rd64_stable(b + self.OFF_CYCLES)
        beats  = self._rd64_stable(b + self.OFF_BEATS)
        bytes_ = self._rd64_stable(b + self.OFF_BYTES)
        pkts   = self._rd32(b + self.OFF_PKTS)
        
        return {
            "cycles": cycles, 
            "beats":  beats, 
            "bytes":  bytes_, 
            "pkts":   pkts
        }
    
    def gap_stats(self, ch) -> Dict[str, Any]:
        """
        Inter-packet gap metrics for channel ch.
        """
        b = self._ch_base(ch)
        gap_last   = self._rd64_stable(b + self.OFF_GAP_LAST)
        gap_total  = self._rd64_stable(b + self.OFF_GAP_TOTAL)
        gap_min    = self._rd64_stable(b + self.OFF_GAP_MIN)
        gap_max    = self._rd64_stable(b + self.OFF_GAP_MAX)
        gap_count  = self._rd32(b + self.OFF_GAP_COUNT)
        busy_total = self._rd64_stable(b + self.OFF_BUSY_TOTAL)

        return {
            "gap_last":   gap_last,
            "gap_total":  gap_total,
            "gap_min":    gap_min,
            "gap_max":    gap_max,
            "gap_count":  gap_count,
            "busy_total": busy_total
        }

    def throughput(self, ch, axis_clk_hz=AXIS_CLK_HZ) -> Tuple[float, float, Dict[str, int]]:
        """
        Returns (gbps, handshake_utilization, stats) for a completed frame on channel ch.
        - gbps  = (bytes * 8 / cycles) * axis_clk_hz / 1e9
        - handshake_utilization = beats / cycles   (fraction of cycles that handshook)
        """
        s = self.stats(ch)
        cycles = max(1, s["cycles"])
        gbps = (s["bytes"] * 8.0 * axis_clk_hz / cycles) / 1e9
        util = s["beats"] / cycles
        return gbps, util, s
    
    def gap_summary(self, ch, axis_clk_hz=AXIS_CLK_HZ):
        """
        Analogous to `throughput`: return (g, mean_gap_ns, util_long_run).
          - g: dict with gap aggregates (gap_last, gap_min/max, gap_total, gap_count, busy_total)
          - mean_gap_ns: average inter-packet gap in nanoseconds
          - util_long_run: busy_total / (busy_total + gap_total)
        """
        g = self.gap_stats(ch)
        gap_total  = g["gap_total"]
        gap_count  = g["gap_count"]
        busy_total = g["busy_total"]

        mean_gap_cycles = (gap_total / gap_count) if gap_count else 0.0
        mean_gap_ns     = (1e9 * mean_gap_cycles / axis_clk_hz) if axis_clk_hz else 0.0
        util_long_run   = (busy_total / (busy_total + gap_total)) if (busy_total + gap_total) else 0.0

        return g, int(mean_gap_cycles), int(mean_gap_ns), util_long_run

    def __repr__(self) -> str:
        return f"AxisDmaProfiler(base=0x{self.base:08X}, size=0x{self.size:X}, channels={self.channels})"

# %%
def allocate_buf(dim1, dim2=None):
    if dim2 is not None:
        return allocate(shape=(dim1, dim2), dtype=np.float64, cacheable=False)
    else:
        return allocate(shape=(dim1,), dtype=np.float64, cacheable=False)

# %%
def write_vec(overlay, vector):
    if DEBUG: print("Writing vector to BRAM.")
    cdma = CDMA(overlay.ip_dict['axi_cdma_0'])

    # Dummy vector
    for i in range(NUM_PARTITIONS):
        vector[i, :] = np.arange(
            i * ELEMENTS_PER_PARTITION + 1,
            (i + 1) * ELEMENTS_PER_PARTITION + 1,
            dtype=np.float64) / 10000.0

    for i in range(NUM_PARTITIONS):
        dest = BRAM_BASE + i * BYTES_PER_PARTITION
        if DEBUG: print(f"    vec[{i}]: src_addr=0x{vector[i].physical_address:8x}, dest_addr=0x{dest:8x}")
        cdma.transfer(vector[i], dest)

# %%
def get_dmas(overlay):
    dmas = [
        getattr(overlay, name)
        for name in sorted(overlay.ip_dict, key=lambda n: int(re.search(r"\d+$", n).group()))
        if name.startswith("axi_dma")
    ]
    if DEBUG: print("    dmas", [d.description['fullpath'] for d in dmas])
    if len(dmas) != NUM_CHANNELS:
        raise RuntimeError(f"Check overlay. Found {len(dmas)} DMAs with NUM_CHANNELS={NUM_CHANNELS}.")
    return dmas

# %%
def create_workers(dmas, matrix):
    if DEBUG: print("Creating threads.")

    rows_per_channel = [
        list(range(start, start + ROWS_PER_CHANNEL))
        for start in range(0, NUM_ROWS, ROWS_PER_CHANNEL)
    ]

    threads = []
    for ch in range(NUM_CHANNELS):
        t = threading.Thread(
            target=worker,
            args=(ch, dmas[ch], rows_per_channel[ch], matrix),
            daemon=True
        )
        threads.append(t)
        if DEBUG: print(f"    Initialized worker {ch}")
    return threads

# %%
def worker(ch, dma, row_indices, matrix):
    if DEBUG > 1: print(f"[WORKER {ch}] Starting up...")
    for count,row_idx in enumerate(row_indices):
        dma.sendchannel.transfer(matrix[row_idx])
        dma.sendchannel.wait()
        if DEBUG > 1: print(f"[WORKER {ch}] Sent row {row_idx} (count={count})")

# %% [markdown]
# ### Main

# %%
if __name__ == "__main__":
    if DEBUG: 
        print(f"\n================================ Parameters =================================")
        print(f"""
    CDMA_BASE = 0x{CDMA_BASE:8X}
    BRAM_BASE = 0x{BRAM_BASE:8X}

    NUM_ROWS         = {NUM_ROWS}
    NUM_CHANNELS     = {NUM_CHANNELS} 
    ROWS_PER_CHANNEL = {ROWS_PER_CHANNEL}

    WORD_WIDTH        = {WORD_WIDTH}
    ELEMENT_WIDTH     = {ELEMENT_WIDTH}
    ELEMENTS_PER_WORD = {ELEMENTS_PER_WORD}
    BYTES_PER_WORD    = {BYTES_PER_WORD}

    ELEMENTS_PER_ROW = {ELEMENTS_PER_ROW}
    WORDS_PER_ROW    = {WORDS_PER_ROW}
    BYTES_PER_ROW    = {BYTES_PER_ROW}

    NUM_PARTITIONS = {NUM_PARTITIONS}

    ELEMENTS_PER_PARTITION = {ELEMENTS_PER_PARTITION}
    WORDS_PER_PARTITION    = {WORDS_PER_PARTITION}
    BYTES_PER_PARTITION    = {BYTES_PER_PARTITION}""")

    PL.reset()
    matrix = vector = result = None 

    try:
        if DEBUG: print("\n================================ Initialize =================================\n")

        # Load overlay
        if DEBUG: print("Loading Overlay.")
        overlay = Overlay(BIT, download=True)
        if not overlay.is_loaded():
            raise RuntimeError("Overlay download failed.")
        
        # Get DMAs and Profiler
        dmas = get_dmas(overlay)
        prof = AxisDmaProfiler(overlay)

        # Allocate buffers
        if DEBUG: print("Allocating buffers.")
        matrix =  allocate_buf(NUM_ROWS, ELEMENTS_PER_ROW)
        vector =  allocate_buf(NUM_PARTITIONS, ELEMENTS_PER_PARTITION)
        result = [allocate_buf(ROWS_PER_CHANNEL) for _ in range(NUM_CHANNELS)]
        if DEBUG:
            print(f"    matrix: src_addr=0x{matrix.physical_address:8X}")
            print(f"    vector: src_addr=0x{vector.physical_address:8X}")
            [print(f"    result[{i}]: src_addr=0x{r.physical_address:8X}") for i,r in enumerate(result)]

        # Read matrix into buffer
        if DEBUG: print("Reading matrix file.")
        with open(MTRX_PATH, "rb") as a_file:
            for i in range(NUM_ROWS):
                view = memoryview(matrix[i]).cast("B")
                if a_file.readinto(view) != BYTES_PER_ROW:
                    raise RuntimeError(f"Failed to read full row {i}.")
                if DEBUG > 2: print(f"    matrix[{i}]: {matrix[i]}")

        # Write vector to BRAM
        t0_vec = time.perf_counter()
        write_vec(overlay, vector) 
        t1_vec = time.perf_counter()

        # Create worker threads
        threads = create_workers(dmas, matrix)

        # Execute
        if DEBUG: print("\n================================== Compute ==================================\n")
        
        t0_comp = time.perf_counter()

        for ch in range(NUM_CHANNELS):
            dmas[ch].recvchannel.transfer(result[ch])

        for t in threads: t.start()
        for t in threads: t.join()

        for ch in range(NUM_CHANNELS):
            dmas[ch].recvchannel.wait()

        t1_comp = time.perf_counter()

        # Print results
        if DEBUG:
            print()
            for i in range(NUM_CHANNELS):
                for j in range(ROWS_PER_CHANNEL):
                    row_idx = i * ROWS_PER_CHANNEL + j
                    if (row_idx > 5 and row_idx < NUM_ROWS-5):
                        if not DEBUG > 2: # Only print all rows if DEBUG == 3
                            if (row_idx == 6): print("...")
                            continue
                    actual = result[i][j]
                    expected = float(np.dot(matrix[row_idx], vector.flatten()))
                    print(f"Row {row_idx}: Actual={actual:.32f} | Expected={expected:.32f}")
            
            print("\n================================ Performance ================================\n")
            for i in range(NUM_CHANNELS):
                gbps, util, s = prof.throughput(ch=i)
                g, mean_gap_cycles, mean_gap_ns, util_long_run = prof.gap_summary(ch=i)
                print(f"Channel {i}:")
                if DEBUG > 1:
                    print(f"    {s}")
                    print(f"    {g}")
                print(f"    Throughput: {gbps:.3f} Gbps | Handshake util: {util:.2%}")
                print(f"    Avg gap length: {mean_gap_cycles} cycles, {mean_gap_ns} ns | Busy util: {util_long_run:.2%}")
        
        print(f"\nOverhead time: {t1_vec - t0_vec:.6f}s")
        print(f"Compute time:  {t1_comp - t0_comp:.6f}s")

    finally:
        if result is not None:
            for r in result: r.freebuffer()
        for buf in [matrix, vector]:
            if buf is not None: buf.freebuffer()
# Out:
# ================================ Parameters =================================
#
#     CDMA_BASE = 0xA0000000
#     BRAM_BASE = 0x80000000
#
#     NUM_ROWS         = 1024
#     NUM_CHANNELS     = 1
#     ROWS_PER_CHANNEL = 1024
#
#     WORD_WIDTH        = 64
#     ELEMENT_WIDTH     = 64
#     ELEMENTS_PER_WORD = 1
#     BYTES_PER_WORD    = 8
#
#     ELEMENTS_PER_ROW = 8192
#     WORDS_PER_ROW    = 8192
#     BYTES_PER_ROW    = 65536
#
#     NUM_PARTITIONS = 1
#
#     ELEMENTS_PER_PARTITION = 8192
#     WORDS_PER_PARTITION    = 8192
#     BYTES_PER_PARTITION    = 65536
#
# ================================ Initialize =================================
#
# Loading Overlay.
#     dmas ['axi_dma_0']
#     AxisDmaProfiler(base=0xA0040000, size=0x1000, channels=1)
# Allocating buffers.
#     matrix: src_addr=0x39300000
#     vector: src_addr=0x375B0000
#     result[0]: src_addr=0x375C0000
# Reading matrix file.
# Writing vector to BRAM.
#     vec[0]: src_addr=0x375b0000, dest_addr=0x80000000
# Creating threads.
#     Initialized worker 0
#
# ================================== Compute ==================================
#
# [WORKER 0] Starting up...
# [WORKER 0] Sent row 0 (count=0)
# [WORKER 0] Sent row 1 (count=1)
# [WORKER 0] Sent row 2 (count=2)
# [WORKER 0] Sent row 3 (count=3)
# [WORKER 0] Sent row 4 (count=4)
# [WORKER 0] Sent row 5 (count=5)
# [WORKER 0] Sent row 6 (count=6)
# [WORKER 0] Sent row 7 (count=7)
# [WORKER 0] Sent row 8 (count=8)
# [WORKER 0] Sent row 9 (count=9)
# [WORKER 0] Sent row 10 (count=10)
# [WORKER 0] Sent row 11 (count=11)
# [WORKER 0] Sent row 12 (count=12)
# [WORKER 0] Sent row 13 (count=13)
# [WORKER 0] Sent row 14 (count=14)
# [WORKER 0] Sent row 15 (count=15)
# [WORKER 0] Sent row 16 (count=16)
# [WORKER 0] Sent row 17 (count=17)
# [WORKER 0] Sent row 18 (count=18)
# [WORKER 0] Sent row 19 (count=19)
# [WORKER 0] Sent row 20 (count=20)
# [WORKER 0] Sent row 21 (count=21)
# [WORKER 0] Sent row 22 (count=22)
# [WORKER 0] Sent row 23 (count=23)
# [WORKER 0] Sent row 24 (count=24)
# [WORKER 0] Sent row 25 (count=25)
# [WORKER 0] Sent row 26 (count=26)
# [WORKER 0] Sent row 27 (count=27)
# [WORKER 0] Sent row 28 (count=28)
# [WORKER 0] Sent row 29 (count=29)
# [WORKER 0] Sent row 30 (count=30)
# [WORKER 0] Sent row 31 (count=31)
# [WORKER 0] Sent row 32 (count=32)
# [WORKER 0] Sent row 33 (count=33)
# [WORKER 0] Sent row 34 (count=34)
# [WORKER 0] Sent row 35 (count=35)
# [WORKER 0] Sent row 36 (count=36)
# [WORKER 0] Sent row 37 (count=37)
# [WORKER 0] Sent row 38 (count=38)
# [WORKER 0] Sent row 39 (count=39)
# [WORKER 0] Sent row 40 (count=40)
# [WORKER 0] Sent row 41 (count=41)
# [WORKER 0] Sent row 42 (count=42)
# [WORKER 0] Sent row 43 (count=43)
# [WORKER 0] Sent row 44 (count=44)
# [WORKER 0] Sent row 45 (count=45)
# [WORKER 0] Sent row 46 (count=46)
# [WORKER 0] Sent row 47 (count=47)
# [WORKER 0] Sent row 48 (count=48)
# [WORKER 0] Sent row 49 (count=49)
# [WORKER 0] Sent row 50 (count=50)
# [WORKER 0] Sent row 51 (count=51)
# [WORKER 0] Sent row 52 (count=52)
# [WORKER 0] Sent row 53 (count=53)
# [WORKER 0] Sent row 54 (count=54)
# [WORKER 0] Sent row 55 (count=55)
# [WORKER 0] Sent row 56 (count=56)
# [WORKER 0] Sent row 57 (count=57)
# [WORKER 0] Sent row 58 (count=58)
# [WORKER 0] Sent row 59 (count=59)
# [WORKER 0] Sent row 60 (count=60)
# [WORKER 0] Sent row 61 (count=61)
# [WORKER 0] Sent row 62 (count=62)
# [WORKER 0] Sent row 63 (count=63)
# [WORKER 0] Sent row 64 (count=64)
# [WORKER 0] Sent row 65 (count=65)
# [WORKER 0] Sent row 66 (count=66)
# [WORKER 0] Sent row 67 (count=67)
# [WORKER 0] Sent row 68 (count=68)
# [WORKER 0] Sent row 69 (count=69)
# [WORKER 0] Sent row 70 (count=70)
# [WORKER 0] Sent row 71 (count=71)
# [WORKER 0] Sent row 72 (count=72)
# [WORKER 0] Sent row 73 (count=73)
# [WORKER 0] Sent row 74 (count=74)
# [WORKER 0] Sent row 75 (count=75)
# [WORKER 0] Sent row 76 (count=76)
# [WORKER 0] Sent row 77 (count=77)
# [WORKER 0] Sent row 78 (count=78)
# [WORKER 0] Sent row 79 (count=79)
# [WORKER 0] Sent row 80 (count=80)
# [WORKER 0] Sent row 81 (count=81)
# [WORKER 0] Sent row 82 (count=82)
# [WORKER 0] Sent row 83 (count=83)
# [WORKER 0] Sent row 84 (count=84)
# [WORKER 0] Sent row 85 (count=85)
# [WORKER 0] Sent row 86 (count=86)
# [WORKER 0] Sent row 87 (count=87)
# [WORKER 0] Sent row 88 (count=88)
# [WORKER 0] Sent row 89 (count=89)
# [WORKER 0] Sent row 90 (count=90)
# [WORKER 0] Sent row 91 (count=91)
# [WORKER 0] Sent row 92 (count=92)
# [WORKER 0] Sent row 93 (count=93)
# [WORKER 0] Sent row 94 (count=94)
# [WORKER 0] Sent row 95 (count=95)
# [WORKER 0] Sent row 96 (count=96)
# [WORKER 0] Sent row 97 (count=97)
# [WORKER 0] Sent row 98 (count=98)
# [WORKER 0] Sent row 99 (count=99)
# [WORKER 0] Sent row 100 (count=100)
# [WORKER 0] Sent row 101 (count=101)
# [WORKER 0] Sent row 102 (count=102)
# [WORKER 0] Sent row 103 (count=103)
# [WORKER 0] Sent row 104 (count=104)
# [WORKER 0] Sent row 105 (count=105)
# [WORKER 0] Sent row 106 (count=106)
# [WORKER 0] Sent row 107 (count=107)
# [WORKER 0] Sent row 108 (count=108)
# [WORKER 0] Sent row 109 (count=109)
# [WORKER 0] Sent row 110 (count=110)
# [WORKER 0] Sent row 111 (count=111)
# [WORKER 0] Sent row 112 (count=112)
# [WORKER 0] Sent row 113 (count=113)
# [WORKER 0] Sent row 114 (count=114)
# [WORKER 0] Sent row 115 (count=115)
# [WORKER 0] Sent row 116 (count=116)
# [WORKER 0] Sent row 117 (count=117)
# [WORKER 0] Sent row 118 (count=118)
# [WORKER 0] Sent row 119 (count=119)
# [WORKER 0] Sent row 120 (count=120)
# [WORKER 0] Sent row 121 (count=121)
# [WORKER 0] Sent row 122 (count=122)
# [WORKER 0] Sent row 123 (count=123)
# [WORKER 0] Sent row 124 (count=124)
# [WORKER 0] Sent row 125 (count=125)
# [WORKER 0] Sent row 126 (count=126)
# [WORKER 0] Sent row 127 (count=127)
# [WORKER 0] Sent row 128 (count=128)
# [WORKER 0] Sent row 129 (count=129)
# [WORKER 0] Sent row 130 (count=130)
# [WORKER 0] Sent row 131 (count=131)
# [WORKER 0] Sent row 132 (count=132)
# [WORKER 0] Sent row 133 (count=133)
# [WORKER 0] Sent row 134 (count=134)
# [WORKER 0] Sent row 135 (count=135)
# [WORKER 0] Sent row 136 (count=136)
# [WORKER 0] Sent row 137 (count=137)
# [WORKER 0] Sent row 138 (count=138)
# [WORKER 0] Sent row 139 (count=139)
# [WORKER 0] Sent row 140 (count=140)
# [WORKER 0] Sent row 141 (count=141)
# [WORKER 0] Sent row 142 (count=142)
# [WORKER 0] Sent row 143 (count=143)
# [WORKER 0] Sent row 144 (count=144)
# [WORKER 0] Sent row 145 (count=145)
# [WORKER 0] Sent row 146 (count=146)
# [WORKER 0] Sent row 147 (count=147)
# [WORKER 0] Sent row 148 (count=148)
# [WORKER 0] Sent row 149 (count=149)
# [WORKER 0] Sent row 150 (count=150)
# [WORKER 0] Sent row 151 (count=151)
# [WORKER 0] Sent row 152 (count=152)
# [WORKER 0] Sent row 153 (count=153)
# [WORKER 0] Sent row 154 (count=154)
# [WORKER 0] Sent row 155 (count=155)
# [WORKER 0] Sent row 156 (count=156)
# [WORKER 0] Sent row 157 (count=157)
# [WORKER 0] Sent row 158 (count=158)
# [WORKER 0] Sent row 159 (count=159)
# [WORKER 0] Sent row 160 (count=160)
# [WORKER 0] Sent row 161 (count=161)
# [WORKER 0] Sent row 162 (count=162)
# [WORKER 0] Sent row 163 (count=163)
# [WORKER 0] Sent row 164 (count=164)
# [WORKER 0] Sent row 165 (count=165)
# [WORKER 0] Sent row 166 (count=166)
# [WORKER 0] Sent row 167 (count=167)
# [WORKER 0] Sent row 168 (count=168)
# [WORKER 0] Sent row 169 (count=169)
# [WORKER 0] Sent row 170 (count=170)
# [WORKER 0] Sent row 171 (count=171)
# [WORKER 0] Sent row 172 (count=172)
# [WORKER 0] Sent row 173 (count=173)
# [WORKER 0] Sent row 174 (count=174)
# [WORKER 0] Sent row 175 (count=175)
# [WORKER 0] Sent row 176 (count=176)
# [WORKER 0] Sent row 177 (count=177)
# [WORKER 0] Sent row 178 (count=178)
# [WORKER 0] Sent row 179 (count=179)
# [WORKER 0] Sent row 180 (count=180)
# [WORKER 0] Sent row 181 (count=181)
# [WORKER 0] Sent row 182 (count=182)
# [WORKER 0] Sent row 183 (count=183)
# [WORKER 0] Sent row 184 (count=184)
# [WORKER 0] Sent row 185 (count=185)
# [WORKER 0] Sent row 186 (count=186)
# [WORKER 0] Sent row 187 (count=187)
# [WORKER 0] Sent row 188 (count=188)
# [WORKER 0] Sent row 189 (count=189)
# [WORKER 0] Sent row 190 (count=190)
# [WORKER 0] Sent row 191 (count=191)
# [WORKER 0] Sent row 192 (count=192)
# [WORKER 0] Sent row 193 (count=193)
# [WORKER 0] Sent row 194 (count=194)
# [WORKER 0] Sent row 195 (count=195)
# [WORKER 0] Sent row 196 (count=196)
# [WORKER 0] Sent row 197 (count=197)
# [WORKER 0] Sent row 198 (count=198)
# [WORKER 0] Sent row 199 (count=199)
# [WORKER 0] Sent row 200 (count=200)
# [WORKER 0] Sent row 201 (count=201)
# [WORKER 0] Sent row 202 (count=202)
# [WORKER 0] Sent row 203 (count=203)
# [WORKER 0] Sent row 204 (count=204)
# [WORKER 0] Sent row 205 (count=205)
# [WORKER 0] Sent row 206 (count=206)
# [WORKER 0] Sent row 207 (count=207)
# [WORKER 0] Sent row 208 (count=208)
# [WORKER 0] Sent row 209 (count=209)
# [WORKER 0] Sent row 210 (count=210)
# [WORKER 0] Sent row 211 (count=211)
# [WORKER 0] Sent row 212 (count=212)
# [WORKER 0] Sent row 213 (count=213)
# [WORKER 0] Sent row 214 (count=214)
# [WORKER 0] Sent row 215 (count=215)
# [WORKER 0] Sent row 216 (count=216)
# [WORKER 0] Sent row 217 (count=217)
# [WORKER 0] Sent row 218 (count=218)
# [WORKER 0] Sent row 219 (count=219)
# [WORKER 0] Sent row 220 (count=220)
# [WORKER 0] Sent row 221 (count=221)
# [WORKER 0] Sent row 222 (count=222)
# [WORKER 0] Sent row 223 (count=223)
# [WORKER 0] Sent row 224 (count=224)
# [WORKER 0] Sent row 225 (count=225)
# [WORKER 0] Sent row 226 (count=226)
# [WORKER 0] Sent row 227 (count=227)
# [WORKER 0] Sent row 228 (count=228)
# [WORKER 0] Sent row 229 (count=229)
# [WORKER 0] Sent row 230 (count=230)
# [WORKER 0] Sent row 231 (count=231)
# [WORKER 0] Sent row 232 (count=232)
# [WORKER 0] Sent row 233 (count=233)
# [WORKER 0] Sent row 234 (count=234)
# [WORKER 0] Sent row 235 (count=235)
# [WORKER 0] Sent row 236 (count=236)
# [WORKER 0] Sent row 237 (count=237)
# [WORKER 0] Sent row 238 (count=238)
# [WORKER 0] Sent row 239 (count=239)
# [WORKER 0] Sent row 240 (count=240)
# [WORKER 0] Sent row 241 (count=241)
# [WORKER 0] Sent row 242 (count=242)
# [WORKER 0] Sent row 243 (count=243)
# [WORKER 0] Sent row 244 (count=244)
# [WORKER 0] Sent row 245 (count=245)
# [WORKER 0] Sent row 246 (count=246)
# [WORKER 0] Sent row 247 (count=247)
# [WORKER 0] Sent row 248 (count=248)
# [WORKER 0] Sent row 249 (count=249)
# [WORKER 0] Sent row 250 (count=250)
# [WORKER 0] Sent row 251 (count=251)
# [WORKER 0] Sent row 252 (count=252)
# [WORKER 0] Sent row 253 (count=253)
# [WORKER 0] Sent row 254 (count=254)
# [WORKER 0] Sent row 255 (count=255)
# [WORKER 0] Sent row 256 (count=256)
# [WORKER 0] Sent row 257 (count=257)
# [WORKER 0] Sent row 258 (count=258)
# [WORKER 0] Sent row 259 (count=259)
# [WORKER 0] Sent row 260 (count=260)
# [WORKER 0] Sent row 261 (count=261)
# [WORKER 0] Sent row 262 (count=262)
# [WORKER 0] Sent row 263 (count=263)
# [WORKER 0] Sent row 264 (count=264)
# [WORKER 0] Sent row 265 (count=265)
# [WORKER 0] Sent row 266 (count=266)
# [WORKER 0] Sent row 267 (count=267)
# [WORKER 0] Sent row 268 (count=268)
# [WORKER 0] Sent row 269 (count=269)
# [WORKER 0] Sent row 270 (count=270)
# [WORKER 0] Sent row 271 (count=271)
# [WORKER 0] Sent row 272 (count=272)
# [WORKER 0] Sent row 273 (count=273)
# [WORKER 0] Sent row 274 (count=274)
# [WORKER 0] Sent row 275 (count=275)
# [WORKER 0] Sent row 276 (count=276)
# [WORKER 0] Sent row 277 (count=277)
# [WORKER 0] Sent row 278 (count=278)
# [WORKER 0] Sent row 279 (count=279)
# [WORKER 0] Sent row 280 (count=280)
# [WORKER 0] Sent row 281 (count=281)
# [WORKER 0] Sent row 282 (count=282)
# [WORKER 0] Sent row 283 (count=283)
# [WORKER 0] Sent row 284 (count=284)
# [WORKER 0] Sent row 285 (count=285)
# [WORKER 0] Sent row 286 (count=286)
# [WORKER 0] Sent row 287 (count=287)
# [WORKER 0] Sent row 288 (count=288)
# [WORKER 0] Sent row 289 (count=289)
# [WORKER 0] Sent row 290 (count=290)
# [WORKER 0] Sent row 291 (count=291)
# [WORKER 0] Sent row 292 (count=292)
# [WORKER 0] Sent row 293 (count=293)
# [WORKER 0] Sent row 294 (count=294)
# [WORKER 0] Sent row 295 (count=295)
# [WORKER 0] Sent row 296 (count=296)
# [WORKER 0] Sent row 297 (count=297)
# [WORKER 0] Sent row 298 (count=298)
# [WORKER 0] Sent row 299 (count=299)
# [WORKER 0] Sent row 300 (count=300)
# [WORKER 0] Sent row 301 (count=301)
# [WORKER 0] Sent row 302 (count=302)
# [WORKER 0] Sent row 303 (count=303)
# [WORKER 0] Sent row 304 (count=304)
# [WORKER 0] Sent row 305 (count=305)
# [WORKER 0] Sent row 306 (count=306)
# [WORKER 0] Sent row 307 (count=307)
# [WORKER 0] Sent row 308 (count=308)
# [WORKER 0] Sent row 309 (count=309)
# [WORKER 0] Sent row 310 (count=310)
# [WORKER 0] Sent row 311 (count=311)
# [WORKER 0] Sent row 312 (count=312)
# [WORKER 0] Sent row 313 (count=313)
# [WORKER 0] Sent row 314 (count=314)
# [WORKER 0] Sent row 315 (count=315)
# [WORKER 0] Sent row 316 (count=316)
# [WORKER 0] Sent row 317 (count=317)
# [WORKER 0] Sent row 318 (count=318)
# [WORKER 0] Sent row 319 (count=319)
# [WORKER 0] Sent row 320 (count=320)
# [WORKER 0] Sent row 321 (count=321)
# [WORKER 0] Sent row 322 (count=322)
# [WORKER 0] Sent row 323 (count=323)
# [WORKER 0] Sent row 324 (count=324)
# [WORKER 0] Sent row 325 (count=325)
# [WORKER 0] Sent row 326 (count=326)
# [WORKER 0] Sent row 327 (count=327)
# [WORKER 0] Sent row 328 (count=328)
# [WORKER 0] Sent row 329 (count=329)
# [WORKER 0] Sent row 330 (count=330)
# [WORKER 0] Sent row 331 (count=331)
# [WORKER 0] Sent row 332 (count=332)
# [WORKER 0] Sent row 333 (count=333)
# [WORKER 0] Sent row 334 (count=334)
# [WORKER 0] Sent row 335 (count=335)
# [WORKER 0] Sent row 336 (count=336)
# [WORKER 0] Sent row 337 (count=337)
# [WORKER 0] Sent row 338 (count=338)
# [WORKER 0] Sent row 339 (count=339)
# [WORKER 0] Sent row 340 (count=340)
# [WORKER 0] Sent row 341 (count=341)
# [WORKER 0] Sent row 342 (count=342)
# [WORKER 0] Sent row 343 (count=343)
# [WORKER 0] Sent row 344 (count=344)
# [WORKER 0] Sent row 345 (count=345)
# [WORKER 0] Sent row 346 (count=346)
# [WORKER 0] Sent row 347 (count=347)
# [WORKER 0] Sent row 348 (count=348)
# [WORKER 0] Sent row 349 (count=349)
# [WORKER 0] Sent row 350 (count=350)
# [WORKER 0] Sent row 351 (count=351)
# [WORKER 0] Sent row 352 (count=352)
# [WORKER 0] Sent row 353 (count=353)
# [WORKER 0] Sent row 354 (count=354)
# [WORKER 0] Sent row 355 (count=355)
# [WORKER 0] Sent row 356 (count=356)
# [WORKER 0] Sent row 357 (count=357)
# [WORKER 0] Sent row 358 (count=358)
# [WORKER 0] Sent row 359 (count=359)
# [WORKER 0] Sent row 360 (count=360)
# [WORKER 0] Sent row 361 (count=361)
# [WORKER 0] Sent row 362 (count=362)
# [WORKER 0] Sent row 363 (count=363)
# [WORKER 0] Sent row 364 (count=364)
# [WORKER 0] Sent row 365 (count=365)
# [WORKER 0] Sent row 366 (count=366)
# [WORKER 0] Sent row 367 (count=367)
# [WORKER 0] Sent row 368 (count=368)
# [WORKER 0] Sent row 369 (count=369)
# [WORKER 0] Sent row 370 (count=370)
# [WORKER 0] Sent row 371 (count=371)
# [WORKER 0] Sent row 372 (count=372)
# [WORKER 0] Sent row 373 (count=373)
# [WORKER 0] Sent row 374 (count=374)
# [WORKER 0] Sent row 375 (count=375)
# [WORKER 0] Sent row 376 (count=376)
# [WORKER 0] Sent row 377 (count=377)
# [WORKER 0] Sent row 378 (count=378)
# [WORKER 0] Sent row 379 (count=379)
# [WORKER 0] Sent row 380 (count=380)
# [WORKER 0] Sent row 381 (count=381)
# [WORKER 0] Sent row 382 (count=382)
# [WORKER 0] Sent row 383 (count=383)
# [WORKER 0] Sent row 384 (count=384)
# [WORKER 0] Sent row 385 (count=385)
# [WORKER 0] Sent row 386 (count=386)
# [WORKER 0] Sent row 387 (count=387)
# [WORKER 0] Sent row 388 (count=388)
# [WORKER 0] Sent row 389 (count=389)
# [WORKER 0] Sent row 390 (count=390)
# [WORKER 0] Sent row 391 (count=391)
# [WORKER 0] Sent row 392 (count=392)
# [WORKER 0] Sent row 393 (count=393)
# [WORKER 0] Sent row 394 (count=394)
# [WORKER 0] Sent row 395 (count=395)
# [WORKER 0] Sent row 396 (count=396)
# [WORKER 0] Sent row 397 (count=397)
# [WORKER 0] Sent row 398 (count=398)
# [WORKER 0] Sent row 399 (count=399)
# [WORKER 0] Sent row 400 (count=400)
# [WORKER 0] Sent row 401 (count=401)
# [WORKER 0] Sent row 402 (count=402)
# [WORKER 0] Sent row 403 (count=403)
# [WORKER 0] Sent row 404 (count=404)
# [WORKER 0] Sent row 405 (count=405)
# [WORKER 0] Sent row 406 (count=406)
# [WORKER 0] Sent row 407 (count=407)
# [WORKER 0] Sent row 408 (count=408)
# [WORKER 0] Sent row 409 (count=409)
# [WORKER 0] Sent row 410 (count=410)
# [WORKER 0] Sent row 411 (count=411)
# [WORKER 0] Sent row 412 (count=412)
# [WORKER 0] Sent row 413 (count=413)
# [WORKER 0] Sent row 414 (count=414)
# [WORKER 0] Sent row 415 (count=415)
# [WORKER 0] Sent row 416 (count=416)
# [WORKER 0] Sent row 417 (count=417)
# [WORKER 0] Sent row 418 (count=418)
# [WORKER 0] Sent row 419 (count=419)
# [WORKER 0] Sent row 420 (count=420)
# [WORKER 0] Sent row 421 (count=421)
# [WORKER 0] Sent row 422 (count=422)
# [WORKER 0] Sent row 423 (count=423)
# [WORKER 0] Sent row 424 (count=424)
# [WORKER 0] Sent row 425 (count=425)
# [WORKER 0] Sent row 426 (count=426)
# [WORKER 0] Sent row 427 (count=427)
# [WORKER 0] Sent row 428 (count=428)
# [WORKER 0] Sent row 429 (count=429)
# [WORKER 0] Sent row 430 (count=430)
# [WORKER 0] Sent row 431 (count=431)
# [WORKER 0] Sent row 432 (count=432)
# [WORKER 0] Sent row 433 (count=433)
# [WORKER 0] Sent row 434 (count=434)
# [WORKER 0] Sent row 435 (count=435)
# [WORKER 0] Sent row 436 (count=436)
# [WORKER 0] Sent row 437 (count=437)
# [WORKER 0] Sent row 438 (count=438)
# [WORKER 0] Sent row 439 (count=439)
# [WORKER 0] Sent row 440 (count=440)
# [WORKER 0] Sent row 441 (count=441)
# [WORKER 0] Sent row 442 (count=442)
# [WORKER 0] Sent row 443 (count=443)
# [WORKER 0] Sent row 444 (count=444)
# [WORKER 0] Sent row 445 (count=445)
# [WORKER 0] Sent row 446 (count=446)
# [WORKER 0] Sent row 447 (count=447)
# [WORKER 0] Sent row 448 (count=448)
# [WORKER 0] Sent row 449 (count=449)
# [WORKER 0] Sent row 450 (count=450)
# [WORKER 0] Sent row 451 (count=451)
# [WORKER 0] Sent row 452 (count=452)
# [WORKER 0] Sent row 453 (count=453)
# [WORKER 0] Sent row 454 (count=454)
# [WORKER 0] Sent row 455 (count=455)
# [WORKER 0] Sent row 456 (count=456)
# [WORKER 0] Sent row 457 (count=457)
# [WORKER 0] Sent row 458 (count=458)
# [WORKER 0] Sent row 459 (count=459)
# [WORKER 0] Sent row 460 (count=460)
# [WORKER 0] Sent row 461 (count=461)
# [WORKER 0] Sent row 462 (count=462)
# [WORKER 0] Sent row 463 (count=463)
# [WORKER 0] Sent row 464 (count=464)
# [WORKER 0] Sent row 465 (count=465)
# [WORKER 0] Sent row 466 (count=466)
# [WORKER 0] Sent row 467 (count=467)
# [WORKER 0] Sent row 468 (count=468)
# [WORKER 0] Sent row 469 (count=469)
# [WORKER 0] Sent row 470 (count=470)
# [WORKER 0] Sent row 471 (count=471)
# [WORKER 0] Sent row 472 (count=472)
# [WORKER 0] Sent row 473 (count=473)
# [WORKER 0] Sent row 474 (count=474)
# [WORKER 0] Sent row 475 (count=475)
# [WORKER 0] Sent row 476 (count=476)
# [WORKER 0] Sent row 477 (count=477)
# [WORKER 0] Sent row 478 (count=478)
# [WORKER 0] Sent row 479 (count=479)
# [WORKER 0] Sent row 480 (count=480)
# [WORKER 0] Sent row 481 (count=481)
# [WORKER 0] Sent row 482 (count=482)
# [WORKER 0] Sent row 483 (count=483)
# [WORKER 0] Sent row 484 (count=484)
# [WORKER 0] Sent row 485 (count=485)
# [WORKER 0] Sent row 486 (count=486)
# [WORKER 0] Sent row 487 (count=487)
# [WORKER 0] Sent row 488 (count=488)
# [WORKER 0] Sent row 489 (count=489)
# [WORKER 0] Sent row 490 (count=490)
# [WORKER 0] Sent row 491 (count=491)
# [WORKER 0] Sent row 492 (count=492)
# [WORKER 0] Sent row 493 (count=493)
# [WORKER 0] Sent row 494 (count=494)
# [WORKER 0] Sent row 495 (count=495)
# [WORKER 0] Sent row 496 (count=496)
# [WORKER 0] Sent row 497 (count=497)
# [WORKER 0] Sent row 498 (count=498)
# [WORKER 0] Sent row 499 (count=499)
# [WORKER 0] Sent row 500 (count=500)
# [WORKER 0] Sent row 501 (count=501)
# [WORKER 0] Sent row 502 (count=502)
# [WORKER 0] Sent row 503 (count=503)
# [WORKER 0] Sent row 504 (count=504)
# [WORKER 0] Sent row 505 (count=505)
# [WORKER 0] Sent row 506 (count=506)
# [WORKER 0] Sent row 507 (count=507)
# [WORKER 0] Sent row 508 (count=508)
# [WORKER 0] Sent row 509 (count=509)
# [WORKER 0] Sent row 510 (count=510)
# [WORKER 0] Sent row 511 (count=511)
# [WORKER 0] Sent row 512 (count=512)
# [WORKER 0] Sent row 513 (count=513)
# [WORKER 0] Sent row 514 (count=514)
# [WORKER 0] Sent row 515 (count=515)
# [WORKER 0] Sent row 516 (count=516)
# [WORKER 0] Sent row 517 (count=517)
# [WORKER 0] Sent row 518 (count=518)
# [WORKER 0] Sent row 519 (count=519)
# [WORKER 0] Sent row 520 (count=520)
# [WORKER 0] Sent row 521 (count=521)
# [WORKER 0] Sent row 522 (count=522)
# [WORKER 0] Sent row 523 (count=523)
# [WORKER 0] Sent row 524 (count=524)
# [WORKER 0] Sent row 525 (count=525)
# [WORKER 0] Sent row 526 (count=526)
# [WORKER 0] Sent row 527 (count=527)
# [WORKER 0] Sent row 528 (count=528)
# [WORKER 0] Sent row 529 (count=529)
# [WORKER 0] Sent row 530 (count=530)
# [WORKER 0] Sent row 531 (count=531)
# [WORKER 0] Sent row 532 (count=532)
# [WORKER 0] Sent row 533 (count=533)
# [WORKER 0] Sent row 534 (count=534)
# [WORKER 0] Sent row 535 (count=535)
# [WORKER 0] Sent row 536 (count=536)
# [WORKER 0] Sent row 537 (count=537)
# [WORKER 0] Sent row 538 (count=538)
# [WORKER 0] Sent row 539 (count=539)
# [WORKER 0] Sent row 540 (count=540)
# [WORKER 0] Sent row 541 (count=541)
# [WORKER 0] Sent row 542 (count=542)
# [WORKER 0] Sent row 543 (count=543)
# [WORKER 0] Sent row 544 (count=544)
# [WORKER 0] Sent row 545 (count=545)
# [WORKER 0] Sent row 546 (count=546)
# [WORKER 0] Sent row 547 (count=547)
# [WORKER 0] Sent row 548 (count=548)
# [WORKER 0] Sent row 549 (count=549)
# [WORKER 0] Sent row 550 (count=550)
# [WORKER 0] Sent row 551 (count=551)
# [WORKER 0] Sent row 552 (count=552)
# [WORKER 0] Sent row 553 (count=553)
# [WORKER 0] Sent row 554 (count=554)
# [WORKER 0] Sent row 555 (count=555)
# [WORKER 0] Sent row 556 (count=556)
# [WORKER 0] Sent row 557 (count=557)
# [WORKER 0] Sent row 558 (count=558)
# [WORKER 0] Sent row 559 (count=559)
# [WORKER 0] Sent row 560 (count=560)
# [WORKER 0] Sent row 561 (count=561)
# [WORKER 0] Sent row 562 (count=562)
# [WORKER 0] Sent row 563 (count=563)
# [WORKER 0] Sent row 564 (count=564)
# [WORKER 0] Sent row 565 (count=565)
# [WORKER 0] Sent row 566 (count=566)
# [WORKER 0] Sent row 567 (count=567)
# [WORKER 0] Sent row 568 (count=568)
# [WORKER 0] Sent row 569 (count=569)
# [WORKER 0] Sent row 570 (count=570)
# [WORKER 0] Sent row 571 (count=571)
# [WORKER 0] Sent row 572 (count=572)
# [WORKER 0] Sent row 573 (count=573)
# [WORKER 0] Sent row 574 (count=574)
# [WORKER 0] Sent row 575 (count=575)
# [WORKER 0] Sent row 576 (count=576)
# [WORKER 0] Sent row 577 (count=577)
# [WORKER 0] Sent row 578 (count=578)
# [WORKER 0] Sent row 579 (count=579)
# [WORKER 0] Sent row 580 (count=580)
# [WORKER 0] Sent row 581 (count=581)
# [WORKER 0] Sent row 582 (count=582)
# [WORKER 0] Sent row 583 (count=583)
# [WORKER 0] Sent row 584 (count=584)
# [WORKER 0] Sent row 585 (count=585)
# [WORKER 0] Sent row 586 (count=586)
# [WORKER 0] Sent row 587 (count=587)
# [WORKER 0] Sent row 588 (count=588)
# [WORKER 0] Sent row 589 (count=589)
# [WORKER 0] Sent row 590 (count=590)
# [WORKER 0] Sent row 591 (count=591)
# [WORKER 0] Sent row 592 (count=592)
# [WORKER 0] Sent row 593 (count=593)
# [WORKER 0] Sent row 594 (count=594)
# [WORKER 0] Sent row 595 (count=595)
# [WORKER 0] Sent row 596 (count=596)
# [WORKER 0] Sent row 597 (count=597)
# [WORKER 0] Sent row 598 (count=598)
# [WORKER 0] Sent row 599 (count=599)
# [WORKER 0] Sent row 600 (count=600)
# [WORKER 0] Sent row 601 (count=601)
# [WORKER 0] Sent row 602 (count=602)
# [WORKER 0] Sent row 603 (count=603)
# [WORKER 0] Sent row 604 (count=604)
# [WORKER 0] Sent row 605 (count=605)
# [WORKER 0] Sent row 606 (count=606)
# [WORKER 0] Sent row 607 (count=607)
# [WORKER 0] Sent row 608 (count=608)
# [WORKER 0] Sent row 609 (count=609)
# [WORKER 0] Sent row 610 (count=610)
# [WORKER 0] Sent row 611 (count=611)
# [WORKER 0] Sent row 612 (count=612)
# [WORKER 0] Sent row 613 (count=613)
# [WORKER 0] Sent row 614 (count=614)
# [WORKER 0] Sent row 615 (count=615)
# [WORKER 0] Sent row 616 (count=616)
# [WORKER 0] Sent row 617 (count=617)
# [WORKER 0] Sent row 618 (count=618)
# [WORKER 0] Sent row 619 (count=619)
# [WORKER 0] Sent row 620 (count=620)
# [WORKER 0] Sent row 621 (count=621)
# [WORKER 0] Sent row 622 (count=622)
# [WORKER 0] Sent row 623 (count=623)
# [WORKER 0] Sent row 624 (count=624)
# [WORKER 0] Sent row 625 (count=625)
# [WORKER 0] Sent row 626 (count=626)
# [WORKER 0] Sent row 627 (count=627)
# [WORKER 0] Sent row 628 (count=628)
# [WORKER 0] Sent row 629 (count=629)
# [WORKER 0] Sent row 630 (count=630)
# [WORKER 0] Sent row 631 (count=631)
# [WORKER 0] Sent row 632 (count=632)
# [WORKER 0] Sent row 633 (count=633)
# [WORKER 0] Sent row 634 (count=634)
# [WORKER 0] Sent row 635 (count=635)
# [WORKER 0] Sent row 636 (count=636)
# [WORKER 0] Sent row 637 (count=637)
# [WORKER 0] Sent row 638 (count=638)
# [WORKER 0] Sent row 639 (count=639)
# [WORKER 0] Sent row 640 (count=640)
# [WORKER 0] Sent row 641 (count=641)
# [WORKER 0] Sent row 642 (count=642)
# [WORKER 0] Sent row 643 (count=643)
# [WORKER 0] Sent row 644 (count=644)
# [WORKER 0] Sent row 645 (count=645)
# [WORKER 0] Sent row 646 (count=646)
# [WORKER 0] Sent row 647 (count=647)
# [WORKER 0] Sent row 648 (count=648)
# [WORKER 0] Sent row 649 (count=649)
# [WORKER 0] Sent row 650 (count=650)
# [WORKER 0] Sent row 651 (count=651)
# [WORKER 0] Sent row 652 (count=652)
# [WORKER 0] Sent row 653 (count=653)
# [WORKER 0] Sent row 654 (count=654)
# [WORKER 0] Sent row 655 (count=655)
# [WORKER 0] Sent row 656 (count=656)
# [WORKER 0] Sent row 657 (count=657)
# [WORKER 0] Sent row 658 (count=658)
# [WORKER 0] Sent row 659 (count=659)
# [WORKER 0] Sent row 660 (count=660)
# [WORKER 0] Sent row 661 (count=661)
# [WORKER 0] Sent row 662 (count=662)
# [WORKER 0] Sent row 663 (count=663)
# [WORKER 0] Sent row 664 (count=664)
# [WORKER 0] Sent row 665 (count=665)
# [WORKER 0] Sent row 666 (count=666)
# [WORKER 0] Sent row 667 (count=667)
# [WORKER 0] Sent row 668 (count=668)
# [WORKER 0] Sent row 669 (count=669)
# [WORKER 0] Sent row 670 (count=670)
# [WORKER 0] Sent row 671 (count=671)
# [WORKER 0] Sent row 672 (count=672)
# [WORKER 0] Sent row 673 (count=673)
# [WORKER 0] Sent row 674 (count=674)
# [WORKER 0] Sent row 675 (count=675)
# [WORKER 0] Sent row 676 (count=676)
# [WORKER 0] Sent row 677 (count=677)
# [WORKER 0] Sent row 678 (count=678)
# [WORKER 0] Sent row 679 (count=679)
# [WORKER 0] Sent row 680 (count=680)
# [WORKER 0] Sent row 681 (count=681)
# [WORKER 0] Sent row 682 (count=682)
# [WORKER 0] Sent row 683 (count=683)
# [WORKER 0] Sent row 684 (count=684)
# [WORKER 0] Sent row 685 (count=685)
# [WORKER 0] Sent row 686 (count=686)
# [WORKER 0] Sent row 687 (count=687)
# [WORKER 0] Sent row 688 (count=688)
# [WORKER 0] Sent row 689 (count=689)
# [WORKER 0] Sent row 690 (count=690)
# [WORKER 0] Sent row 691 (count=691)
# [WORKER 0] Sent row 692 (count=692)
# [WORKER 0] Sent row 693 (count=693)
# [WORKER 0] Sent row 694 (count=694)
# [WORKER 0] Sent row 695 (count=695)
# [WORKER 0] Sent row 696 (count=696)
# [WORKER 0] Sent row 697 (count=697)
# [WORKER 0] Sent row 698 (count=698)
# [WORKER 0] Sent row 699 (count=699)
# [WORKER 0] Sent row 700 (count=700)
# [WORKER 0] Sent row 701 (count=701)
# [WORKER 0] Sent row 702 (count=702)
# [WORKER 0] Sent row 703 (count=703)
# [WORKER 0] Sent row 704 (count=704)
# [WORKER 0] Sent row 705 (count=705)
# [WORKER 0] Sent row 706 (count=706)
# [WORKER 0] Sent row 707 (count=707)
# [WORKER 0] Sent row 708 (count=708)
# [WORKER 0] Sent row 709 (count=709)
# [WORKER 0] Sent row 710 (count=710)
# [WORKER 0] Sent row 711 (count=711)
# [WORKER 0] Sent row 712 (count=712)
# [WORKER 0] Sent row 713 (count=713)
# [WORKER 0] Sent row 714 (count=714)
# [WORKER 0] Sent row 715 (count=715)
# [WORKER 0] Sent row 716 (count=716)
# [WORKER 0] Sent row 717 (count=717)
# [WORKER 0] Sent row 718 (count=718)
# [WORKER 0] Sent row 719 (count=719)
# [WORKER 0] Sent row 720 (count=720)
# [WORKER 0] Sent row 721 (count=721)
# [WORKER 0] Sent row 722 (count=722)
# [WORKER 0] Sent row 723 (count=723)
# [WORKER 0] Sent row 724 (count=724)
# [WORKER 0] Sent row 725 (count=725)
# [WORKER 0] Sent row 726 (count=726)
# [WORKER 0] Sent row 727 (count=727)
# [WORKER 0] Sent row 728 (count=728)
# [WORKER 0] Sent row 729 (count=729)
# [WORKER 0] Sent row 730 (count=730)
# [WORKER 0] Sent row 731 (count=731)
# [WORKER 0] Sent row 732 (count=732)
# [WORKER 0] Sent row 733 (count=733)
# [WORKER 0] Sent row 734 (count=734)
# [WORKER 0] Sent row 735 (count=735)
# [WORKER 0] Sent row 736 (count=736)
# [WORKER 0] Sent row 737 (count=737)
# [WORKER 0] Sent row 738 (count=738)
# [WORKER 0] Sent row 739 (count=739)
# [WORKER 0] Sent row 740 (count=740)
# [WORKER 0] Sent row 741 (count=741)
# [WORKER 0] Sent row 742 (count=742)
# [WORKER 0] Sent row 743 (count=743)
# [WORKER 0] Sent row 744 (count=744)
# [WORKER 0] Sent row 745 (count=745)
# [WORKER 0] Sent row 746 (count=746)
# [WORKER 0] Sent row 747 (count=747)
# [WORKER 0] Sent row 748 (count=748)
# [WORKER 0] Sent row 749 (count=749)
# [WORKER 0] Sent row 750 (count=750)
# [WORKER 0] Sent row 751 (count=751)
# [WORKER 0] Sent row 752 (count=752)
# [WORKER 0] Sent row 753 (count=753)
# [WORKER 0] Sent row 754 (count=754)
# [WORKER 0] Sent row 755 (count=755)
# [WORKER 0] Sent row 756 (count=756)
# [WORKER 0] Sent row 757 (count=757)
# [WORKER 0] Sent row 758 (count=758)
# [WORKER 0] Sent row 759 (count=759)
# [WORKER 0] Sent row 760 (count=760)
# [WORKER 0] Sent row 761 (count=761)
# [WORKER 0] Sent row 762 (count=762)
# [WORKER 0] Sent row 763 (count=763)
# [WORKER 0] Sent row 764 (count=764)
# [WORKER 0] Sent row 765 (count=765)
# [WORKER 0] Sent row 766 (count=766)
# [WORKER 0] Sent row 767 (count=767)
# [WORKER 0] Sent row 768 (count=768)
# [WORKER 0] Sent row 769 (count=769)
# [WORKER 0] Sent row 770 (count=770)
# [WORKER 0] Sent row 771 (count=771)
# [WORKER 0] Sent row 772 (count=772)
# [WORKER 0] Sent row 773 (count=773)
# [WORKER 0] Sent row 774 (count=774)
# [WORKER 0] Sent row 775 (count=775)
# [WORKER 0] Sent row 776 (count=776)
# [WORKER 0] Sent row 777 (count=777)
# [WORKER 0] Sent row 778 (count=778)
# [WORKER 0] Sent row 779 (count=779)
# [WORKER 0] Sent row 780 (count=780)
# [WORKER 0] Sent row 781 (count=781)
# [WORKER 0] Sent row 782 (count=782)
# [WORKER 0] Sent row 783 (count=783)
# [WORKER 0] Sent row 784 (count=784)
# [WORKER 0] Sent row 785 (count=785)
# [WORKER 0] Sent row 786 (count=786)
# [WORKER 0] Sent row 787 (count=787)
# [WORKER 0] Sent row 788 (count=788)
# [WORKER 0] Sent row 789 (count=789)
# [WORKER 0] Sent row 790 (count=790)
# [WORKER 0] Sent row 791 (count=791)
# [WORKER 0] Sent row 792 (count=792)
# [WORKER 0] Sent row 793 (count=793)
# [WORKER 0] Sent row 794 (count=794)
# [WORKER 0] Sent row 795 (count=795)
# [WORKER 0] Sent row 796 (count=796)
# [WORKER 0] Sent row 797 (count=797)
# [WORKER 0] Sent row 798 (count=798)
# [WORKER 0] Sent row 799 (count=799)
# [WORKER 0] Sent row 800 (count=800)
# [WORKER 0] Sent row 801 (count=801)
# [WORKER 0] Sent row 802 (count=802)
# [WORKER 0] Sent row 803 (count=803)
# [WORKER 0] Sent row 804 (count=804)
# [WORKER 0] Sent row 805 (count=805)
# [WORKER 0] Sent row 806 (count=806)
# [WORKER 0] Sent row 807 (count=807)
# [WORKER 0] Sent row 808 (count=808)
# [WORKER 0] Sent row 809 (count=809)
# [WORKER 0] Sent row 810 (count=810)
# [WORKER 0] Sent row 811 (count=811)
# [WORKER 0] Sent row 812 (count=812)
# [WORKER 0] Sent row 813 (count=813)
# [WORKER 0] Sent row 814 (count=814)
# [WORKER 0] Sent row 815 (count=815)
# [WORKER 0] Sent row 816 (count=816)
# [WORKER 0] Sent row 817 (count=817)
# [WORKER 0] Sent row 818 (count=818)
# [WORKER 0] Sent row 819 (count=819)
# [WORKER 0] Sent row 820 (count=820)
# [WORKER 0] Sent row 821 (count=821)
# [WORKER 0] Sent row 822 (count=822)
# [WORKER 0] Sent row 823 (count=823)
# [WORKER 0] Sent row 824 (count=824)
# [WORKER 0] Sent row 825 (count=825)
# [WORKER 0] Sent row 826 (count=826)
# [WORKER 0] Sent row 827 (count=827)
# [WORKER 0] Sent row 828 (count=828)
# [WORKER 0] Sent row 829 (count=829)
# [WORKER 0] Sent row 830 (count=830)
# [WORKER 0] Sent row 831 (count=831)
# [WORKER 0] Sent row 832 (count=832)
# [WORKER 0] Sent row 833 (count=833)
# [WORKER 0] Sent row 834 (count=834)
# [WORKER 0] Sent row 835 (count=835)
# [WORKER 0] Sent row 836 (count=836)
# [WORKER 0] Sent row 837 (count=837)
# [WORKER 0] Sent row 838 (count=838)
# [WORKER 0] Sent row 839 (count=839)
# [WORKER 0] Sent row 840 (count=840)
# [WORKER 0] Sent row 841 (count=841)
# [WORKER 0] Sent row 842 (count=842)
# [WORKER 0] Sent row 843 (count=843)
# [WORKER 0] Sent row 844 (count=844)
# [WORKER 0] Sent row 845 (count=845)
# [WORKER 0] Sent row 846 (count=846)
# [WORKER 0] Sent row 847 (count=847)
# [WORKER 0] Sent row 848 (count=848)
# [WORKER 0] Sent row 849 (count=849)
# [WORKER 0] Sent row 850 (count=850)
# [WORKER 0] Sent row 851 (count=851)
# [WORKER 0] Sent row 852 (count=852)
# [WORKER 0] Sent row 853 (count=853)
# [WORKER 0] Sent row 854 (count=854)
# [WORKER 0] Sent row 855 (count=855)
# [WORKER 0] Sent row 856 (count=856)
# [WORKER 0] Sent row 857 (count=857)
# [WORKER 0] Sent row 858 (count=858)
# [WORKER 0] Sent row 859 (count=859)
# [WORKER 0] Sent row 860 (count=860)
# [WORKER 0] Sent row 861 (count=861)
# [WORKER 0] Sent row 862 (count=862)
# [WORKER 0] Sent row 863 (count=863)
# [WORKER 0] Sent row 864 (count=864)
# [WORKER 0] Sent row 865 (count=865)
# [WORKER 0] Sent row 866 (count=866)
# [WORKER 0] Sent row 867 (count=867)
# [WORKER 0] Sent row 868 (count=868)
# [WORKER 0] Sent row 869 (count=869)
# [WORKER 0] Sent row 870 (count=870)
# [WORKER 0] Sent row 871 (count=871)
# [WORKER 0] Sent row 872 (count=872)
# [WORKER 0] Sent row 873 (count=873)
# [WORKER 0] Sent row 874 (count=874)
# [WORKER 0] Sent row 875 (count=875)
# [WORKER 0] Sent row 876 (count=876)
# [WORKER 0] Sent row 877 (count=877)
# [WORKER 0] Sent row 878 (count=878)
# [WORKER 0] Sent row 879 (count=879)
# [WORKER 0] Sent row 880 (count=880)
# [WORKER 0] Sent row 881 (count=881)
# [WORKER 0] Sent row 882 (count=882)
# [WORKER 0] Sent row 883 (count=883)
# [WORKER 0] Sent row 884 (count=884)
# [WORKER 0] Sent row 885 (count=885)
# [WORKER 0] Sent row 886 (count=886)
# [WORKER 0] Sent row 887 (count=887)
# [WORKER 0] Sent row 888 (count=888)
# [WORKER 0] Sent row 889 (count=889)
# [WORKER 0] Sent row 890 (count=890)
# [WORKER 0] Sent row 891 (count=891)
# [WORKER 0] Sent row 892 (count=892)
# [WORKER 0] Sent row 893 (count=893)
# [WORKER 0] Sent row 894 (count=894)
# [WORKER 0] Sent row 895 (count=895)
# [WORKER 0] Sent row 896 (count=896)
# [WORKER 0] Sent row 897 (count=897)
# [WORKER 0] Sent row 898 (count=898)
# [WORKER 0] Sent row 899 (count=899)
# [WORKER 0] Sent row 900 (count=900)
# [WORKER 0] Sent row 901 (count=901)
# [WORKER 0] Sent row 902 (count=902)
# [WORKER 0] Sent row 903 (count=903)
# [WORKER 0] Sent row 904 (count=904)
# [WORKER 0] Sent row 905 (count=905)
# [WORKER 0] Sent row 906 (count=906)
# [WORKER 0] Sent row 907 (count=907)
# [WORKER 0] Sent row 908 (count=908)
# [WORKER 0] Sent row 909 (count=909)
# [WORKER 0] Sent row 910 (count=910)
# [WORKER 0] Sent row 911 (count=911)
# [WORKER 0] Sent row 912 (count=912)
# [WORKER 0] Sent row 913 (count=913)
# [WORKER 0] Sent row 914 (count=914)
# [WORKER 0] Sent row 915 (count=915)
# [WORKER 0] Sent row 916 (count=916)
# [WORKER 0] Sent row 917 (count=917)
# [WORKER 0] Sent row 918 (count=918)
# [WORKER 0] Sent row 919 (count=919)
# [WORKER 0] Sent row 920 (count=920)
# [WORKER 0] Sent row 921 (count=921)
# [WORKER 0] Sent row 922 (count=922)
# [WORKER 0] Sent row 923 (count=923)
# [WORKER 0] Sent row 924 (count=924)
# [WORKER 0] Sent row 925 (count=925)
# [WORKER 0] Sent row 926 (count=926)
# [WORKER 0] Sent row 927 (count=927)
# [WORKER 0] Sent row 928 (count=928)
# [WORKER 0] Sent row 929 (count=929)
# [WORKER 0] Sent row 930 (count=930)
# [WORKER 0] Sent row 931 (count=931)
# [WORKER 0] Sent row 932 (count=932)
# [WORKER 0] Sent row 933 (count=933)
# [WORKER 0] Sent row 934 (count=934)
# [WORKER 0] Sent row 935 (count=935)
# [WORKER 0] Sent row 936 (count=936)
# [WORKER 0] Sent row 937 (count=937)
# [WORKER 0] Sent row 938 (count=938)
# [WORKER 0] Sent row 939 (count=939)
# [WORKER 0] Sent row 940 (count=940)
# [WORKER 0] Sent row 941 (count=941)
# [WORKER 0] Sent row 942 (count=942)
# [WORKER 0] Sent row 943 (count=943)
# [WORKER 0] Sent row 944 (count=944)
# [WORKER 0] Sent row 945 (count=945)
# [WORKER 0] Sent row 946 (count=946)
# [WORKER 0] Sent row 947 (count=947)
# [WORKER 0] Sent row 948 (count=948)
# [WORKER 0] Sent row 949 (count=949)
# [WORKER 0] Sent row 950 (count=950)
# [WORKER 0] Sent row 951 (count=951)
# [WORKER 0] Sent row 952 (count=952)
# [WORKER 0] Sent row 953 (count=953)
# [WORKER 0] Sent row 954 (count=954)
# [WORKER 0] Sent row 955 (count=955)
# [WORKER 0] Sent row 956 (count=956)
# [WORKER 0] Sent row 957 (count=957)
# [WORKER 0] Sent row 958 (count=958)
# [WORKER 0] Sent row 959 (count=959)
# [WORKER 0] Sent row 960 (count=960)
# [WORKER 0] Sent row 961 (count=961)
# [WORKER 0] Sent row 962 (count=962)
# [WORKER 0] Sent row 963 (count=963)
# [WORKER 0] Sent row 964 (count=964)
# [WORKER 0] Sent row 965 (count=965)
# [WORKER 0] Sent row 966 (count=966)
# [WORKER 0] Sent row 967 (count=967)
# [WORKER 0] Sent row 968 (count=968)
# [WORKER 0] Sent row 969 (count=969)
# [WORKER 0] Sent row 970 (count=970)
# [WORKER 0] Sent row 971 (count=971)
# [WORKER 0] Sent row 972 (count=972)
# [WORKER 0] Sent row 973 (count=973)
# [WORKER 0] Sent row 974 (count=974)
# [WORKER 0] Sent row 975 (count=975)
# [WORKER 0] Sent row 976 (count=976)
# [WORKER 0] Sent row 977 (count=977)
# [WORKER 0] Sent row 978 (count=978)
# [WORKER 0] Sent row 979 (count=979)
# [WORKER 0] Sent row 980 (count=980)
# [WORKER 0] Sent row 981 (count=981)
# [WORKER 0] Sent row 982 (count=982)
# [WORKER 0] Sent row 983 (count=983)
# [WORKER 0] Sent row 984 (count=984)
# [WORKER 0] Sent row 985 (count=985)
# [WORKER 0] Sent row 986 (count=986)
# [WORKER 0] Sent row 987 (count=987)
# [WORKER 0] Sent row 988 (count=988)
# [WORKER 0] Sent row 989 (count=989)
# [WORKER 0] Sent row 990 (count=990)
# [WORKER 0] Sent row 991 (count=991)
# [WORKER 0] Sent row 992 (count=992)
# [WORKER 0] Sent row 993 (count=993)
# [WORKER 0] Sent row 994 (count=994)
# [WORKER 0] Sent row 995 (count=995)
# [WORKER 0] Sent row 996 (count=996)
# [WORKER 0] Sent row 997 (count=997)
# [WORKER 0] Sent row 998 (count=998)
# [WORKER 0] Sent row 999 (count=999)
# [WORKER 0] Sent row 1000 (count=1000)
# [WORKER 0] Sent row 1001 (count=1001)
# [WORKER 0] Sent row 1002 (count=1002)
# [WORKER 0] Sent row 1003 (count=1003)
# [WORKER 0] Sent row 1004 (count=1004)
# [WORKER 0] Sent row 1005 (count=1005)
# [WORKER 0] Sent row 1006 (count=1006)
# [WORKER 0] Sent row 1007 (count=1007)
# [WORKER 0] Sent row 1008 (count=1008)
# [WORKER 0] Sent row 1009 (count=1009)
# [WORKER 0] Sent row 1010 (count=1010)
# [WORKER 0] Sent row 1011 (count=1011)
# [WORKER 0] Sent row 1012 (count=1012)
# [WORKER 0] Sent row 1013 (count=1013)
# [WORKER 0] Sent row 1014 (count=1014)
# [WORKER 0] Sent row 1015 (count=1015)
# [WORKER 0] Sent row 1016 (count=1016)
# [WORKER 0] Sent row 1017 (count=1017)
# [WORKER 0] Sent row 1018 (count=1018)
# [WORKER 0] Sent row 1019 (count=1019)
# [WORKER 0] Sent row 1020 (count=1020)
# [WORKER 0] Sent row 1021 (count=1021)
# [WORKER 0] Sent row 1022 (count=1022)
# [WORKER 0] Sent row 1023 (count=1023)
#
# Row 0: Actual=0.00000025987910132494559819576986 | Expected=0.00000025987910132494459234414499
# Row 1: Actual=0.00000000000524225748558223353310 | Expected=0.00000000000524225748558223918765
# Row 2: Actual=0.00288655127990549830591104907285 | Expected=0.00288655127990544062635547284401
# Row 3: Actual=0.00000000000066094114954115423683 | Expected=0.00000000000066094114954115726606
# Row 4: Actual=0.00012291017682742748405935739875 | Expected=0.00012291017682742634564707628897
# Row 5: Actual=0.00000000000014385188072078307016 | Expected=0.00000000000014385188072078647804
# ...
# Row 1019: Actual=0.00070228649412208135009022536011 | Expected=0.00070228649412207842274435964924
# Row 1020: Actual=0.00000000000000021596564919078829 | Expected=0.00000000000000021596564919403771
# Row 1021: Actual=0.00013140377359915339353958751989 | Expected=0.00013140377359915344774969614416
# Row 1022: Actual=0.00000000000000027400729184999516 | Expected=0.00000000000000027400729185323773
# Row 1023: Actual=0.00015410181151938846604541877294 | Expected=0.00015410181151938849315047308508
#
# ================================ Performance ================================
#
# Channel 0:
#     {'cycles': 8192, 'beats': 8192, 'bytes': 65536, 'pkts': 1024}
#     {'gap_last': 26361, 'gap_total': 27325252, 'gap_min': 24543, 'gap_max': 197756, 'gap_count': 1023, 'busy_total': 8387674}
#     Throughput: 12.800 Gbps | Handshake util: 100.00%
#     Avg gap length: 26710 cycles, 133554 ns | Busy util: 23.49%
#
# Overhead time: 0.037056s
# Compute time:  0.287245s
