# %%
#/root/jupyter_notebooks/mvm-accelerator/test.ipynb

import pynq
from pynq import Overlay, allocate, MMIO, PL
from threading import Thread, Barrier
import time, re, os, sys
import numpy as np

# %% [markdown]
# ### Config

# %%
VERBOSE = 3 # (0, 1, 2, 3, 4)
PROFILE = 1 # (0, 1)

# %%
# the following params are fixed in hardware

CDMA_BASE = 0xA0000000 
BRAM_BASE = 0x80000000 
PROF_BASE = 0xA00C0000

AXIS_CLK_HZ = 250e6

AVAILABLE_CHANNELS = 4
ACTIVE_CHANNELS = AVAILABLE_CHANNELS
NUM_PARTITIONS  = AVAILABLE_CHANNELS

NUM_ROWS = 17088
ROWS_PER_CHANNEL = NUM_ROWS // ACTIVE_CHANNELS

WORD_WIDTH = 128
ELEMENT_WIDTH = 16
ELEMENTS_PER_WORD = WORD_WIDTH // ELEMENT_WIDTH

BYTES_PER_ELEMENT = ELEMENT_WIDTH // 8
BYTES_PER_WORD = WORD_WIDTH // 8

ELEMENTS_PER_ROW = 17088
WORDS_PER_ROW = ELEMENTS_PER_ROW // ELEMENTS_PER_WORD
BYTES_PER_ROW = WORDS_PER_ROW * BYTES_PER_WORD

ELEMENTS_PER_PARTITION = ELEMENTS_PER_ROW // NUM_PARTITIONS
BYTES_PER_PARTITION = BYTES_PER_ROW // NUM_PARTITIONS
PARTITION_ADDR_WIDTH = BYTES_PER_PARTITION.bit_length() # $clog2(BYTES_PER_PARTITION+1)
PARTITION_ALIGN = 1 << PARTITION_ADDR_WIDTH
PARTITION_BASE = [BRAM_BASE + i*PARTITION_ALIGN for i in range(NUM_PARTITIONS)]

BYTES_PER_CH = ROWS_PER_CHANNEL * ELEMENTS_PER_ROW * BYTES_PER_ELEMENT
DRAM_ROW_BYTES = 64 * 1024 # 64 KiB / row
DRAM_OFFSETS = [0, 4*DRAM_ROW_BYTES, 8*DRAM_ROW_BYTES, 12*DRAM_ROW_BYTES]

PAD = max(DRAM_OFFSETS) + DRAM_ROW_BYTES
ALLOC_SIZE = ACTIVE_CHANNELS * BYTES_PER_CH + PAD

if PROFILE: NUM_DMAS = AVAILABLE_CHANNELS

# %%
assert WORD_WIDTH % ELEMENT_WIDTH == 0
assert ELEMENTS_PER_ROW % ACTIVE_CHANNELS == 0
assert ELEMENTS_PER_ROW % ELEMENTS_PER_WORD == 0
assert NUM_ROWS % ACTIVE_CHANNELS == 0

# %%
BASE_DIR = "/home/ubuntu/mvm-accelerator"
#PROJ_DIR  = f"{BASE_DIR}}/hw/fp{ELEMENT_WIDTH}_{NUM_ROWS}x{ELEMENTS_PER_ROW}/"
BIT       = f"{BASE_DIR}/hw/design_1.bit"
MTRX_FILE = f"{BASE_DIR}/matrix.npy"

# %% [markdown]
# ### Helpers

# %%
#https://github.com/iamNCJ/PYNQ-CDMA-Driver/blob/main/pynq_cdma/cdma.py

from pynq import DefaultIP
from pynq.buffer import PynqBuffer

class CDMA(DefaultIP):
    def __init__(self, description):
        super().__init__(description=description)

    bindto = ['xilinx.com:ip:axi_cdma:4.1']

    @property
    def idle(self):
        """
        `transfer` can only be called when the DMA is idle
        :return: True if the DMA engine is idle
        """
        return self.register_map.CDMASR.Idle

    def _do_transfer(self, source: int, dest: int, bytes_count: int):
        """
        Execute DMA transfer
        :param source: source address
        :param dest: destination address
        :param bytes_count: bytes to transfer
        :return: None
        """
        if not self.idle:
            raise Exception('DMA transfer can only start when engine is idle')

        assert source > 0
        if source > 0xFFFF_FFFF:
            self.register_map.SA_MSB[:] = source >> 8
        self.register_map.SA[:] = source & 0xFFFF_FFFF

        assert dest > 0
        if dest > 0xFFFF_FFFF:
            self.register_map.DA_MSB[:] = dest >> 8
        self.register_map.DA[:] = dest & 0xFFFF_FFFF

        assert bytes_count > 0
        self.register_map.BTT = bytes_count

        # Spin
        while not self.idle:
            pass

    def transfer(self, source, dest, bytes_count=None):
        """
        Transfer data through DMA
        :param source:
        :param dest:
        :param bytes_count:
        :return:
        """
        # Set source
        bytes_source = None
        if isinstance(source, PynqBuffer):
            source_addr = source.device_address
            bytes_source = source.nbytes
        elif isinstance(source, int):
            source_addr = source
        else:
            raise TypeError(f'Type {type(source)} not supported as source')

        bytes_dest = None
        if isinstance(dest, PynqBuffer):
            dest_addr = dest.device_address
            bytes_dest = dest.nbytes
        elif isinstance(dest, int):
            dest_addr = dest
        else:
            raise TypeError(f'Type {type(source)} not supported as dest')

        if bytes_count is None:
            if bytes_source is not None and bytes_dest is not None:
                bytes_count = min(bytes_source, bytes_dest)
            elif bytes_source is not None:
                bytes_count = bytes_source
            elif bytes_dest is not None:
                bytes_count = bytes_dest
            else:
                raise RuntimeError(f'Bytes to transfer is not set and cannot be inferred')

        self._do_transfer(source_addr, dest_addr, bytes_count)

# %%
from typing import Tuple, Dict, Any

class AxisDmaProfiler:
    """
    Address map:
    
        +0x00: STATUS [0]=have_result, [1]=running
        
        +0x04: CYCLES    [31:0]   +0x08: CYCLES    [63:32]
        +0x0C: BEATS     [31:0]   +0x10: BEATS     [63:32]
        +0x14: BYTES     [31:0]   +0x18: BYTES     [63:32]
        +0x1C: PKTS      [31:0]
        
        +0x20: READY_LOW [31:0]   +0x24: READY_LOW [63:32]
        +0x28: VALID_LOW [31:0]   +0x2C: VALID_LOW [63:32]
        
        +0x30: GAP_LAST  [31:0]   +0x34: GAP_LAST  [63:32]
        +0x38: GAP_TOTAL [31:0]   +0x3C: GAP_TOTAL [63:32]
        +0x40: GAP_MIN   [31:0]   +0x44: GAP_MIN   [63:32]
        +0x48: GAP_MAX   [31:0]   +0x4C: GAP_MAX   [63:32]
        +0x50: GAP_COUNT [31:0]
        
        +0x54: GAP_STATUS [0]=gap_valid, [1]=armed
        
        +0x58: BUSY_TOTAL[31:0]   +0x5C: BUSY_TOTAL[63:32]
    """
    
    OFF_STATUS  = 0x00
    OFF_CYCLES  = 0x04
    OFF_BEATS   = 0x0C
    OFF_BYTES   = 0x14
    OFF_PKTS    = 0x1C
    
    OFF_RDY_LOW = 0x20
    OFF_VLD_LOW = 0x28
    
    OFF_FIRSTHS = 0x30
    
    OFF_BUSY_TOTAL = 0x38
    
    OFF_GAP_STATUS = 0x40
    OFF_GAP_LAST   = 0x44
    OFF_GAP_TOTAL  = 0x4C
    OFF_GAP_MIN    = 0x54
    OFF_GAP_MAX    = 0x5C
    OFF_GAP_COUNT  = 0x64
    
    OFF_GLOB_SS_STATUS = 0x68
    OFF_GLOB_SS_CYCLES = 0x6C
    OFF_GLOB_SM_STATUS = 0x74
    OFF_GLOB_SM_CYCLES = 0x78
    
    CH_WINDOW = 0x100 # 0x100 bytes per port

    def __init__(self, overlay, ports=4, axis_clk_hz=300e6, ip_name_contains="axis_dma_profiler", base=None, size=0x1000):
        
        self.overlay = overlay
        self.ports = ports
        self.axis_clk_hz = axis_clk_hz

        key = next((k for k in overlay.ip_dict if ip_name_contains in k), None)
        
        if key is None:
            if base is None:
                raise ValueError(
                    f"Could not find IP containing '{ip_name_contains}' in overlay.ip_dict. "
                    f"Pass base=... explicitly or adjust ip_name_contains."
                )
        else: 
            ip = overlay.ip_dict[key]
            base = int(ip["phys_addr"])
            size = int(ip["addr_range"])

        if base is None: raise ValueError("Profiler base address is unknown.")
        if size is None: raise ValueError("Profiler size is unknown.")

        self.base = base
        self.size = size
        self.mmio = MMIO(self.base, self.size)
        
    def _rd32(self, off):
        return self.mmio.read(off)

    def _rd64(self, off, attempts=4):
        for _ in range(attempts):
            hi1 = self._rd32(off + 4)
            lo  = self._rd32(off)
            hi2 = self._rd32(off + 4)
            if hi1 == hi2:
                return (hi1 << 32) | lo
        return -1

    def _port_base(self, port):
        if not (0 <= port < self.ports):
            raise ValueError(f"Port out of range: {port} (ports={self.ports})")
        return port * self.CH_WINDOW

    # ========== Public ==========

    def stats(self, port) -> Dict[str, int]:
        """
        Reads (cycles, beats, bytes, pkts). Prefer calling when have_result=1 and running=0.
        """
        b = self._port_base(port)
        cycles  = self._rd64(b + self.OFF_CYCLES)
        beats   = self._rd64(b + self.OFF_BEATS)
        bytes_  = self._rd64(b + self.OFF_BYTES)
        pkts    = self._rd32(b + self.OFF_PKTS)
        
        rdy_lo  = self._rd64(b + self.OFF_RDY_LOW)
        vld_lo  = self._rd64(b + self.OFF_VLD_LOW)
        
        firsths = self._rd64(b + self.OFF_FIRSTHS)
        
        return {
            "cycles":  cycles, 
            "beats":   beats, 
            "bytes":   bytes_, 
            "pkts":    pkts,
            "rdy_lo":  rdy_lo,
            "vld_lo":  vld_lo,
            "firsths": firsths
        }
    
    def gap_stats(self, port) -> Dict[str, Any]:
        """
        Inter-packet gap metrics.
        """
        b = self._port_base(port)
        gap_last   = self._rd64(b + self.OFF_GAP_LAST)
        gap_total  = self._rd64(b + self.OFF_GAP_TOTAL)
        gap_min    = self._rd64(b + self.OFF_GAP_MIN)
        gap_max    = self._rd64(b + self.OFF_GAP_MAX)
        gap_count  = self._rd32(b + self.OFF_GAP_COUNT)
        busy_total = self._rd64(b + self.OFF_BUSY_TOTAL)
        
        if gap_count == 0: gap_last = gap_total = gap_min = gap_max = None

        return {
            "gap_last":   gap_last,
            "gap_total":  gap_total,
            "gap_min":    gap_min,
            "gap_max":    gap_max,
            "gap_count":  gap_count,
            "busy_total": busy_total
        }
    
    def glob_stats(self, port=0) -> Dict[str, int]:
        """
        Get global timers
        """
        b = self._port_base(port)
        ss_cycles = self._rd64(b + self.OFF_GLOB_SS_CYCLES)
        sm_cycles = self._rd64(b + self.OFF_GLOB_SM_CYCLES)
        
        return {
            "ss_cycles": ss_cycles,
            "sm_cycles": sm_cycles
        }
        

    def throughput(self, port) -> Tuple[float, float, Dict[str, int]]:
        """
        Returns (gbps, handshake_utilization, stats) for a completed frame .
        - gbps  = (bytes * 8 / cycles) * axis_clk_hz / 1e9
        - handshake_utilization = beats / cycles   (fraction of cycles that handshook)
        """
        s = self.stats(port)
        cycles = max(1, s["cycles"])
        firsths = s["firsths"]
        gbps = (s["bytes"] * 8.0 * self.axis_clk_hz / (cycles+firsths)) / 1e9
        util = s["beats"] / cycles
        return gbps, util, s
    
    def gap_summary(self, port):
        """
        Analogous to `throughput`: return (g, mean_gap_ns, util_long_run).
          - g: dict with gap aggregates (gap_last, gap_min/max, gap_total, gap_count, busy_total)
          - mean_gap_ns: average inter-packet gap in nanoseconds
          - util_long_run: busy_total / (busy_total + gap_total)
        """
        g = self.gap_stats(port)
        gap_total  = g["gap_total"]
        gap_count  = g["gap_count"]
        busy_total = g["busy_total"]

        mean_gap_cycles = (gap_total / gap_count) if gap_count else 0.0
        mean_gap_ns     = (1e9 * mean_gap_cycles / self.axis_clk_hz) if self.axis_clk_hz else 0.0
        util_long_run   = (busy_total / (busy_total + gap_total)) if gap_total else 0.0

        return g, int(mean_gap_cycles), int(mean_gap_ns), util_long_run

    def __repr__(self) -> str:
        return f"AxisDmaProfiler(base=0x{self.base:08x}, size=0x{self.size:x}, ports={self.ports})"

# %%
def create_workers(barrier, dmas, matrix, result):
    workers = []
    for ch in range(ACTIVE_CHANNELS):
        w = Thread(target=worker, args=(barrier, ch, dmas[ch], matrix[ch], result[ch]), daemon=True)
        workers.append(w)
        
    return workers

# %%
def worker(barrier, ch, dma, matrix, result):    
        
    # arm result channel
    dma.recvchannel.transfer(result)
    if VERBOSE > 2: print(f"[WORKER {ch}] Starting up...")
    barrier.wait()
    
    # send inputs
    dma.sendchannel.transfer(matrix)
    dma.sendchannel.wait()
    if VERBOSE > 2: print(f"[WORKER {ch}] Inputs sent.")

    # wait for output
    dma.recvchannel.wait()
    if VERBOSE > 2: print(f"[WORKER {ch}] Results received.")
    result.invalidate()
    barrier.wait()

# %% [markdown]
# # Main

# %% [markdown]
# ### Initialize

# %%
if VERBOSE: 
    print(f"\n================================ Parameters =================================")

    print(f"""
CDMA_BASE = 0x{CDMA_BASE:08x}
BRAM_BASE = 0x{BRAM_BASE:08x}
PROF_BASE = 0x{PROF_BASE:08x}

AXIS_CLK_HZ = {AXIS_CLK_HZ/1e6} MHz

AVAILABLE_CHANNELS = {AVAILABLE_CHANNELS}
ACTIVE_CHANNELS    = {ACTIVE_CHANNELS}
NUM_PARTITIONS     = {NUM_PARTITIONS}

NUM_ROWS           = {NUM_ROWS}
ROWS_PER_CHANNEL   = {ROWS_PER_CHANNEL}

WORD_WIDTH        = {WORD_WIDTH}
ELEMENT_WIDTH     = {ELEMENT_WIDTH}
ELEMENTS_PER_WORD = {ELEMENTS_PER_WORD}

BYTES_PER_ELEMENT = {BYTES_PER_ELEMENT}
BYTES_PER_WORD    = {BYTES_PER_WORD}

ELEMENTS_PER_ROW = {ELEMENTS_PER_ROW}
WORDS_PER_ROW    = {WORDS_PER_ROW}
BYTES_PER_ROW    = {BYTES_PER_ROW}

ELEMENTS_PER_PARTITION = {ELEMENTS_PER_PARTITION}
BYTES_PER_PARTITION    = {BYTES_PER_PARTITION}
PARTITION_ADDR_WIDTH   = {PARTITION_ADDR_WIDTH}
PARTITION_ALIGN        = {PARTITION_ALIGN}
PARTITION_BASE         = {[hex(p) for p in PARTITION_BASE]}

BYTES_PER_CH   = {BYTES_PER_CH}
DRAM_ROW_BYTES = {DRAM_ROW_BYTES}
DRAM_OFFSETS   = {[hex(d) for d in DRAM_OFFSETS]}

PAD        = {PAD:08x}
ALLOC_SIZE = {ALLOC_SIZE:08x}""")

full = vector = result = None 

if VERBOSE: print("\n================================== Setup ====================================\n")

# Make sure matrix exists
if not os.path.exists(MTRX_FILE): raise FileNotFoundError(f"No matrix found at {MTRX_FILE}")

# Load overlay
if VERBOSE: print("Loading Overlay.")
overlay = Overlay(BIT, download=True)
if not overlay.is_loaded():
    raise RuntimeError("Overlay download failed.")
        
# Allocate buffers
if VERBOSE: print("Allocating buffers.")
full = allocate(shape=(ALLOC_SIZE,), dtype='u1')
matrix = []
for ch in range(ACTIVE_CHANNELS):
    start = ch * BYTES_PER_CH + DRAM_OFFSETS[ch]
    sub_u1 = full[start:start+BYTES_PER_CH]
    matrix.append(sub_u1.view(np.float16).reshape((ROWS_PER_CHANNEL, ELEMENTS_PER_ROW)))

vector = allocate(shape=(NUM_PARTITIONS, ELEMENTS_PER_PARTITION,), dtype=np.float16)
result = allocate(shape=(ACTIVE_CHANNELS, ROWS_PER_CHANNEL), dtype=np.float64)

if VERBOSE > 2:
    for ch, m in enumerate(matrix):
        print(f"    matrix[{ch}]: addr=0x{m.physical_address:08x}, nbytes=0x{m.nbytes:08x}")
    print(f"    full:   addr=0x{full.physical_address:08x}, nbytes=0x{full.nbytes:08x}")
    print(f"    vector: addr=0x{vector.physical_address:08x}, nbytes=0x{vector.nbytes:08x}")
    print(f"    result: addr=0x{result.physical_address:08x}, nbytes=0x{result.nbytes:08x}")

if VERBOSE: print("\n================================ Initialize =================================\n")
    
# Initialize buffers
if VERBOSE: print("Initializing Buffers.")

if VERBOSE > 1: print(f"    Loading matrix from {MTRX_FILE}")
matrix_data = np.load(MTRX_FILE, mmap_mode='r')
expected_shape = (ACTIVE_CHANNELS, ROWS_PER_CHANNEL, ELEMENTS_PER_ROW)
if matrix_data.shape != expected_shape:
    raise RuntimeError(f"Matrix shape {matrix_data.shape} does not match expected {expected_shape}.")
for ch, m in enumerate(matrix):
    np.copyto(m, matrix_data[ch])
    m.flush()

for v in vector: v[:] = np.random.rand(ROWS_PER_CHANNEL).astype(np.float16)
vector.flush()
result.fill(0.0)
    
# Initialize profiler
if PROFILE: 
    if VERBOSE: print("Initializing Profiler.")
    prof = AxisDmaProfiler(overlay, ports=NUM_DMAS, axis_clk_hz=AXIS_CLK_HZ, base=PROF_BASE)
    if VERBOSE > 2: print(f"    {prof.__repr__()}")

# Initialize DMAs
if VERBOSE: print("Initializing DMAs.")
dmas = [
    getattr(overlay, name)
    for name in sorted(overlay.ip_dict, key=lambda n: int(re.search(r"\d+$", n).group()))
    if name.startswith("axi_dma")
]
if VERBOSE > 2: print("    dmas =", [d.description['fullpath'] for d in dmas])
if len(dmas) != AVAILABLE_CHANNELS:
    raise RuntimeError(f"Check overlay. Found {len(dmas)} DMAs with AVAILABLE_CHANNELS={AVAILABLE_CHANNELS}.")
        
if VERBOSE: print("\n=============================================================================\n")
# Out:
# ================================ Parameters =================================
#
# CDMA_BASE = 0xa0000000
# BRAM_BASE = 0x80000000
# PROF_BASE = 0xa00c0000
#
# AXIS_CLK_HZ = 250.0 MHz
#
# AVAILABLE_CHANNELS = 4
# ACTIVE_CHANNELS    = 4
# NUM_PARTITIONS     = 4
#
# NUM_ROWS           = 17088
# ROWS_PER_CHANNEL   = 4272
#
# WORD_WIDTH        = 128
# ELEMENT_WIDTH     = 16
# ELEMENTS_PER_WORD = 8
#
# BYTES_PER_ELEMENT = 2
# BYTES_PER_WORD    = 16
#
# ELEMENTS_PER_ROW = 17088
# WORDS_PER_ROW    = 2136
# BYTES_PER_ROW    = 34176
#
# ELEMENTS_PER_PARTITION = 4272
# BYTES_PER_PARTITION    = 8544
# PARTITION_ADDR_WIDTH   = 14
# PARTITION_ALIGN        = 16384
# PARTITION_BASE         = ['0x80000000', '0x80004000', '0x80008000', '0x8000c000']
#
# BYTES_PER_CH   = 145999872
# DRAM_ROW_BYTES = 65536
# DRAM_OFFSETS   = ['0x0', '0x40000', '0x80000', '0xc0000']
#
# PAD        = 000d0000
# ALLOC_SIZE = 22dc2000
#
# ================================== Setup ====================================
#
# Loading Overlay.
# Allocating buffers.
#     matrix[0]: addr=0x39300000, nbytes=0x08b3c800
#     matrix[1]: addr=0x41e7c800, nbytes=0x08b3c800
#     matrix[2]: addr=0x4a9f9000, nbytes=0x08b3c800
#     matrix[3]: addr=0x53575800, nbytes=0x08b3c800
#     full:   addr=0x39300000, nbytes=0x22dc2000
#     vector: addr=0x375b0000, nbytes=0x00008580
#     result: addr=0x375c0000, nbytes=0x00021600
#
# ================================ Initialize =================================
#
# Initializing Buffers.
#     Loading matrix from /home/ubuntu/mvm-accelerator/matrix.npy
# Initializing Profiler.
#     AxisDmaProfiler(base=0xa00c0000, size=0x1000, ports=4)
# Initializing DMAs.
#     dmas = ['axi_dma_0', 'axi_dma_1', 'axi_dma_2', 'axi_dma_3']
#
# =============================================================================

# %% [markdown]
# ### Execute

# %%
def run_once(n, timeout):
    print(f"\n============================== Send Vector ({n}) ==============================\n")

    overlay.download() # for some reason it stalls on the second run without this ???
        
    # Write vector to BRAM
    if VERBOSE: print("Writing vector to BRAM.")
    cdma = CDMA(overlay.ip_dict['axi_cdma_0'])
    cdma_addr = hex(overlay.ip_dict['axi_cdma_0']['phys_addr'])
    
    vec_start = time.perf_counter()
    for p in range(NUM_PARTITIONS):
        start_idx = p*ELEMENTS_PER_PARTITION
        if VERBOSE > 2: 
            print(f"    cdma@{cdma_addr}.transfer("
                  f"src=0x{vector[p].physical_address:08x}, dest=0x{PARTITION_BASE[p]:08x})")
        cdma.transfer(source=vector[p], dest=PARTITION_BASE[p], bytes_count=BYTES_PER_PARTITION)
    vec_end = time.perf_counter()

    vec_time = (vec_end - vec_start) * 1000
    print(f"Elapsed time: {vec_time:.6f} ms")

    if VERBOSE > 1: print(f"\n================================ Compute ({n}) ================================\n")

    # Create worker threads
    barrier = Barrier(ACTIVE_CHANNELS)
    workers = create_workers(barrier, dmas, matrix, result)

    # Aaaand... Go!    
    start = time.perf_counter()
    for w in workers: w.start()
    
    # Join threads with timeout
    for w in workers: 
        w.join(timeout=timeout)
        if w.is_alive():
            raise TimeoutError(f"Worker thread {w.name} timed out.")
    comp_time = (time.perf_counter() - start) * 1000

    # Print results
    if VERBOSE > 1:
        if VERBOSE > 2: print()
        for i in range(ACTIVE_CHANNELS):
            for j in range(ROWS_PER_CHANNEL):
                row_idx = i * ROWS_PER_CHANNEL + j
                if (row_idx > 5 and row_idx < NUM_ROWS-5):
                    if not VERBOSE > 3:
                        if (row_idx == 6): print("...")
                        continue
                actual = result[i][j]
                expected = float(np.dot(matrix[i][j], vector.flatten().astype(np.float64)))
                print(f"Row {row_idx}: Actual={actual:.32f} | Expected={expected:.32f}")

    print(f"\n============================== Performance ({n}) ==============================\n")

    if PROFILE:
        for i in range(prof.ports):
            gbps, util, s = prof.throughput(port=i)
            g, mean_gap_cycles, mean_gap_ns, util_long_run = prof.gap_summary(port=i)
            print(f"Port {i}:")
            print(f"    Handshake util: {util:.3%} | Throughput: {gbps/8:.3f} GB/s")
            if g["gap_count"] > 0: print(f"    Avg gap len: {mean_gap_cycles} cycles, {mean_gap_ns} ns | Busy util: {util_long_run:.2%}")
            if VERBOSE:
                print(f"    {s}")
                if g["gap_count"] > 0: print(f"    {g}")

        glob = prof.glob_stats()
        ss_cycles = glob['ss_cycles']
        sm_cycles = glob['sm_cycles']
        
        ss_time_ms = ss_cycles * (1 / AXIS_CLK_HZ) * 1e3
        sm_time_ms = sm_cycles * (1 / AXIS_CLK_HZ) * 1e3
        throughput = (NUM_ROWS * ELEMENTS_PER_ROW * BYTES_PER_ELEMENT / 1e9) / (sm_time_ms / 1e3) # GB/s
        
        print(f"\nTotal throughput: {throughput:.3f} GB/s")
        print(f"RTL SS time: {ss_cycles} cycles -> {ss_time_ms:.3f} ms")
        print(f"RTL SM time: {sm_cycles} cycles -> {sm_time_ms:.3f} ms")
        
    print(f"Python compute time: {comp_time:.3f} ms")
    print("\n=============================================================================\n")

# %%
NUM_RUNS = 32
MAX_RUN_RETRIES = 3
RUN_TIMEOUT = 0.5

n = 0
while n < NUM_RUNS:
    success = False
    for attempt in range(1, MAX_RUN_RETRIES + 1):
        try:
            print(f"\n****************************** Run {n} (attempt {attempt}) ******************************n")
            run_once(n, RUN_TIMEOUT)
            success = True
            break
        except TimeoutError as e:
            print(f"[Run {n}] Timeout: {e}")
            print("Resetting overlay and retrying this run...")
            overlay.download()

    if not success:
        print(f"[Run {n}] FAILED after {MAX_RUN_RETRIES} attempts, aborting test.")
        break

    n += 1
# Out:
# ****************************** Run 0 (attempt 1) ******************************n
#
# ============================== Send Vector (0) ==============================
#
# Writing vector to BRAM.
#     cdma@0xa0000000.transfer(src=0x375b0000, dest=0x80000000)
#     cdma@0xa0000000.transfer(src=0x375b2160, dest=0x80004000)
#     cdma@0xa0000000.transfer(src=0x375b42c0, dest=0x80008000)
#     cdma@0xa0000000.transfer(src=0x375b6420, dest=0x8000c000)
# Elapsed time: 38.693359 ms
#
# ================================ Compute (0) ================================
#
# [WORKER 1] Starting up...
# [WORKER 2] Starting up...
# [WORKER 0] Starting up...
# [WORKER 3] Starting up...
# [WORKER 0] Inputs sent.
# [WORKER 3] Inputs sent.
# [WORKER 3] Results received.
# [WORKER 0] Results received.
# [WORKER 2] Inputs sent.
# [WORKER 1] Inputs sent.
# [WORKER 2] Results received.
# [WORKER 1] Results received.
#
# Row 0: Actual=4286.84056591987609863281250000000000 | Expected=4286.86249327175755752250552177429199
# Row 1: Actual=4277.48105442523956298828125000000000 | Expected=4277.48995073049081838689744472503662
# Row 2: Actual=4288.63652086257934570312500000000000 | Expected=4288.64307196225854568183422088623047
# Row 3: Actual=4326.32779699563980102539062500000000 | Expected=4326.33743699589831521734595298767090
# Row 4: Actual=4293.05696231126785278320312500000000 | Expected=4293.07362181993084959685802459716797
# Row 5: Actual=4299.83244180679321289062500000000000 | Expected=4299.83507089991326211020350456237793
# ...
# Row 17083: Actual=4309.47935312986373901367187500000000 | Expected=4309.47944732551695778965950012207031
# Row 17084: Actual=4365.56492686271667480468750000000000 | Expected=4365.57213628218414669390767812728882
# Row 17085: Actual=4325.82284796237945556640625000000000 | Expected=4325.82009828357877267990261316299438
# Row 17086: Actual=4339.48127335309982299804687500000000 | Expected=4339.49229616475349757820367813110352
# Row 17087: Actual=4330.44119298458099365234375000000000 | Expected=4330.43400147466127236839383840560913
#
# ============================== Performance (0) ==============================
#
# Port 0:
#     Handshake util: 100.000% | Throughput: 3.655 GB/s
#     {'cycles': 9125035, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 43, 'firsths': 860391}
# Port 1:
#     Handshake util: 99.998% | Throughput: 1.982 GB/s
#     {'cycles': 9125162, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 170, 'firsths': 9289037}
# Port 2:
#     Handshake util: 99.999% | Throughput: 1.894 GB/s
#     {'cycles': 9125102, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 110, 'firsths': 10147446}
# Port 3:
#     Handshake util: 100.000% | Throughput: 4.000 GB/s
#     {'cycles': 9125002, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 10, 'firsths': 0}
#
# Total throughput: 7.575 GB/s
# RTL SS time: 19272549 cycles -> 77.090 ms
# RTL SM time: 19272641 cycles -> 77.091 ms
# Python compute time: 124.616 ms
#
# =============================================================================
#
#
# ****************************** Run 1 (attempt 1) ******************************n
#
# ============================== Send Vector (1) ==============================
#
# Writing vector to BRAM.
#     cdma@0xa0000000.transfer(src=0x375b0000, dest=0x80000000)
#     cdma@0xa0000000.transfer(src=0x375b2160, dest=0x80004000)
#     cdma@0xa0000000.transfer(src=0x375b42c0, dest=0x80008000)
#     cdma@0xa0000000.transfer(src=0x375b6420, dest=0x8000c000)
# Elapsed time: 39.003752 ms
#
# ================================ Compute (1) ================================
#
# [WORKER 0] Starting up...
# [WORKER 1] Starting up...
# [WORKER 2] Starting up...
# [WORKER 3] Starting up...
# [WORKER 2] Inputs sent.
# [WORKER 3] Inputs sent.
# [WORKER 3] Results received.
# [WORKER 2] Results received.
# [WORKER 0] Inputs sent.
# [WORKER 0] Results received.
# [WORKER 1] Inputs sent.
# [WORKER 1] Results received.
#
# Row 0: Actual=4286.84056591987609863281250000000000 | Expected=4286.86249327175755752250552177429199
# Row 1: Actual=4277.48105442523956298828125000000000 | Expected=4277.48995073049081838689744472503662
# Row 2: Actual=4288.63652086257934570312500000000000 | Expected=4288.64307196225854568183422088623047
# Row 3: Actual=4326.32779699563980102539062500000000 | Expected=4326.33743699589831521734595298767090
# Row 4: Actual=4293.05696231126785278320312500000000 | Expected=4293.07362181993084959685802459716797
# Row 5: Actual=4299.83244180679321289062500000000000 | Expected=4299.83507089991326211020350456237793
# ...
# Row 17083: Actual=4309.47935312986373901367187500000000 | Expected=4309.47944732551695778965950012207031
# Row 17084: Actual=4365.56492686271667480468750000000000 | Expected=4365.57213628218414669390767812728882
# Row 17085: Actual=4325.82284796237945556640625000000000 | Expected=4325.82009828357877267990261316299438
# Row 17086: Actual=4339.48127335309982299804687500000000 | Expected=4339.49229616475349757820367813110352
# Row 17087: Actual=4330.44119298458099365234375000000000 | Expected=4330.43400147466127236839383840560913
#
# ============================== Performance (1) ==============================
#
# Port 0:
#     Handshake util: 99.996% | Throughput: 1.982 GB/s
#     {'cycles': 9125355, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 363, 'firsths': 9290352}
# Port 1:
#     Handshake util: 99.997% | Throughput: 1.894 GB/s
#     {'cycles': 9125273, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 281, 'firsths': 10149171}
# Port 2:
#     Handshake util: 99.994% | Throughput: 3.655 GB/s
#     {'cycles': 9125566, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 574, 'firsths': 860707}
# Port 3:
#     Handshake util: 99.994% | Throughput: 4.000 GB/s
#     {'cycles': 9125499, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 507, 'firsths': 0}
#
# Total throughput: 7.575 GB/s
# RTL SS time: 19274445 cycles -> 77.098 ms
# RTL SM time: 19274537 cycles -> 77.098 ms
# Python compute time: 122.775 ms
#
# =============================================================================
#
#
# ****************************** Run 2 (attempt 1) ******************************n
#
# ============================== Send Vector (2) ==============================
#
# Writing vector to BRAM.
#     cdma@0xa0000000.transfer(src=0x375b0000, dest=0x80000000)
#     cdma@0xa0000000.transfer(src=0x375b2160, dest=0x80004000)
#     cdma@0xa0000000.transfer(src=0x375b42c0, dest=0x80008000)
#     cdma@0xa0000000.transfer(src=0x375b6420, dest=0x8000c000)
# Elapsed time: 40.689877 ms
#
# ================================ Compute (2) ================================
#
# [WORKER 1] Starting up...
# [WORKER 2] Starting up...
# [WORKER 0] Starting up...
# [WORKER 3] Starting up...
# [WORKER 0] Inputs sent.
# [WORKER 3] Inputs sent.
# [WORKER 3] Results received.
# [WORKER 0] Results received.
# [WORKER 1] Inputs sent.
# [WORKER 1] Results received.
# [WORKER 2] Inputs sent.
# [WORKER 2] Results received.
#
# Row 0: Actual=4286.84056591987609863281250000000000 | Expected=4286.86249327175755752250552177429199
# Row 1: Actual=4277.48105442523956298828125000000000 | Expected=4277.48995073049081838689744472503662
# Row 2: Actual=4288.63652086257934570312500000000000 | Expected=4288.64307196225854568183422088623047
# Row 3: Actual=4326.32779699563980102539062500000000 | Expected=4326.33743699589831521734595298767090
# Row 4: Actual=4293.05696231126785278320312500000000 | Expected=4293.07362181993084959685802459716797
# Row 5: Actual=4299.83244180679321289062500000000000 | Expected=4299.83507089991326211020350456237793
# ...
# Row 17083: Actual=4309.47935312986373901367187500000000 | Expected=4309.47944732551695778965950012207031
# Row 17084: Actual=4365.56492686271667480468750000000000 | Expected=4365.57213628218414669390767812728882
# Row 17085: Actual=4325.82284796237945556640625000000000 | Expected=4325.82009828357877267990261316299438
# Row 17086: Actual=4339.48127335309982299804687500000000 | Expected=4339.49229616475349757820367813110352
# Row 17087: Actual=4330.44119298458099365234375000000000 | Expected=4330.43400147466127236839383840560913
#
# ============================== Performance (2) ==============================
#
# Port 0:
#     Handshake util: 100.000% | Throughput: 3.655 GB/s
#     {'cycles': 9124998, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 6, 'firsths': 861642}
# Port 1:
#     Handshake util: 100.000% | Throughput: 2.067 GB/s
#     {'cycles': 9124998, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 6, 'firsths': 8530979}
# Port 2:
#     Handshake util: 100.000% | Throughput: 1.790 GB/s
#     {'cycles': 9125004, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 12, 'firsths': 11264580}
# Port 3:
#     Handshake util: 100.000% | Throughput: 4.000 GB/s
#     {'cycles': 9124999, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 7, 'firsths': 0}
#
# Total throughput: 7.160 GB/s
# RTL SS time: 20389585 cycles -> 81.558 ms
# RTL SM time: 20389689 cycles -> 81.559 ms
# Python compute time: 129.536 ms
#
# =============================================================================
#
#
# ****************************** Run 3 (attempt 1) ******************************n
#
# ============================== Send Vector (3) ==============================
# Writing vector to BRAM.
#     cdma@0xa0000000.transfer(src=0x375b0000, dest=0x80000000)
#     cdma@0xa0000000.transfer(src=0x375b2160, dest=0x80004000)
#     cdma@0xa0000000.transfer(src=0x375b42c0, dest=0x80008000)
#     cdma@0xa0000000.transfer(src=0x375b6420, dest=0x8000c000)
# Elapsed time: 39.052683 ms
#
# ================================ Compute (3) ================================
#
# [WORKER 0] Starting up...
# [WORKER 1] Starting up...
# [WORKER 2] Starting up...
# [WORKER 3] Starting up...
# [WORKER 3] Inputs sent.
# [WORKER 3] Results received.
# [WORKER 2] Inputs sent.
# [WORKER 2] Results received.
# [WORKER 0] Inputs sent.
# [WORKER 0] Results received.
# [WORKER 1] Inputs sent.
# [WORKER 1] Results received.
#
# Row 0: Actual=4286.84056591987609863281250000000000 | Expected=4286.86249327175755752250552177429199
# Row 1: Actual=4277.48105442523956298828125000000000 | Expected=4277.48995073049081838689744472503662
# Row 2: Actual=4288.63652086257934570312500000000000 | Expected=4288.64307196225854568183422088623047
# Row 3: Actual=4326.32779699563980102539062500000000 | Expected=4326.33743699589831521734595298767090
# Row 4: Actual=4293.05696231126785278320312500000000 | Expected=4293.07362181993084959685802459716797
# Row 5: Actual=4299.83244180679321289062500000000000 | Expected=4299.83507089991326211020350456237793
# ...
# Row 17083: Actual=4309.47935312986373901367187500000000 | Expected=4309.47944732551695778965950012207031
# Row 17084: Actual=4365.56492686271667480468750000000000 | Expected=4365.57213628218414669390767812728882
# Row 17085: Actual=4325.82284796237945556640625000000000 | Expected=4325.82009828357877267990261316299438
# Row 17086: Actual=4339.48127335309982299804687500000000 | Expected=4339.49229616475349757820367813110352
# Row 17087: Actual=4330.44119298458099365234375000000000 | Expected=4330.43400147466127236839383840560913
#
# ============================== Performance (3) ==============================
#
# Port 0:
#     Handshake util: 99.998% | Throughput: 2.068 GB/s
#     {'cycles': 9125148, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 156, 'firsths': 8522839}
# Port 1:
#     Handshake util: 99.999% | Throughput: 1.890 GB/s
#     {'cycles': 9125089, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 97, 'firsths': 10188285}
# Port 2:
#     Handshake util: 100.000% | Throughput: 3.657 GB/s
#     {'cycles': 9125036, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 44, 'firsths': 854471}
# Port 3:
#     Handshake util: 99.999% | Throughput: 4.000 GB/s
#     {'cycles': 9125087, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 95, 'firsths': 0}
#
# Total throughput: 7.559 GB/s
# RTL SS time: 19313375 cycles -> 77.254 ms
# RTL SM time: 19313549 cycles -> 77.254 ms
# Python compute time: 123.096 ms
#
# =============================================================================
#
#
# ****************************** Run 4 (attempt 1) ******************************n
#
# ============================== Send Vector (4) ==============================
#
# Writing vector to BRAM.
#     cdma@0xa0000000.transfer(src=0x375b0000, dest=0x80000000)
#     cdma@0xa0000000.transfer(src=0x375b2160, dest=0x80004000)
#     cdma@0xa0000000.transfer(src=0x375b42c0, dest=0x80008000)
#     cdma@0xa0000000.transfer(src=0x375b6420, dest=0x8000c000)
# Elapsed time: 41.041920 ms
#
# ================================ Compute (4) ================================
#
# [WORKER 1] Starting up...
# [WORKER 0] Starting up...
# [WORKER 2] Starting up...
# [WORKER 3] Starting up...
# [WORKER 3] Inputs sent.
# [WORKER 1] Inputs sent.
# [WORKER 1] Results received.
# [WORKER 2] Inputs sent.
# [WORKER 2] Results received.
# [WORKER 0] Inputs sent.
# [WORKER 3] Results received.
# [WORKER 0] Results received.
#
# Row 0: Actual=4286.84056591987609863281250000000000 | Expected=4286.86249327175755752250552177429199
# Row 1: Actual=4277.48105442523956298828125000000000 | Expected=4277.48995073049081838689744472503662
# Row 2: Actual=4288.63652086257934570312500000000000 | Expected=4288.64307196225854568183422088623047
# Row 3: Actual=4326.32779699563980102539062500000000 | Expected=4326.33743699589831521734595298767090
# Row 4: Actual=4293.05696231126785278320312500000000 | Expected=4293.07362181993084959685802459716797
# Row 5: Actual=4299.83244180679321289062500000000000 | Expected=4299.83507089991326211020350456237793
# ...
# Row 17083: Actual=4309.47935312986373901367187500000000 | Expected=4309.47944732551695778965950012207031
# Row 17084: Actual=4365.56492686271667480468750000000000 | Expected=4365.57213628218414669390767812728882
# Row 17085: Actual=4325.82284796237945556640625000000000 | Expected=4325.82009828357877267990261316299438
# Row 17086: Actual=4339.48127335309982299804687500000000 | Expected=4339.49229616475349757820367813110352
# Row 17087: Actual=4330.44119298458099365234375000000000 | Expected=4330.43400147466127236839383840560913
#
# ============================== Performance (4) ==============================
#
# Port 0:
#     Handshake util: 100.000% | Throughput: 1.877 GB/s
#     {'cycles': 9124999, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 7, 'firsths': 10319715}
# Port 1:
#     Handshake util: 99.988% | Throughput: 2.562 GB/s
#     {'cycles': 9126065, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 1073, 'firsths': 5122720}
# Port 2:
#     Handshake util: 99.984% | Throughput: 3.656 GB/s
#     {'cycles': 9126409, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 1417, 'firsths': 856877}
# Port 3:
#     Handshake util: 99.992% | Throughput: 4.000 GB/s
#     {'cycles': 9125711, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 719, 'firsths': 0}
#
# Total throughput: 7.508 GB/s
# RTL SS time: 19444715 cycles -> 77.779 ms
# RTL SM time: 19444820 cycles -> 77.779 ms
# Python compute time: 123.606 ms
#
# =============================================================================
#
#
# ****************************** Run 5 (attempt 1) ******************************n
#
# ============================== Send Vector (5) ==============================
#
# Writing vector to BRAM.
#     cdma@0xa0000000.transfer(src=0x375b0000, dest=0x80000000)
#     cdma@0xa0000000.transfer(src=0x375b2160, dest=0x80004000)
#     cdma@0xa0000000.transfer(src=0x375b42c0, dest=0x80008000)
#     cdma@0xa0000000.transfer(src=0x375b6420, dest=0x8000c000)
# Elapsed time: 38.835021 ms
#
# ================================ Compute (5) ================================
#
# [WORKER 0] Starting up...
# [WORKER 1] Starting up...
# [WORKER 3] Starting up...
# [WORKER 2] Starting up...
# [WORKER 3] Inputs sent.
# [WORKER 2] Inputs sent.
# [WORKER 3] Results received.
# [WORKER 2] Results received.
# [WORKER 0] Inputs sent.
# [WORKER 1] Inputs sent.
# [WORKER 1] Results received.
# [WORKER 0] Results received.
#
# Row 0: Actual=4286.84056591987609863281250000000000 | Expected=4286.86249327175755752250552177429199
# Row 1: Actual=4277.48105442523956298828125000000000 | Expected=4277.48995073049081838689744472503662
# Row 2: Actual=4288.63652086257934570312500000000000 | Expected=4288.64307196225854568183422088623047
# Row 3: Actual=4326.32779699563980102539062500000000 | Expected=4326.33743699589831521734595298767090
# Row 4: Actual=4293.05696231126785278320312500000000 | Expected=4293.07362181993084959685802459716797
# Row 5: Actual=4299.83244180679321289062500000000000 | Expected=4299.83507089991326211020350456237793
# ...
# Row 17083: Actual=4309.47935312986373901367187500000000 | Expected=4309.47944732551695778965950012207031
# Row 17084: Actual=4365.56492686271667480468750000000000 | Expected=4365.57213628218414669390767812728882
# Row 17085: Actual=4325.82284796237945556640625000000000 | Expected=4325.82009828357877267990261316299438
# Row 17086: Actual=4339.48127335309982299804687500000000 | Expected=4339.49229616475349757820367813110352
# Row 17087: Actual=4330.44119298458099365234375000000000 | Expected=4330.43400147466127236839383840560913
#
# ============================== Performance (5) ==============================
#
# Port 0:
#     Handshake util: 100.000% | Throughput: 1.897 GB/s
#     {'cycles': 9124998, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 6, 'firsths': 10119174}
# Port 1:
#     Handshake util: 100.000% | Throughput: 1.815 GB/s
#     {'cycles': 9124998, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 6, 'firsths': 10983709}
# Port 2:
#     Handshake util: 100.000% | Throughput: 4.000 GB/s
#     {'cycles': 9124998, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 6, 'firsths': 0}
# Port 3:
#     Handshake util: 100.000% | Throughput: 3.658 GB/s
#     {'cycles': 9124998, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 6, 'firsths': 853970}
#
# Total throughput: 7.260 GB/s
# RTL SS time: 20108708 cycles -> 80.435 ms
# RTL SM time: 20108884 cycles -> 80.436 ms
# Python compute time: 129.766 ms
#
# =============================================================================
#
#
# ****************************** Run 6 (attempt 1) ******************************n
#
# ============================== Send Vector (6) ==============================
# Writing vector to BRAM.
#     cdma@0xa0000000.transfer(src=0x375b0000, dest=0x80000000)
#     cdma@0xa0000000.transfer(src=0x375b2160, dest=0x80004000)
#     cdma@0xa0000000.transfer(src=0x375b42c0, dest=0x80008000)
#     cdma@0xa0000000.transfer(src=0x375b6420, dest=0x8000c000)
# Elapsed time: 38.708100 ms
#
# ================================ Compute (6) ================================
#
# [WORKER 1] Starting up...
# [WORKER 0] Starting up...
# [WORKER 2] Starting up...
# [WORKER 3] Starting up...
# [WORKER 3] Inputs sent.
# [WORKER 3] Results received.
# [WORKER 1] Inputs sent.
# [WORKER 1] Results received.
# [WORKER 0] Inputs sent.
# [WORKER 2] Inputs sent.
# [WORKER 0] Results received.
# [WORKER 2] Results received.
#
# Row 0: Actual=4286.84056591987609863281250000000000 | Expected=4286.86249327175755752250552177429199
# Row 1: Actual=4277.48105442523956298828125000000000 | Expected=4277.48995073049081838689744472503662
# Row 2: Actual=4288.63652086257934570312500000000000 | Expected=4288.64307196225854568183422088623047
# Row 3: Actual=4326.32779699563980102539062500000000 | Expected=4326.33743699589831521734595298767090
# Row 4: Actual=4293.05696231126785278320312500000000 | Expected=4293.07362181993084959685802459716797
# Row 5: Actual=4299.83244180679321289062500000000000 | Expected=4299.83507089991326211020350456237793
# ...
# Row 17083: Actual=4309.47935312986373901367187500000000 | Expected=4309.47944732551695778965950012207031
# Row 17084: Actual=4365.56492686271667480468750000000000 | Expected=4365.57213628218414669390767812728882
# Row 17085: Actual=4325.82284796237945556640625000000000 | Expected=4325.82009828357877267990261316299438
# Row 17086: Actual=4339.48127335309982299804687500000000 | Expected=4339.49229616475349757820367813110352
# Row 17087: Actual=4330.44119298458099365234375000000000 | Expected=4330.43400147466127236839383840560913
#
# ============================== Performance (6) ==============================
#
# Port 0:
#     Handshake util: 100.000% | Throughput: 1.970 GB/s
#     {'cycles': 9124999, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 7, 'firsths': 9406661}
# Port 1:
#     Handshake util: 99.997% | Throughput: 3.656 GB/s
#     {'cycles': 9125227, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 235, 'firsths': 859705}
# Port 2:
#     Handshake util: 99.997% | Throughput: 2.063 GB/s
#     {'cycles': 9125230, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 238, 'firsths': 8567270}
# Port 3:
#     Handshake util: 100.000% | Throughput: 4.000 GB/s
#     {'cycles': 9125005, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 13, 'firsths': 0}
#
# Total throughput: 7.878 GB/s
# RTL SS time: 18531661 cycles -> 74.127 ms
# RTL SM time: 18531766 cycles -> 74.127 ms
# Python compute time: 118.340 ms
#
# =============================================================================
#
#
# ****************************** Run 7 (attempt 1) ******************************n
#
# ============================== Send Vector (7) ==============================
#
# Writing vector to BRAM.
#     cdma@0xa0000000.transfer(src=0x375b0000, dest=0x80000000)
#     cdma@0xa0000000.transfer(src=0x375b2160, dest=0x80004000)
#     cdma@0xa0000000.transfer(src=0x375b42c0, dest=0x80008000)
#     cdma@0xa0000000.transfer(src=0x375b6420, dest=0x8000c000)
# Elapsed time: 40.503136 ms
#
# ================================ Compute (7) ================================
#
# [WORKER 0] Starting up...
# [WORKER 1] Starting up...
# [WORKER 2] Starting up...
# [WORKER 3] Starting up...
# [WORKER 3] Inputs sent.
# [WORKER 2] Inputs sent.
# [WORKER 2] Results received.
# [WORKER 1] Inputs sent.
# [WORKER 0] Inputs sent.
# [WORKER 3] Results received.
# [WORKER 1] Results received.
# [WORKER 0] Results received.
#
# Row 0: Actual=4286.84056591987609863281250000000000 | Expected=4286.86249327175755752250552177429199
# Row 1: Actual=4277.48105442523956298828125000000000 | Expected=4277.48995073049081838689744472503662
# Row 2: Actual=4288.63652086257934570312500000000000 | Expected=4288.64307196225854568183422088623047
# Row 3: Actual=4326.32779699563980102539062500000000 | Expected=4326.33743699589831521734595298767090
# Row 4: Actual=4293.05696231126785278320312500000000 | Expected=4293.07362181993084959685802459716797
# Row 5: Actual=4299.83244180679321289062500000000000 | Expected=4299.83507089991326211020350456237793
# ...
# Row 17083: Actual=4309.47935312986373901367187500000000 | Expected=4309.47944732551695778965950012207031
# Row 17084: Actual=4365.56492686271667480468750000000000 | Expected=4365.57213628218414669390767812728882
# Row 17085: Actual=4325.82284796237945556640625000000000 | Expected=4325.82009828357877267990261316299438
# Row 17086: Actual=4339.48127335309982299804687500000000 | Expected=4339.49229616475349757820367813110352
# Row 17087: Actual=4330.44119298458099365234375000000000 | Expected=4330.43400147466127236839383840560913
#
# ============================== Performance (7) ==============================
#
# Port 0:
#     Handshake util: 99.997% | Throughput: 1.983 GB/s
#     {'cycles': 9125294, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 302, 'firsths': 9277880}
# Port 1:
#     Handshake util: 99.996% | Throughput: 1.895 GB/s
#     {'cycles': 9125371, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 379, 'firsths': 10137737}
# Port 2:
#     Handshake util: 99.999% | Throughput: 3.654 GB/s
#     {'cycles': 9125054, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 62, 'firsths': 863425}
# Port 3:
#     Handshake util: 100.000% | Throughput: 4.000 GB/s
#     {'cycles': 9125032, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 40, 'firsths': 0}
#
# Total throughput: 7.579 GB/s
# RTL SS time: 19263109 cycles -> 77.052 ms
# RTL SM time: 19263318 cycles -> 77.053 ms
# Python compute time: 122.918 ms
#
# =============================================================================
#
#
# ****************************** Run 8 (attempt 1) ******************************n
#
# ============================== Send Vector (8) ==============================
#
# Writing vector to BRAM.
#     cdma@0xa0000000.transfer(src=0x375b0000, dest=0x80000000)
#     cdma@0xa0000000.transfer(src=0x375b2160, dest=0x80004000)
#     cdma@0xa0000000.transfer(src=0x375b42c0, dest=0x80008000)
#     cdma@0xa0000000.transfer(src=0x375b6420, dest=0x8000c000)
# Elapsed time: 37.727142 ms
#
# ================================ Compute (8) ================================
#
# [WORKER 1] Starting up...
# [WORKER 2] Starting up...
# [WORKER 0] Starting up...
# [WORKER 3] Starting up...
# [WORKER 3] Inputs sent.
# [WORKER 3] Results received.
# [WORKER 1] Inputs sent.
# [WORKER 2] Inputs sent.
# [WORKER 0] Inputs sent.
# [WORKER 1] Results received.
# [WORKER 2] Results received.
# [WORKER 0] Results received.
#
# Row 0: Actual=4286.84056591987609863281250000000000 | Expected=4286.86249327175755752250552177429199
# Row 1: Actual=4277.48105442523956298828125000000000 | Expected=4277.48995073049081838689744472503662
# Row 2: Actual=4288.63652086257934570312500000000000 | Expected=4288.64307196225854568183422088623047
# Row 3: Actual=4326.32779699563980102539062500000000 | Expected=4326.33743699589831521734595298767090
# Row 4: Actual=4293.05696231126785278320312500000000 | Expected=4293.07362181993084959685802459716797
# Row 5: Actual=4299.83244180679321289062500000000000 | Expected=4299.83507089991326211020350456237793
# ...
# Row 17083: Actual=4309.47935312986373901367187500000000 | Expected=4309.47944732551695778965950012207031
# Row 17084: Actual=4365.56492686271667480468750000000000 | Expected=4365.57213628218414669390767812728882
# Row 17085: Actual=4325.82284796237945556640625000000000 | Expected=4325.82009828357877267990261316299438
# Row 17086: Actual=4339.48127335309982299804687500000000 | Expected=4339.49229616475349757820367813110352
# Row 17087: Actual=4330.44119298458099365234375000000000 | Expected=4330.43400147466127236839383840560913
#
# ============================== Performance (8) ==============================
#
# Port 0:
#     Handshake util: 100.000% | Throughput: 3.654 GB/s
#     {'cycles': 9125002, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 10, 'firsths': 865318}
# Port 1:
#     Handshake util: 99.993% | Throughput: 1.896 GB/s
#     {'cycles': 9125633, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 641, 'firsths': 10126286}
# Port 2:
#     Handshake util: 99.993% | Throughput: 1.814 GB/s
#     {'cycles': 9125632, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 640, 'firsths': 10997338}
# Port 3:
#     Handshake util: 100.000% | Throughput: 4.000 GB/s
#     {'cycles': 9125016, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 24, 'firsths': 0}
#
# Total throughput: 7.255 GB/s
# RTL SS time: 20122971 cycles -> 80.492 ms
# RTL SM time: 20123063 cycles -> 80.492 ms
# Python compute time: 128.747 ms
#
# =============================================================================
#
#
# ****************************** Run 9 (attempt 1) ******************************n
#
# ============================== Send Vector (9) ==============================
# Writing vector to BRAM.
#     cdma@0xa0000000.transfer(src=0x375b0000, dest=0x80000000)
#     cdma@0xa0000000.transfer(src=0x375b2160, dest=0x80004000)
#     cdma@0xa0000000.transfer(src=0x375b42c0, dest=0x80008000)
#     cdma@0xa0000000.transfer(src=0x375b6420, dest=0x8000c000)
# Elapsed time: 39.382886 ms
#
# ================================ Compute (9) ================================
#
# [WORKER 0] Starting up...
# [WORKER 1] Starting up...
# [WORKER 2] Starting up...
# [WORKER 3] Starting up...
# [WORKER 3] Inputs sent.
# [WORKER 3] Results received.
# [WORKER 2] Inputs sent.
# [WORKER 2] Results received.
# [WORKER 1] Inputs sent.
# [WORKER 0] Inputs sent.
# [WORKER 1] Results received.
# [WORKER 0] Results received.
#
# Row 0: Actual=4286.84056591987609863281250000000000 | Expected=4286.86249327175755752250552177429199
# Row 1: Actual=4277.48105442523956298828125000000000 | Expected=4277.48995073049081838689744472503662
# Row 2: Actual=4288.63652086257934570312500000000000 | Expected=4288.64307196225854568183422088623047
# Row 3: Actual=4326.32779699563980102539062500000000 | Expected=4326.33743699589831521734595298767090
# Row 4: Actual=4293.05696231126785278320312500000000 | Expected=4293.07362181993084959685802459716797
# Row 5: Actual=4299.83244180679321289062500000000000 | Expected=4299.83507089991326211020350456237793
# ...
# Row 17083: Actual=4309.47935312986373901367187500000000 | Expected=4309.47944732551695778965950012207031
# Row 17084: Actual=4365.56492686271667480468750000000000 | Expected=4365.57213628218414669390767812728882
# Row 17085: Actual=4325.82284796237945556640625000000000 | Expected=4325.82009828357877267990261316299438
# Row 17086: Actual=4339.48127335309982299804687500000000 | Expected=4339.49229616475349757820367813110352
# Row 17087: Actual=4330.44119298458099365234375000000000 | Expected=4330.43400147466127236839383840560913
#
# ============================== Performance (9) ==============================
#
# Port 0:
#     Handshake util: 99.992% | Throughput: 1.970 GB/s
#     {'cycles': 9125699, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 707, 'firsths': 9405496}
# Port 1:
#     Handshake util: 99.992% | Throughput: 2.063 GB/s
#     {'cycles': 9125725, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 733, 'firsths': 8565009}
# Port 2:
#     Handshake util: 99.991% | Throughput: 3.655 GB/s
#     {'cycles': 9125846, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 854, 'firsths': 860898}
# Port 3:
#     Handshake util: 99.992% | Throughput: 4.000 GB/s
#     {'cycles': 9125738, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 746, 'firsths': 0}
#
# Total throughput: 7.879 GB/s
# RTL SS time: 18531196 cycles -> 74.125 ms
# RTL SM time: 18531288 cycles -> 74.125 ms
# Python compute time: 118.714 ms
#
# =============================================================================
#
#
# ****************************** Run 10 (attempt 1) ******************************n
#
# ============================== Send Vector (10) ==============================
#
# Writing vector to BRAM.
#     cdma@0xa0000000.transfer(src=0x375b0000, dest=0x80000000)
#     cdma@0xa0000000.transfer(src=0x375b2160, dest=0x80004000)
#     cdma@0xa0000000.transfer(src=0x375b42c0, dest=0x80008000)
#     cdma@0xa0000000.transfer(src=0x375b6420, dest=0x8000c000)
# Elapsed time: 37.623841 ms
#
# ================================ Compute (10) ================================
#
# [WORKER 0] Starting up...
# [WORKER 1] Starting up...
# [WORKER 3] Starting up...
# [WORKER 2] Starting up...
# [WORKER 2] Inputs sent.
# [WORKER 2] Results received.
# [Run 10] Timeout: Worker thread Thread-57 (worker) timed out.
# Resetting overlay and retrying this run...

# %% [markdown]
# ### Cleanup

# %%
for buf in [full, vector, result]: 
    if buf is not None: buf.freebuffer()
