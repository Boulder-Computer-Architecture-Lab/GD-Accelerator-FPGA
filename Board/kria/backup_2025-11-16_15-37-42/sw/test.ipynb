# %%
#/root/jupyter_notebooks/mvm-accelerator/test.ipynb

import pynq
from pynq import Overlay, allocate, MMIO, PL
import time, re, os, sys
import numpy as np

# %% [markdown]
# ### Config

# %%
VERBOSE = 3 # (0, 1, 2, 3, 4)
PROFILE = 1 # (0, 1)

# %%
# the following params are fixed in hardware

CDMA_BASE = 0xA0000000 
BRAM_BASE = 0x80000000 
PROF_BASE = 0xA00C0000

AXIS_CLK_HZ = 250e6
AXIS_CLK_MHZ = AXIS_CLK_HZ / 1e6

AVAILABLE_CHANNELS = 4
ACTIVE_CHANNELS = AVAILABLE_CHANNELS
NUM_PARTITIONS  = AVAILABLE_CHANNELS

NUM_ROWS = 17088
ROWS_PER_CHANNEL = NUM_ROWS // ACTIVE_CHANNELS

WORD_WIDTH = 128
ELEMENT_WIDTH = 16
ELEMENTS_PER_WORD = WORD_WIDTH // ELEMENT_WIDTH

BYTES_PER_ELEMENT = ELEMENT_WIDTH // 8
BYTES_PER_WORD = WORD_WIDTH // 8

ELEMENTS_PER_ROW = 17088
WORDS_PER_ROW = ELEMENTS_PER_ROW // ELEMENTS_PER_WORD
BYTES_PER_ROW = WORDS_PER_ROW * BYTES_PER_WORD

ELEMENTS_PER_PARTITION = ELEMENTS_PER_ROW // NUM_PARTITIONS
BYTES_PER_PARTITION = BYTES_PER_ROW // NUM_PARTITIONS
PARTITION_ADDR_WIDTH = BYTES_PER_PARTITION.bit_length() # $clog2(BYTES_PER_PARTITION+1)
PARTITION_ALIGN = 1 << PARTITION_ADDR_WIDTH
PARTITION_BASE = [BRAM_BASE + i*PARTITION_ALIGN for i in range(NUM_PARTITIONS)]

BYTES_PER_CH = ROWS_PER_CHANNEL * ELEMENTS_PER_ROW * BYTES_PER_ELEMENT
DRAM_ROW_BYTES = 64 * 1024 # 64 KiB / row
DRAM_OFFSETS = [0, 4*DRAM_ROW_BYTES, 8*DRAM_ROW_BYTES, 12*DRAM_ROW_BYTES]

PAD = max(DRAM_OFFSETS) + DRAM_ROW_BYTES
ALLOC_SIZE = ACTIVE_CHANNELS * BYTES_PER_CH + PAD

if PROFILE: NUM_DMAS = AVAILABLE_CHANNELS

# %%
assert WORD_WIDTH % ELEMENT_WIDTH == 0
assert ELEMENTS_PER_ROW % ACTIVE_CHANNELS == 0
assert ELEMENTS_PER_ROW % ELEMENTS_PER_WORD == 0
assert NUM_ROWS % ACTIVE_CHANNELS == 0

# %%
BASE_DIR = "/home/ubuntu/mvm-accelerator"
PROJ_DIR  = f"{BASE_DIR}/hw/fp{ELEMENT_WIDTH}_{NUM_ROWS}x{ELEMENTS_PER_ROW}_{int(AXIS_CLK_MHZ)}"
BIT       = f"{PROJ_DIR}/design_1.bit"
MTRX_FILE = f"{BASE_DIR}/matrix.npy"

# %% [markdown]
# ### Helpers

# %%
#https://github.com/iamNCJ/PYNQ-CDMA-Driver/blob/main/pynq_cdma/cdma.py

from pynq import DefaultIP
from pynq.buffer import PynqBuffer

class CDMA(DefaultIP):
    def __init__(self, description):
        super().__init__(description=description)

    bindto = ['xilinx.com:ip:axi_cdma:4.1']

    @property
    def idle(self):
        """
        `transfer` can only be called when the DMA is idle
        :return: True if the DMA engine is idle
        """
        return self.register_map.CDMASR.Idle

    def _do_transfer(self, source: int, dest: int, bytes_count: int):
        """
        Execute DMA transfer
        :param source: source address
        :param dest: destination address
        :param bytes_count: bytes to transfer
        :return: None
        """
        if not self.idle:
            raise Exception('DMA transfer can only start when engine is idle')

        assert source > 0
        if source > 0xFFFF_FFFF:
            self.register_map.SA_MSB[:] = source >> 8
        self.register_map.SA[:] = source & 0xFFFF_FFFF

        assert dest > 0
        if dest > 0xFFFF_FFFF:
            self.register_map.DA_MSB[:] = dest >> 8
        self.register_map.DA[:] = dest & 0xFFFF_FFFF

        assert bytes_count > 0
        self.register_map.BTT = bytes_count

        # Spin
        while not self.idle:
            pass

    def transfer(self, source, dest, bytes_count=None):
        """
        Transfer data through DMA
        :param source:
        :param dest:
        :param bytes_count:
        :return:
        """
        # Set source
        bytes_source = None
        if isinstance(source, PynqBuffer):
            source_addr = source.device_address
            bytes_source = source.nbytes
        elif isinstance(source, int):
            source_addr = source
        else:
            raise TypeError(f'Type {type(source)} not supported as source')

        bytes_dest = None
        if isinstance(dest, PynqBuffer):
            dest_addr = dest.device_address
            bytes_dest = dest.nbytes
        elif isinstance(dest, int):
            dest_addr = dest
        else:
            raise TypeError(f'Type {type(source)} not supported as dest')

        if bytes_count is None:
            if bytes_source is not None and bytes_dest is not None:
                bytes_count = min(bytes_source, bytes_dest)
            elif bytes_source is not None:
                bytes_count = bytes_source
            elif bytes_dest is not None:
                bytes_count = bytes_dest
            else:
                raise RuntimeError(f'Bytes to transfer is not set and cannot be inferred')

        self._do_transfer(source_addr, dest_addr, bytes_count)

# %%
from typing import Tuple, Dict, Any

class AxisDmaProfiler:
    """
    Address map:
    
        +0x00: STATUS [0]=have_result, [1]=running
        
        +0x04: CYCLES    [31:0]   +0x08: CYCLES    [63:32]
        +0x0C: BEATS     [31:0]   +0x10: BEATS     [63:32]
        +0x14: BYTES     [31:0]   +0x18: BYTES     [63:32]
        +0x1C: PKTS      [31:0]
        
        +0x20: READY_LOW [31:0]   +0x24: READY_LOW [63:32]
        +0x28: VALID_LOW [31:0]   +0x2C: VALID_LOW [63:32]
        
        +0x30: GAP_LAST  [31:0]   +0x34: GAP_LAST  [63:32]
        +0x38: GAP_TOTAL [31:0]   +0x3C: GAP_TOTAL [63:32]
        +0x40: GAP_MIN   [31:0]   +0x44: GAP_MIN   [63:32]
        +0x48: GAP_MAX   [31:0]   +0x4C: GAP_MAX   [63:32]
        +0x50: GAP_COUNT [31:0]
        
        +0x54: GAP_STATUS [0]=gap_valid, [1]=armed
        
        +0x58: BUSY_TOTAL[31:0]   +0x5C: BUSY_TOTAL[63:32]
    """
    
    OFF_STATUS  = 0x00
    OFF_CYCLES  = 0x04
    OFF_BEATS   = 0x0C
    OFF_BYTES   = 0x14
    OFF_PKTS    = 0x1C
    
    OFF_RDY_LOW = 0x20
    OFF_VLD_LOW = 0x28
    
    OFF_FIRSTHS = 0x30
    
    OFF_BUSY_TOTAL = 0x38
    
    OFF_GAP_STATUS = 0x40
    OFF_GAP_LAST   = 0x44
    OFF_GAP_TOTAL  = 0x4C
    OFF_GAP_MIN    = 0x54
    OFF_GAP_MAX    = 0x5C
    OFF_GAP_COUNT  = 0x64
    
    OFF_GLOB_SS_STATUS = 0x68
    OFF_GLOB_SS_CYCLES = 0x6C
    OFF_GLOB_SM_STATUS = 0x74
    OFF_GLOB_SM_CYCLES = 0x78
    
    CH_WINDOW = 0x100 # 0x100 bytes per port

    def __init__(self, overlay, ports=4, axis_clk_hz=300e6, ip_name_contains="axis_dma_profiler", base=None, size=0x1000):
        
        self.overlay = overlay
        self.ports = ports
        self.axis_clk_hz = axis_clk_hz

        key = next((k for k in overlay.ip_dict if ip_name_contains in k), None)
        
        if key is None:
            if base is None:
                raise ValueError(
                    f"Could not find IP containing '{ip_name_contains}' in overlay.ip_dict. "
                    f"Pass base=... explicitly or adjust ip_name_contains."
                )
        else: 
            ip = overlay.ip_dict[key]
            base = int(ip["phys_addr"])
            size = int(ip["addr_range"])

        if base is None: raise ValueError("Profiler base address is unknown.")
        if size is None: raise ValueError("Profiler size is unknown.")

        self.base = base
        self.size = size
        self.mmio = MMIO(self.base, self.size)
        
    def _rd32(self, off):
        return self.mmio.read(off)

    def _rd64(self, off, attempts=4):
        for _ in range(attempts):
            hi1 = self._rd32(off + 4)
            lo  = self._rd32(off)
            hi2 = self._rd32(off + 4)
            if hi1 == hi2:
                return (hi1 << 32) | lo
        return -1

    def _port_base(self, port):
        if not (0 <= port < self.ports):
            raise ValueError(f"Port out of range: {port} (ports={self.ports})")
        return port * self.CH_WINDOW

    # ========== Public ==========

    def stats(self, port) -> Dict[str, int]:
        """
        Reads (cycles, beats, bytes, pkts). Prefer calling when have_result=1 and running=0.
        """
        b = self._port_base(port)
        cycles  = self._rd64(b + self.OFF_CYCLES)
        beats   = self._rd64(b + self.OFF_BEATS)
        bytes_  = self._rd64(b + self.OFF_BYTES)
        pkts    = self._rd32(b + self.OFF_PKTS)
        
        rdy_lo  = self._rd64(b + self.OFF_RDY_LOW)
        vld_lo  = self._rd64(b + self.OFF_VLD_LOW)
        
        firsths = self._rd64(b + self.OFF_FIRSTHS)
        
        return {
            "cycles":  cycles, 
            "beats":   beats, 
            "bytes":   bytes_, 
            "pkts":    pkts,
            "rdy_lo":  rdy_lo,
            "vld_lo":  vld_lo,
            "firsths": firsths
        }
    
    def gap_stats(self, port) -> Dict[str, Any]:
        """
        Inter-packet gap metrics.
        """
        b = self._port_base(port)
        gap_last   = self._rd64(b + self.OFF_GAP_LAST)
        gap_total  = self._rd64(b + self.OFF_GAP_TOTAL)
        gap_min    = self._rd64(b + self.OFF_GAP_MIN)
        gap_max    = self._rd64(b + self.OFF_GAP_MAX)
        gap_count  = self._rd32(b + self.OFF_GAP_COUNT)
        busy_total = self._rd64(b + self.OFF_BUSY_TOTAL)
        
        if gap_count == 0: gap_last = gap_total = gap_min = gap_max = None

        return {
            "gap_last":   gap_last,
            "gap_total":  gap_total,
            "gap_min":    gap_min,
            "gap_max":    gap_max,
            "gap_count":  gap_count,
            "busy_total": busy_total
        }
    
    def glob_stats(self, port=0) -> Dict[str, int]:
        """
        Get global timers
        """
        b = self._port_base(port)
        ss_cycles = self._rd64(b + self.OFF_GLOB_SS_CYCLES)
        sm_cycles = self._rd64(b + self.OFF_GLOB_SM_CYCLES)
        
        return {
            "ss_cycles": ss_cycles,
            "sm_cycles": sm_cycles
        }
        

    def throughput(self, port) -> Tuple[float, float, Dict[str, int]]:
        """
        Returns (gbps, handshake_utilization, stats) for a completed frame .
        - gbps  = (bytes * 8 / cycles) * axis_clk_hz / 1e9
        - handshake_utilization = beats / cycles   (fraction of cycles that handshook)
        """
        s = self.stats(port)
        cycles = max(1, s["cycles"])
        firsths = s["firsths"]
        gbps = (s["bytes"] * 8.0 * self.axis_clk_hz / (cycles+firsths)) / 1e9
        util = s["beats"] / cycles
        return gbps, util, s
    
    def gap_summary(self, port):
        """
        Analogous to `throughput`: return (g, mean_gap_ns, util_long_run).
          - g: dict with gap aggregates (gap_last, gap_min/max, gap_total, gap_count, busy_total)
          - mean_gap_ns: average inter-packet gap in nanoseconds
          - util_long_run: busy_total / (busy_total + gap_total)
        """
        g = self.gap_stats(port)
        gap_total  = g["gap_total"]
        gap_count  = g["gap_count"]
        busy_total = g["busy_total"]

        mean_gap_cycles = (gap_total / gap_count) if gap_count else 0.0
        mean_gap_ns     = (1e9 * mean_gap_cycles / self.axis_clk_hz) if self.axis_clk_hz else 0.0
        util_long_run   = (busy_total / (busy_total + gap_total)) if gap_total else 0.0

        return g, int(mean_gap_cycles), int(mean_gap_ns), util_long_run

    def __repr__(self) -> str:
        return f"AxisDmaProfiler(base=0x{self.base:08x}, size=0x{self.size:x}, ports={self.ports})"

# %% [markdown]
# # Main

# %% [markdown]
# ### Initialize

# %%
if VERBOSE: 
    print(f"\n================================ Parameters =================================")

    print(f"""
CDMA_BASE = 0x{CDMA_BASE:08x}
BRAM_BASE = 0x{BRAM_BASE:08x}
PROF_BASE = 0x{PROF_BASE:08x}

AXIS_CLK_HZ = {AXIS_CLK_HZ}
AXIS_CLK_HZ = {AXIS_CLK_MHZ}

AVAILABLE_CHANNELS = {AVAILABLE_CHANNELS}
ACTIVE_CHANNELS    = {ACTIVE_CHANNELS}
NUM_PARTITIONS     = {NUM_PARTITIONS}

NUM_ROWS           = {NUM_ROWS}
ROWS_PER_CHANNEL   = {ROWS_PER_CHANNEL}

WORD_WIDTH        = {WORD_WIDTH}
ELEMENT_WIDTH     = {ELEMENT_WIDTH}
ELEMENTS_PER_WORD = {ELEMENTS_PER_WORD}

BYTES_PER_ELEMENT = {BYTES_PER_ELEMENT}
BYTES_PER_WORD    = {BYTES_PER_WORD}

ELEMENTS_PER_ROW = {ELEMENTS_PER_ROW}
WORDS_PER_ROW    = {WORDS_PER_ROW}
BYTES_PER_ROW    = {BYTES_PER_ROW}

ELEMENTS_PER_PARTITION = {ELEMENTS_PER_PARTITION}
BYTES_PER_PARTITION    = {BYTES_PER_PARTITION}
PARTITION_ADDR_WIDTH   = {PARTITION_ADDR_WIDTH}
PARTITION_ALIGN        = {PARTITION_ALIGN}
PARTITION_BASE         = {[hex(p) for p in PARTITION_BASE]}

BYTES_PER_CH   = {BYTES_PER_CH}
DRAM_ROW_BYTES = {DRAM_ROW_BYTES}
DRAM_OFFSETS   = {[hex(d) for d in DRAM_OFFSETS]}

PAD        = {PAD:08x}
ALLOC_SIZE = {ALLOC_SIZE:08x}""")

full = vector = result = None 
PL.reset()

if VERBOSE: print("\n================================== Setup ====================================\n")

# Make sure matrix exists
if not os.path.exists(MTRX_FILE): raise FileNotFoundError(f"No matrix found at {MTRX_FILE}")

# Load overlay
if VERBOSE: print("Loading Overlay.")
overlay = Overlay(BIT, download=True)
if not overlay.is_loaded():
    raise RuntimeError("Overlay download failed.")
        
# Allocate buffers
if VERBOSE: print("Allocating buffers.")
full = allocate(shape=(ALLOC_SIZE,), dtype='u1')
matrix = []
for ch in range(ACTIVE_CHANNELS):
    start = ch * BYTES_PER_CH + DRAM_OFFSETS[ch]
    sub_u1 = full[start:start+BYTES_PER_CH]
    matrix.append(sub_u1.view(np.float16).reshape((ROWS_PER_CHANNEL, ELEMENTS_PER_ROW)))

vector = allocate(shape=(NUM_PARTITIONS, ELEMENTS_PER_PARTITION,), dtype=np.float16)
result = allocate(shape=(ACTIVE_CHANNELS, ROWS_PER_CHANNEL), dtype=np.float64)

if VERBOSE > 2:
    for ch, m in enumerate(matrix):
        print(f"    matrix[{ch}]: addr=0x{m.physical_address:08x}, nbytes=0x{m.nbytes:08x}")
    print(f"    full:   addr=0x{full.physical_address:08x}, nbytes=0x{full.nbytes:08x}")
    print(f"    vector: addr=0x{vector.physical_address:08x}, nbytes=0x{vector.nbytes:08x}")
    print(f"    result: addr=0x{result.physical_address:08x}, nbytes=0x{result.nbytes:08x}")

if VERBOSE: print("\n================================ Initialize =================================\n")
    
# Initialize buffers
if VERBOSE: print("Initializing Buffers.")

if VERBOSE > 1: print(f"    Loading matrix from {MTRX_FILE}")
matrix_data = np.load(MTRX_FILE, mmap_mode='r')
expected_shape = (ACTIVE_CHANNELS, ROWS_PER_CHANNEL, ELEMENTS_PER_ROW)
if matrix_data.shape != expected_shape:
    raise RuntimeError(f"Matrix shape {matrix_data.shape} does not match expected {expected_shape}.")
for ch, m in enumerate(matrix):
    np.copyto(m, matrix_data[ch])
    m.flush()

for v in vector: v[:] = np.random.rand(ROWS_PER_CHANNEL).astype(np.float16)
vector.flush()
result.fill(0.0)
    
# Initialize profiler
if PROFILE: 
    if VERBOSE: print("Initializing Profiler.")
    prof = AxisDmaProfiler(overlay, ports=NUM_DMAS, axis_clk_hz=AXIS_CLK_HZ, base=PROF_BASE)
    if VERBOSE > 2: print(f"    {prof.__repr__()}")

# Initialize DMAs
if VERBOSE: print("Initializing DMAs.")
dmas = [
    getattr(overlay, name)
    for name in sorted(overlay.ip_dict, key=lambda n: int(re.search(r"\d+$", n).group()))
    if name.startswith("axi_dma")
]
if VERBOSE > 2: print("    dmas =", [d.description['fullpath'] for d in dmas])
if len(dmas) != AVAILABLE_CHANNELS:
    raise RuntimeError(f"Check overlay. Found {len(dmas)} DMAs with AVAILABLE_CHANNELS={AVAILABLE_CHANNELS}.")
        
if VERBOSE: print("\n=============================================================================\n")
# Out:
# ================================ Parameters =================================
#
# CDMA_BASE = 0xa0000000
# BRAM_BASE = 0x80000000
# PROF_BASE = 0xa00c0000
#
# AXIS_CLK_HZ = 250000000.0
# AXIS_CLK_HZ = 250.0
#
# AVAILABLE_CHANNELS = 4
# ACTIVE_CHANNELS    = 4
# NUM_PARTITIONS     = 4
#
# NUM_ROWS           = 17088
# ROWS_PER_CHANNEL   = 4272
#
# WORD_WIDTH        = 128
# ELEMENT_WIDTH     = 16
# ELEMENTS_PER_WORD = 8
#
# BYTES_PER_ELEMENT = 2
# BYTES_PER_WORD    = 16
#
# ELEMENTS_PER_ROW = 17088
# WORDS_PER_ROW    = 2136
# BYTES_PER_ROW    = 34176
#
# ELEMENTS_PER_PARTITION = 4272
# BYTES_PER_PARTITION    = 8544
# PARTITION_ADDR_WIDTH   = 14
# PARTITION_ALIGN        = 16384
# PARTITION_BASE         = ['0x80000000', '0x80004000', '0x80008000', '0x8000c000']
#
# BYTES_PER_CH   = 145999872
# DRAM_ROW_BYTES = 65536
# DRAM_OFFSETS   = ['0x0', '0x40000', '0x80000', '0xc0000']
#
# PAD        = 000d0000
# ALLOC_SIZE = 22dc2000
#
# ================================== Setup ====================================
#
# Loading Overlay.
# Allocating buffers.
#     matrix[0]: addr=0x39300000, nbytes=0x08b3c800
#     matrix[1]: addr=0x41e7c800, nbytes=0x08b3c800
#     matrix[2]: addr=0x4a9f9000, nbytes=0x08b3c800
#     matrix[3]: addr=0x53575800, nbytes=0x08b3c800
#     full:   addr=0x39300000, nbytes=0x22dc2000
#     vector: addr=0x375b0000, nbytes=0x00008580
#     result: addr=0x375c0000, nbytes=0x00021600
#
# ================================ Initialize =================================
#
# Initializing Buffers.
#     Loading matrix from /home/ubuntu/mvm-accelerator/matrix.npy
# Initializing Profiler.
#     AxisDmaProfiler(base=0xa00c0000, size=0x1000, ports=4)
# Initializing DMAs.
#     dmas = ['axi_dma_0', 'axi_dma_1', 'axi_dma_2', 'axi_dma_3']
#
# =============================================================================

# %% [markdown]
# ### Execute

# %%
def send_vec():
        
    print(f"\n============================== Send Vector ==============================\n")
        
    # Write vector to BRAM
    if VERBOSE: print("Writing vector to BRAM.")
    cdma = CDMA(overlay.ip_dict['axi_cdma_0'])
    cdma_addr = hex(overlay.ip_dict['axi_cdma_0']['phys_addr'])
    
    vec_start = time.perf_counter()
    
    for p in range(NUM_PARTITIONS):
        start_idx = p*ELEMENTS_PER_PARTITION
        if VERBOSE > 2: 
            print(f"    cdma@{cdma_addr}.transfer("
                  f"src=0x{vector[p].physical_address:08x}, dest=0x{PARTITION_BASE[p]:08x})")
        cdma.transfer(source=vector[p], dest=PARTITION_BASE[p], bytes_count=BYTES_PER_PARTITION)
    
    return (time.perf_counter() - start) * 1000

def run_once(n):

    if VERBOSE > 1: print(f"\n================================ Compute ({n}) ================================\n")

    # Aaaand... Go!    
    start = time.perf_counter()
    for ch,d in enumerate(dmas): d.recvchannel.transfer(result[ch])
    for ch,d in enumerate(dmas): d.sendchannel.transfer(matrix[ch])
    for ch,d in enumerate(dmas): d.sendchannel.wait()
    for ch,d in enumerate(dmas): d.recvchannel.wait()
    comp_time_ms = (time.perf_counter() - start) * 1000

    # Print results
    if VERBOSE > 1:
        if VERBOSE > 2: print()
        for i in range(ACTIVE_CHANNELS):
            for j in range(ROWS_PER_CHANNEL):
                row_idx = i * ROWS_PER_CHANNEL + j
                if (row_idx > 5 and row_idx < NUM_ROWS-5):
                    if not VERBOSE > 3:
                        if (row_idx == 6): print("...")
                        continue
                actual = result[i][j]
                expected = float(np.dot(matrix[i][j], vector.flatten().astype(np.float64)))
                print(f"Row {row_idx}: Actual={actual:.32f} | Expected={expected:.32f}")

    print(f"\n============================== Performance ({n}) ==============================\n")

    if PROFILE:
        for i in range(prof.ports):
            gbps, util, s = prof.throughput(port=i)
            g, mean_gap_cycles, mean_gap_ns, util_long_run = prof.gap_summary(port=i)
            print(f"Port {i}:")
            print(f"    Handshake util: {util:.3%} | Throughput: {gbps/8:.3f} GB/s")
            if g["gap_count"] > 0: print(f"    Avg gap len: {mean_gap_cycles} cycles, {mean_gap_ns} ns | Busy util: {util_long_run:.2%}")
            if VERBOSE:
                print(f"    {s}")
                if g["gap_count"] > 0: print(f"    {g}")

        glob = prof.glob_stats()
        ss_cycles = glob['ss_cycles']
        sm_cycles = glob['sm_cycles']
        
        ss_time_ms = ss_cycles * (1 / AXIS_CLK_HZ) * 1e3
        sm_time_ms = sm_cycles * (1 / AXIS_CLK_HZ) * 1e3
        throughput = (NUM_ROWS * ELEMENTS_PER_ROW * BYTES_PER_ELEMENT / 1e9) / (sm_time_ms / 1e3) # GB/s
        
        print(f"\nTotal throughput: {throughput:.3f} GB/s")
        print(f"RTL SS time: {ss_cycles} cycles -> {ss_time_ms:.3f} ms")
        print(f"RTL SM time: {sm_cycles} cycles -> {sm_time_ms:.3f} ms")
        
    result.invalidate()
    return comp_time_ms

# %%
NUM_RUNS = 16

overlay.download()

vec_time_ms = send_vec()
print(f"Elapsed time: {vec_time_ms:.6f} ms")

for n in range(NUM_RUNS):
    comp_time_ms = run_once(n)
    print(f"Python compute time: {comp_time_ms:.3f} ms")

print("\n=============================================================================\n")
# Out:
# ============================== Send Vector ==============================
#
# Writing vector to BRAM.
#     cdma@0xa0000000.transfer(src=0x375b0000, dest=0x80000000)
#     cdma@0xa0000000.transfer(src=0x375b2160, dest=0x80004000)
#     cdma@0xa0000000.transfer(src=0x375b42c0, dest=0x80008000)
#     cdma@0xa0000000.transfer(src=0x375b6420, dest=0x8000c000)
# Elapsed time: -438602389897.780823 ms
#
# ================================ Compute (0) ================================
#
#
# Row 0: Actual=4250.50210529565811157226562500000000 | Expected=4250.49385945867106784135103225708008
# Row 1: Actual=4216.93733721971511840820312500000000 | Expected=4216.94544537068577483296394348144531
# Row 2: Actual=4275.49207729101181030273437500000000 | Expected=4275.48418085025605250848457217216492
# Row 3: Actual=4283.28575313091278076171875000000000 | Expected=4283.28358455227953527355566620826721
# Row 4: Actual=4254.00884646177291870117187500000000 | Expected=4254.02182414436538238078355789184570
# Row 5: Actual=4261.79101175069808959960937500000000 | Expected=4261.78378512621202389709651470184326
# ...
# Row 17083: Actual=4273.12563282251358032226562500000000 | Expected=4273.13700897845410509034991264343262
# Row 17084: Actual=4299.71338564157485961914062500000000 | Expected=4299.71822519297711551189422607421875
# Row 17085: Actual=4286.27866160869598388671875000000000 | Expected=4286.28195848283939994871616363525391
# Row 17086: Actual=4316.56294614076614379882812500000000 | Expected=4316.54429732091739424504339694976807
# Row 17087: Actual=4250.84352046251296997070312500000000 | Expected=4250.84040138460113666951656341552734
#
# ============================== Performance (0) ==============================
#
# Port 0:
#     Handshake util: 99.826% | Throughput: 3.993 GB/s
#     {'cycles': 9140908, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 15212, 'vld_lo': 704, 'firsths': 0}
# Port 1:
#     Handshake util: 99.783% | Throughput: 3.947 GB/s
#     {'cycles': 9144864, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 19872, 'firsths': 102614}
# Port 2:
#     Handshake util: 99.783% | Throughput: 3.903 GB/s
#     {'cycles': 9144863, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 0, 'vld_lo': 19871, 'firsths': 205756}
# Port 3:
#     Handshake util: 99.804% | Throughput: 3.860 GB/s
#     {'cycles': 9142944, 'beats': 9124992, 'bytes': 145999872, 'pkts': 1, 'rdy_lo': 17269, 'vld_lo': 683, 'firsths': 312243}
#
# Total throughput: 15.439 GB/s
# RTL SS time: 9455188 cycles -> 37.821 ms
# RTL SM time: 9456302 cycles -> 37.825 ms
# Python compute time: 62.100 ms
#
# ================================ Compute (1) ================================
#
#
# Row 0: Actual=4250.50210529565811157226562500000000 | Expected=4250.49385945867106784135103225708008
# Row 1: Actual=4216.93733721971511840820312500000000 | Expected=4216.94544537068577483296394348144531
# Row 2: Actual=4275.49207729101181030273437500000000 | Expected=4275.48418085025605250848457217216492
# Row 3: Actual=4283.28575313091278076171875000000000 | Expected=4283.28358455227953527355566620826721
# Row 4: Actual=4254.00884646177291870117187500000000 | Expected=4254.02182414436538238078355789184570
# Row 5: Actual=4261.79101175069808959960937500000000 | Expected=4261.78378512621202389709651470184326
# ...
# Row 17083: Actual=4273.12563282251358032226562500000000 | Expected=4273.13700897845410509034991264343262
# Row 17084: Actual=4299.71338564157485961914062500000000 | Expected=4299.71822519297711551189422607421875
# Row 17085: Actual=4286.27866160869598388671875000000000 | Expected=4286.28195848283939994871616363525391
# Row 17086: Actual=4316.56294614076614379882812500000000 | Expected=4316.54429732091739424504339694976807
# Row 17087: Actual=4250.84352046251296997070312500000000 | Expected=4250.84040138460113666951656341552734
#
# ============================== Performance (1) ==============================
#
# Port 0:
#     Handshake util: 99.835% | Throughput: 1.963 GB/s
#     Avg gap len: 12007122 cycles, 48028488 ns | Busy util: 60.36%
#     {'cycles': 9140070, 'beats': 9124992, 'bytes': 145999872, 'pkts': 2, 'rdy_lo': 14179, 'vld_lo': 899, 'firsths': 9455188}
#     {'gap_last': 12007122, 'gap_total': 12007122, 'gap_min': 12007122, 'gap_max': 12007122, 'gap_count': 1, 'busy_total': 18280976}
# Port 1:
#     Handshake util: 99.786% | Throughput: 3.947 GB/s
#     Avg gap len: 12003250 cycles, 48013000 ns | Busy util: 60.38%
#     {'cycles': 9144583, 'beats': 9124992, 'bytes': 145999872, 'pkts': 2, 'rdy_lo': 0, 'vld_lo': 19591, 'firsths': 102698}
#     {'gap_last': 12003250, 'gap_total': 12003250, 'gap_min': 12003250, 'gap_max': 12003250, 'gap_count': 1, 'busy_total': 18289445}
# Port 2:
#     Handshake util: 99.786% | Throughput: 3.903 GB/s
#     Avg gap len: 12004391 cycles, 48017564 ns | Busy util: 60.37%
#     {'cycles': 9144562, 'beats': 9124992, 'bytes': 145999872, 'pkts': 2, 'rdy_lo': 0, 'vld_lo': 19570, 'firsths': 206980}
#     {'gap_last': 12004391, 'gap_total': 12004391, 'gap_min': 12004391, 'gap_max': 12004391, 'gap_count': 1, 'busy_total': 18289423}
# Port 3:
#     Handshake util: 99.816% | Throughput: 3.861 GB/s
#     Avg gap len: 12003500 cycles, 48014000 ns | Busy util: 60.37%
#     {'cycles': 9141843, 'beats': 9124992, 'bytes': 145999872, 'pkts': 2, 'rdy_lo': 16154, 'vld_lo': 697, 'firsths': 310657}
#     {'gap_last': 12003500, 'gap_total': 12003500, 'gap_min': 12003500, 'gap_max': 12003500, 'gap_count': 1, 'busy_total': 18284785}
#
# Total throughput: 15.444 GB/s
# RTL SS time: 9452501 cycles -> 37.810 ms
# RTL SM time: 9453615 cycles -> 37.814 ms
# Python compute time: 61.961 ms
#
# ================================ Compute (2) ================================
#
#
# Row 0: Actual=4250.50210529565811157226562500000000 | Expected=4250.49385945867106784135103225708008
# Row 1: Actual=4216.93733721971511840820312500000000 | Expected=4216.94544537068577483296394348144531
# Row 2: Actual=4275.49207729101181030273437500000000 | Expected=4275.48418085025605250848457217216492
# Row 3: Actual=4283.28575313091278076171875000000000 | Expected=4283.28358455227953527355566620826721
# Row 4: Actual=4254.00884646177291870117187500000000 | Expected=4254.02182414436538238078355789184570
# Row 5: Actual=4261.79101175069808959960937500000000 | Expected=4261.78378512621202389709651470184326
# ...
# Row 17083: Actual=4273.12563282251358032226562500000000 | Expected=4273.13700897845410509034991264343262
# Row 17084: Actual=4299.71338564157485961914062500000000 | Expected=4299.71822519297711551189422607421875
# Row 17085: Actual=4286.27866160869598388671875000000000 | Expected=4286.28195848283939994871616363525391
# Row 17086: Actual=4316.56294614076614379882812500000000 | Expected=4316.54429732091739424504339694976807
# Row 17087: Actual=4250.84352046251296997070312500000000 | Expected=4250.84040138460113666951656341552734
#
# ============================== Performance (2) ==============================
#
# Port 0:
#     Handshake util: 99.992% | Throughput: 1.965 GB/s
#     Avg gap len: 12045936 cycles, 48183746 ns | Busy util: 53.22%
#     {'cycles': 9125742, 'beats': 9124992, 'bytes': 145999872, 'pkts': 3, 'rdy_lo': 0, 'vld_lo': 750, 'firsths': 9452501}
#     {'gap_last': 12084751, 'gap_total': 24091873, 'gap_min': 12007122, 'gap_max': 12084751, 'gap_count': 2, 'busy_total': 27406717}
# Port 1:
#     Handshake util: 99.959% | Throughput: 3.955 GB/s
#     Avg gap len: 12040929 cycles, 48163716 ns | Busy util: 53.24%
#     {'cycles': 9128717, 'beats': 9124992, 'bytes': 145999872, 'pkts': 3, 'rdy_lo': 0, 'vld_lo': 3725, 'firsths': 101068}
#     {'gap_last': 12078608, 'gap_total': 24081858, 'gap_min': 12003250, 'gap_max': 12078608, 'gap_count': 2, 'busy_total': 27418161}
# Port 2:
#     Handshake util: 99.959% | Throughput: 3.911 GB/s
#     Avg gap len: 12040766 cycles, 48163064 ns | Busy util: 53.24%
#     {'cycles': 9128699, 'beats': 9124992, 'bytes': 145999872, 'pkts': 3, 'rdy_lo': 0, 'vld_lo': 3707, 'firsths': 203862}
#     {'gap_last': 12077141, 'gap_total': 24081532, 'gap_min': 12004391, 'gap_max': 12077141, 'gap_count': 2, 'busy_total': 27418121}
# Port 3:
#     Handshake util: 99.984% | Throughput: 3.869 GB/s
#     Avg gap len: 12041078 cycles, 48164312 ns | Busy util: 53.23%
#     {'cycles': 9126463, 'beats': 9124992, 'bytes': 145999872, 'pkts': 3, 'rdy_lo': 672, 'vld_lo': 799, 'firsths': 306335}
#     {'gap_last': 12078656, 'gap_total': 24082156, 'gap_min': 12003500, 'gap_max': 12078656, 'gap_count': 2, 'busy_total': 27411247}
#
# Total throughput: 15.476 GB/s
# RTL SS time: 9432799 cycles -> 37.731 ms
# RTL SM time: 9433913 cycles -> 37.736 ms
# Python compute time: 61.767 ms
#
# ================================ Compute (3) ================================
# Row 0: Actual=4250.50210529565811157226562500000000 | Expected=4250.49385945867106784135103225708008
# Row 1: Actual=4216.93733721971511840820312500000000 | Expected=4216.94544537068577483296394348144531
# Row 2: Actual=4275.49207729101181030273437500000000 | Expected=4275.48418085025605250848457217216492
# Row 3: Actual=4283.28575313091278076171875000000000 | Expected=4283.28358455227953527355566620826721
# Row 4: Actual=4254.00884646177291870117187500000000 | Expected=4254.02182414436538238078355789184570
# Row 5: Actual=4261.79101175069808959960937500000000 | Expected=4261.78378512621202389709651470184326
# ...
# Row 17083: Actual=4273.12563282251358032226562500000000 | Expected=4273.13700897845410509034991264343262
# Row 17084: Actual=4299.71338564157485961914062500000000 | Expected=4299.71822519297711551189422607421875
# Row 17085: Actual=4286.27866160869598388671875000000000 | Expected=4286.28195848283939994871616363525391
# Row 17086: Actual=4316.56294614076614379882812500000000 | Expected=4316.54429732091739424504339694976807
# Row 17087: Actual=4250.84352046251296997070312500000000 | Expected=4250.84040138460113666951656341552734
#
# ============================== Performance (3) ==============================
#
# Port 0:
#     Handshake util: 99.875% | Throughput: 1.966 GB/s
#     Avg gap len: 12022985 cycles, 48091941 ns | Busy util: 50.33%
#     {'cycles': 9136367, 'beats': 9124992, 'bytes': 145999872, 'pkts': 4, 'rdy_lo': 10269, 'vld_lo': 1106, 'firsths': 9432799}
#     {'gap_last': 11977083, 'gap_total': 36068956, 'gap_min': 11977083, 'gap_max': 12084751, 'gap_count': 3, 'busy_total': 36543083}
# Port 1:
#     Handshake util: 99.823% | Throughput: 3.947 GB/s
#     Avg gap len: 12020346 cycles, 48081384 ns | Busy util: 50.34%
#     {'cycles': 9141209, 'beats': 9124992, 'bytes': 145999872, 'pkts': 4, 'rdy_lo': 0, 'vld_lo': 16217, 'firsths': 106140}
#     {'gap_last': 11979180, 'gap_total': 36061038, 'gap_min': 11979180, 'gap_max': 12078608, 'gap_count': 3, 'busy_total': 36559369}
# Port 2:
#     Handshake util: 99.823% | Throughput: 3.904 GB/s
#     Avg gap len: 12020331 cycles, 48081325 ns | Busy util: 50.34%
#     {'cycles': 9141167, 'beats': 9124992, 'bytes': 145999872, 'pkts': 4, 'rdy_lo': 0, 'vld_lo': 16175, 'firsths': 209198}
#     {'gap_last': 11979462, 'gap_total': 36060994, 'gap_min': 11979462, 'gap_max': 12077141, 'gap_count': 3, 'busy_total': 36559287}
# Port 3:
#     Handshake util: 99.848% | Throughput: 3.862 GB/s
#     Avg gap len: 12021306 cycles, 48085224 ns | Busy util: 50.33%
#     {'cycles': 9138911, 'beats': 9124992, 'bytes': 145999872, 'pkts': 4, 'rdy_lo': 13589, 'vld_lo': 330, 'firsths': 311735}
#     {'gap_last': 11981762, 'gap_total': 36063918, 'gap_min': 11981762, 'gap_max': 12078656, 'gap_count': 3, 'busy_total': 36550157}
#
# Total throughput: 15.447 GB/s
# RTL SS time: 9450647 cycles -> 37.803 ms
# RTL SM time: 9451761 cycles -> 37.807 ms
# Python compute time: 61.854 ms
#
# ================================ Compute (4) ================================
#
#
# Row 0: Actual=4250.50210529565811157226562500000000 | Expected=4250.49385945867106784135103225708008
# Row 1: Actual=4216.93733721971511840820312500000000 | Expected=4216.94544537068577483296394348144531
# Row 2: Actual=4275.49207729101181030273437500000000 | Expected=4275.48418085025605250848457217216492
# Row 3: Actual=4283.28575313091278076171875000000000 | Expected=4283.28358455227953527355566620826721
# Row 4: Actual=4254.00884646177291870117187500000000 | Expected=4254.02182414436538238078355789184570
# Row 5: Actual=4261.79101175069808959960937500000000 | Expected=4261.78378512621202389709651470184326
# ...
# Row 17083: Actual=4273.12563282251358032226562500000000 | Expected=4273.13700897845410509034991264343262
# Row 17084: Actual=4299.71338564157485961914062500000000 | Expected=4299.71822519297711551189422607421875
# Row 17085: Actual=4286.27866160869598388671875000000000 | Expected=4286.28195848283939994871616363525391
# Row 17086: Actual=4316.56294614076614379882812500000000 | Expected=4316.54429732091739424504339694976807
# Row 17087: Actual=4250.84352046251296997070312500000000 | Expected=4250.84040138460113666951656341552734
#
# ============================== Performance (4) ==============================
#
# Port 0:
#     Handshake util: 99.512% | Throughput: 1.960 GB/s
#     Avg gap len: 12061170 cycles, 48244680 ns | Busy util: 48.65%
#     {'cycles': 9169777, 'beats': 9124992, 'bytes': 145999872, 'pkts': 5, 'rdy_lo': 43935, 'vld_lo': 850, 'firsths': 9450647}
#     {'gap_last': 12175724, 'gap_total': 48244680, 'gap_min': 11977083, 'gap_max': 12175724, 'gap_count': 4, 'busy_total': 45712859}
# Port 1:
#     Handshake util: 99.455% | Throughput: 3.935 GB/s
#     Avg gap len: 12056828 cycles, 48227313 ns | Busy util: 48.67%
#     {'cycles': 9175038, 'beats': 9124992, 'bytes': 145999872, 'pkts': 5, 'rdy_lo': 0, 'vld_lo': 50046, 'firsths': 101533}
#     {'gap_last': 12166275, 'gap_total': 48227313, 'gap_min': 11979180, 'gap_max': 12166275, 'gap_count': 4, 'busy_total': 45734406}
# Port 2:
#     Handshake util: 99.455% | Throughput: 3.890 GB/s
#     Avg gap len: 12057450 cycles, 48229801 ns | Busy util: 48.67%
#     {'cycles': 9175012, 'beats': 9124992, 'bytes': 145999872, 'pkts': 5, 'rdy_lo': 0, 'vld_lo': 50020, 'firsths': 207081}
#     {'gap_last': 12168807, 'gap_total': 48229801, 'gap_min': 11979462, 'gap_max': 12168807, 'gap_count': 4, 'busy_total': 45734298}
# Port 3:
#     Handshake util: 99.475% | Throughput: 3.848 GB/s
#     Avg gap len: 12059108 cycles, 48236434 ns | Busy util: 48.66%
#     {'cycles': 9173167, 'beats': 9124992, 'bytes': 145999872, 'pkts': 5, 'rdy_lo': 48136, 'vld_lo': 39, 'firsths': 311071}
#     {'gap_last': 12172516, 'gap_total': 48236434, 'gap_min': 11981762, 'gap_max': 12172516, 'gap_count': 4, 'busy_total': 45723323}
#
# Total throughput: 15.392 GB/s
# RTL SS time: 9484239 cycles -> 37.937 ms
# RTL SM time: 9485353 cycles -> 37.941 ms
# Python compute time: 62.058 ms
#
# ================================ Compute (5) ================================
#
#
# Row 0: Actual=4250.50210529565811157226562500000000 | Expected=4250.49385945867106784135103225708008
# Row 1: Actual=4216.93733721971511840820312500000000 | Expected=4216.94544537068577483296394348144531
# Row 2: Actual=4275.49207729101181030273437500000000 | Expected=4275.48418085025605250848457217216492
# Row 3: Actual=4283.28575313091278076171875000000000 | Expected=4283.28358455227953527355566620826721
# Row 4: Actual=4254.00884646177291870117187500000000 | Expected=4254.02182414436538238078355789184570
# Row 5: Actual=4261.79101175069808959960937500000000 | Expected=4261.78378512621202389709651470184326
# ...
# Row 17083: Actual=4273.12563282251358032226562500000000 | Expected=4273.13700897845410509034991264343262
# Row 17084: Actual=4299.71338564157485961914062500000000 | Expected=4299.71822519297711551189422607421875
# Row 17085: Actual=4286.27866160869598388671875000000000 | Expected=4286.28195848283939994871616363525391
# Row 17086: Actual=4316.56294614076614379882812500000000 | Expected=4316.54429732091739424504339694976807
# Row 17087: Actual=4250.84352046251296997070312500000000 | Expected=4250.84040138460113666951656341552734
#
# ============================== Performance (5) ==============================
#
# Port 0:
#     Handshake util: 98.651% | Throughput: 1.948 GB/s
#     Avg gap len: 12049346 cycles, 48197386 ns | Busy util: 47.71%
#     {'cycles': 9249787, 'beats': 9124992, 'bytes': 145999872, 'pkts': 6, 'rdy_lo': 123778, 'vld_lo': 1017, 'firsths': 9484239}
#     {'gap_last': 12002053, 'gap_total': 60246733, 'gap_min': 11977083, 'gap_max': 12175724, 'gap_count': 5, 'busy_total': 54962645}
# Port 1:
#     Handshake util: 98.590% | Throughput: 3.901 GB/s
#     Avg gap len: 12044857 cycles, 48179428 ns | Busy util: 47.73%
#     {'cycles': 9255449, 'beats': 9124992, 'bytes': 145999872, 'pkts': 6, 'rdy_lo': 0, 'vld_lo': 130457, 'firsths': 101714}
#     {'gap_last': 11996973, 'gap_total': 60224286, 'gap_min': 11979180, 'gap_max': 12166275, 'gap_count': 5, 'busy_total': 54989854}
# Port 2:
#     Handshake util: 98.590% | Throughput: 3.858 GB/s
#     Avg gap len: 12044764 cycles, 48179059 ns | Busy util: 47.73%
#     {'cycles': 9255464, 'beats': 9124992, 'bytes': 145999872, 'pkts': 6, 'rdy_lo': 0, 'vld_lo': 130472, 'firsths': 204286}
#     {'gap_last': 11994023, 'gap_total': 60223824, 'gap_min': 11979462, 'gap_max': 12168807, 'gap_count': 5, 'busy_total': 54989761}
# Port 3:
#     Handshake util: 98.622% | Throughput: 3.817 GB/s
#     Avg gap len: 12046748 cycles, 48186994 ns | Busy util: 47.72%
#     {'cycles': 9252500, 'beats': 9124992, 'bytes': 145999872, 'pkts': 6, 'rdy_lo': 126986, 'vld_lo': 522, 'firsths': 309717}
#     {'gap_last': 11997309, 'gap_total': 60233743, 'gap_min': 11981762, 'gap_max': 12172516, 'gap_count': 5, 'busy_total': 54975822}
#
# Total throughput: 15.267 GB/s
# RTL SS time: 9562218 cycles -> 38.249 ms
# RTL SM time: 9563332 cycles -> 38.253 ms
# Python compute time: 62.551 ms
#
# ================================ Compute (6) ================================
#
#
# Row 0: Actual=4250.50210529565811157226562500000000 | Expected=4250.49385945867106784135103225708008
# Row 1: Actual=4216.93733721971511840820312500000000 | Expected=4216.94544537068577483296394348144531
# Row 2: Actual=4275.49207729101181030273437500000000 | Expected=4275.48418085025605250848457217216492
# Row 3: Actual=4283.28575313091278076171875000000000 | Expected=4283.28358455227953527355566620826721
# Row 4: Actual=4254.00884646177291870117187500000000 | Expected=4254.02182414436538238078355789184570
# Row 5: Actual=4261.79101175069808959960937500000000 | Expected=4261.78378512621202389709651470184326
# ...
# Row 17083: Actual=4273.12563282251358032226562500000000 | Expected=4273.13700897845410509034991264343262
# Row 17084: Actual=4299.71338564157485961914062500000000 | Expected=4299.71822519297711551189422607421875
# Row 17085: Actual=4286.27866160869598388671875000000000 | Expected=4286.28195848283939994871616363525391
# Row 17086: Actual=4316.56294614076614379882812500000000 | Expected=4316.54429732091739424504339694976807
# Row 17087: Actual=4250.84352046251296997070312500000000 | Expected=4250.84040138460113666951656341552734
#
# ============================== Performance (6) ==============================
#
# Port 0:
#     Handshake util: 99.996% | Throughput: 1.953 GB/s
#     Avg gap len: 12060299 cycles, 48241197 ns | Busy util: 46.97%
#     {'cycles': 9125355, 'beats': 9124992, 'bytes': 145999872, 'pkts': 7, 'rdy_lo': 0, 'vld_lo': 363, 'firsths': 9562218}
#     {'gap_last': 12115063, 'gap_total': 72361796, 'gap_min': 11977083, 'gap_max': 12175724, 'gap_count': 6, 'busy_total': 64087999}
# Port 1:
#     Handshake util: 99.986% | Throughput: 3.950 GB/s
#     Avg gap len: 12057842 cycles, 48231370 ns | Busy util: 46.98%
#     {'cycles': 9126237, 'beats': 9124992, 'bytes': 145999872, 'pkts': 7, 'rdy_lo': 0, 'vld_lo': 1245, 'firsths': 115082}
#     {'gap_last': 12122769, 'gap_total': 72347055, 'gap_min': 11979180, 'gap_max': 12166275, 'gap_count': 6, 'busy_total': 64116090}
# Port 2:
#     Handshake util: 99.986% | Throughput: 3.906 GB/s
#     Avg gap len: 12057771 cycles, 48231087 ns | Busy util: 46.98%
#     {'cycles': 9126241, 'beats': 9124992, 'bytes': 145999872, 'pkts': 7, 'rdy_lo': 0, 'vld_lo': 1249, 'firsths': 217707}
#     {'gap_last': 12122807, 'gap_total': 72346631, 'gap_min': 11979462, 'gap_max': 12168807, 'gap_count': 6, 'busy_total': 64116001}
# Port 3:
#     Handshake util: 99.995% | Throughput: 3.862 GB/s
#     Avg gap len: 12060375 cycles, 48241502 ns | Busy util: 46.97%
#     {'cycles': 9125459, 'beats': 9124992, 'bytes': 145999872, 'pkts': 7, 'rdy_lo': 28, 'vld_lo': 439, 'firsths': 325877}
#     {'gap_last': 12128510, 'gap_total': 72362253, 'gap_min': 11981762, 'gap_max': 12172516, 'gap_count': 6, 'busy_total': 64101280}
#
# Total throughput: 15.446 GB/s
# RTL SS time: 9451337 cycles -> 37.805 ms
# RTL SM time: 9452012 cycles -> 37.808 ms
# Python compute time: 61.925 ms
#
# ================================ Compute (7) ================================
# Row 0: Actual=4250.50210529565811157226562500000000 | Expected=4250.49385945867106784135103225708008
# Row 1: Actual=4216.93733721971511840820312500000000 | Expected=4216.94544537068577483296394348144531
# Row 2: Actual=4275.49207729101181030273437500000000 | Expected=4275.48418085025605250848457217216492
# Row 3: Actual=4283.28575313091278076171875000000000 | Expected=4283.28358455227953527355566620826721
# Row 4: Actual=4254.00884646177291870117187500000000 | Expected=4254.02182414436538238078355789184570
# Row 5: Actual=4261.79101175069808959960937500000000 | Expected=4261.78378512621202389709651470184326
# ...
# Row 17083: Actual=4273.12563282251358032226562500000000 | Expected=4273.13700897845410509034991264343262
# Row 17084: Actual=4299.71338564157485961914062500000000 | Expected=4299.71822519297711551189422607421875
# Row 17085: Actual=4286.27866160869598388671875000000000 | Expected=4286.28195848283939994871616363525391
# Row 17086: Actual=4316.56294614076614379882812500000000 | Expected=4316.54429732091739424504339694976807
# Row 17087: Actual=4250.84352046251296997070312500000000 | Expected=4250.84040138460113666951656341552734
#
# ============================== Performance (7) ==============================
#
# Port 0:
#     Handshake util: 99.589% | Throughput: 1.961 GB/s
#     Avg gap len: 12057715 cycles, 48230862 ns | Busy util: 46.46%
#     {'cycles': 9162659, 'beats': 9124992, 'bytes': 145999872, 'pkts': 8, 'rdy_lo': 37459, 'vld_lo': 208, 'firsths': 9451337}
#     {'gap_last': 12042214, 'gap_total': 84404010, 'gap_min': 11977083, 'gap_max': 12175724, 'gap_count': 7, 'busy_total': 73250657}
# Port 1:
#     Handshake util: 99.549% | Throughput: 3.938 GB/s
#     Avg gap len: 12053653 cycles, 48214613 ns | Busy util: 46.48%
#     {'cycles': 9166350, 'beats': 9124992, 'bytes': 145999872, 'pkts': 8, 'rdy_lo': 0, 'vld_lo': 41358, 'firsths': 102269}
#     {'gap_last': 12028519, 'gap_total': 84375574, 'gap_min': 11979180, 'gap_max': 12166275, 'gap_count': 7, 'busy_total': 73282439}
# Port 2:
#     Handshake util: 99.549% | Throughput: 3.895 GB/s
#     Avg gap len: 12053470 cycles, 48213881 ns | Busy util: 46.48%
#     {'cycles': 9166333, 'beats': 9124992, 'bytes': 145999872, 'pkts': 8, 'rdy_lo': 0, 'vld_lo': 41341, 'firsths': 204040}
#     {'gap_last': 12027661, 'gap_total': 84374292, 'gap_min': 11979462, 'gap_max': 12168807, 'gap_count': 7, 'busy_total': 73282333}
# Port 3:
#     Handshake util: 99.569% | Throughput: 3.854 GB/s
#     Avg gap len: 12055016 cycles, 48220065 ns | Busy util: 46.47%
#     {'cycles': 9164527, 'beats': 9124992, 'bytes': 145999872, 'pkts': 8, 'rdy_lo': 39366, 'vld_lo': 169, 'firsths': 306629}
#     {'gap_last': 12022862, 'gap_total': 84385115, 'gap_min': 11981762, 'gap_max': 12172516, 'gap_count': 7, 'busy_total': 73265806}
#
# Total throughput: 15.413 GB/s
# RTL SS time: 9471157 cycles -> 37.885 ms
# RTL SM time: 9472271 cycles -> 37.889 ms
# Python compute time: 61.996 ms
#
# ================================ Compute (8) ================================
#
#
# Row 0: Actual=4250.50210529565811157226562500000000 | Expected=4250.49385945867106784135103225708008
# Row 1: Actual=4216.93733721971511840820312500000000 | Expected=4216.94544537068577483296394348144531
# Row 2: Actual=4275.49207729101181030273437500000000 | Expected=4275.48418085025605250848457217216492
# Row 3: Actual=4283.28575313091278076171875000000000 | Expected=4283.28358455227953527355566620826721
# Row 4: Actual=4254.00884646177291870117187500000000 | Expected=4254.02182414436538238078355789184570
# Row 5: Actual=4261.79101175069808959960937500000000 | Expected=4261.78378512621202389709651470184326
# ...
# Row 17083: Actual=4273.12563282251358032226562500000000 | Expected=4273.13700897845410509034991264343262
# Row 17084: Actual=4299.71338564157485961914062500000000 | Expected=4299.71822519297711551189422607421875
# Row 17085: Actual=4286.27866160869598388671875000000000 | Expected=4286.28195848283939994871616363525391
# Row 17086: Actual=4316.56294614076614379882812500000000 | Expected=4316.54429732091739424504339694976807
# Row 17087: Actual=4250.84352046251296997070312500000000 | Expected=4250.84040138460113666951656341552734
#
# ============================== Performance (8) ==============================
#
# Port 0:
#     Handshake util: 99.825% | Throughput: 1.961 GB/s
#     Avg gap len: 12064717 cycles, 48258870 ns | Busy util: 46.05%
#     {'cycles': 9140993, 'beats': 9124992, 'bytes': 145999872, 'pkts': 9, 'rdy_lo': 15660, 'vld_lo': 341, 'firsths': 9471157}
#     {'gap_last': 12113730, 'gap_total': 96517740, 'gap_min': 11977083, 'gap_max': 12175724, 'gap_count': 8, 'busy_total': 82391649}
# Port 1:
#     Handshake util: 99.783% | Throughput: 3.947 GB/s
#     Avg gap len: 12060683 cycles, 48242735 ns | Busy util: 46.07%
#     {'cycles': 9144801, 'beats': 9124992, 'bytes': 145999872, 'pkts': 9, 'rdy_lo': 0, 'vld_lo': 19809, 'firsths': 102126}
#     {'gap_last': 12109896, 'gap_total': 96485470, 'gap_min': 11979180, 'gap_max': 12166275, 'gap_count': 8, 'busy_total': 82427239}
# Port 2:
#     Handshake util: 99.784% | Throughput: 3.904 GB/s
#     Avg gap len: 12060534 cycles, 48242137 ns | Busy util: 46.07%
#     {'cycles': 9144787, 'beats': 9124992, 'bytes': 145999872, 'pkts': 9, 'rdy_lo': 0, 'vld_lo': 19795, 'firsths': 203967}
#     {'gap_last': 12109983, 'gap_total': 96484275, 'gap_min': 11979462, 'gap_max': 12168807, 'gap_count': 8, 'busy_total': 82427119}
# Port 3:
#     Handshake util: 99.814% | Throughput: 3.855 GB/s
#     Avg gap len: 12064625 cycles, 48258503 ns | Busy util: 46.06%
#     {'cycles': 9142030, 'beats': 9124992, 'bytes': 145999872, 'pkts': 9, 'rdy_lo': 16723, 'vld_lo': 315, 'firsths': 326658}
#     {'gap_last': 12131891, 'gap_total': 96517006, 'gap_min': 11981762, 'gap_max': 12172516, 'gap_count': 8, 'busy_total': 82407835}
#
# Total throughput: 15.417 GB/s
# RTL SS time: 9468689 cycles -> 37.875 ms
# RTL SM time: 9469803 cycles -> 37.879 ms
# Python compute time: 61.985 ms
#
# ================================ Compute (9) ================================
#
#
# Row 0: Actual=4250.50210529565811157226562500000000 | Expected=4250.49385945867106784135103225708008
# Row 1: Actual=4216.93733721971511840820312500000000 | Expected=4216.94544537068577483296394348144531
# Row 2: Actual=4275.49207729101181030273437500000000 | Expected=4275.48418085025605250848457217216492
# Row 3: Actual=4283.28575313091278076171875000000000 | Expected=4283.28358455227953527355566620826721
# Row 4: Actual=4254.00884646177291870117187500000000 | Expected=4254.02182414436538238078355789184570
# Row 5: Actual=4261.79101175069808959960937500000000 | Expected=4261.78378512621202389709651470184326
# ...
# Row 17083: Actual=4273.12563282251358032226562500000000 | Expected=4273.13700897845410509034991264343262
# Row 17084: Actual=4299.71338564157485961914062500000000 | Expected=4299.71822519297711551189422607421875
# Row 17085: Actual=4286.27866160869598388671875000000000 | Expected=4286.28195848283939994871616363525391
# Row 17086: Actual=4316.56294614076614379882812500000000 | Expected=4316.54429732091739424504339694976807
# Row 17087: Actual=4250.84352046251296997070312500000000 | Expected=4250.84040138460113666951656341552734
#
# ============================== Performance (9) ==============================
#
# Port 0:
#     Handshake util: 99.880% | Throughput: 1.962 GB/s
#     Avg gap len: 12057174 cycles, 48228696 ns | Busy util: 45.75%
#     {'cycles': 9135916, 'beats': 9124992, 'bytes': 145999872, 'pkts': 10, 'rdy_lo': 10034, 'vld_lo': 890, 'firsths': 9468689}
#     {'gap_last': 11996827, 'gap_total': 108514567, 'gap_min': 11977083, 'gap_max': 12175724, 'gap_count': 9, 'busy_total': 91527564}
# Port 1:
#     Handshake util: 99.830% | Throughput: 3.949 GB/s
#     Avg gap len: 12053216 cycles, 48212867 ns | Busy util: 45.77%
#     {'cycles': 9140510, 'beats': 9124992, 'bytes': 145999872, 'pkts': 10, 'rdy_lo': 0, 'vld_lo': 15518, 'firsths': 102589}
#     {'gap_last': 11993482, 'gap_total': 108478952, 'gap_min': 11979180, 'gap_max': 12166275, 'gap_count': 9, 'busy_total': 91567748}
# Port 2:
#     Handshake util: 99.830% | Throughput: 3.906 GB/s
#     Avg gap len: 12053164 cycles, 48212658 ns | Busy util: 45.77%
#     {'cycles': 9140513, 'beats': 9124992, 'bytes': 145999872, 'pkts': 10, 'rdy_lo': 0, 'vld_lo': 15521, 'firsths': 205141}
#     {'gap_last': 11994207, 'gap_total': 108478482, 'gap_min': 11979462, 'gap_max': 12168807, 'gap_count': 9, 'busy_total': 91567631}
# Port 3:
#     Handshake util: 99.842% | Throughput: 3.864 GB/s
#     Avg gap len: 12054767 cycles, 48219071 ns | Busy util: 45.76%
#     {'cycles': 9139437, 'beats': 9124992, 'bytes': 145999872, 'pkts': 10, 'rdy_lo': 14100, 'vld_lo': 345, 'firsths': 306773}
#     {'gap_last': 11975905, 'gap_total': 108492911, 'gap_min': 11975905, 'gap_max': 12172516, 'gap_count': 9, 'busy_total': 91547271}
#
# Total throughput: 15.454 GB/s
# RTL SS time: 9446211 cycles -> 37.785 ms
# RTL SM time: 9447325 cycles -> 37.789 ms
# Python compute time: 61.845 ms
#
# ================================ Compute (10) ================================
#
#
# Row 0: Actual=4250.50210529565811157226562500000000 | Expected=4250.49385945867106784135103225708008
# Row 1: Actual=4216.93733721971511840820312500000000 | Expected=4216.94544537068577483296394348144531
# Row 2: Actual=4275.49207729101181030273437500000000 | Expected=4275.48418085025605250848457217216492
# Row 3: Actual=4283.28575313091278076171875000000000 | Expected=4283.28358455227953527355566620826721
# Row 4: Actual=4254.00884646177291870117187500000000 | Expected=4254.02182414436538238078355789184570
# Row 5: Actual=4261.79101175069808959960937500000000 | Expected=4261.78378512621202389709651470184326
# ...
# Row 17083: Actual=4273.12563282251358032226562500000000 | Expected=4273.13700897845410509034991264343262
# Row 17084: Actual=4299.71338564157485961914062500000000 | Expected=4299.71822519297711551189422607421875
# Row 17085: Actual=4286.27866160869598388671875000000000 | Expected=4286.28195848283939994871616363525391
# Row 17086: Actual=4316.56294614076614379882812500000000 | Expected=4316.54429732091739424504339694976807
# Row 17087: Actual=4250.84352046251296997070312500000000 | Expected=4250.84040138460113666951656341552734
#
# ============================== Performance (10) ==============================
#
# Port 0:
#     Handshake util: 99.989% | Throughput: 1.965 GB/s
#     Avg gap len: 12062268 cycles, 48249074 ns | Busy util: 45.49%
#     {'cycles': 9126041, 'beats': 9124992, 'bytes': 145999872, 'pkts': 11, 'rdy_lo': 0, 'vld_lo': 1049, 'firsths': 9446211}
#     {'gap_last': 12108119, 'gap_total': 120622686, 'gap_min': 11977083, 'gap_max': 12175724, 'gap_count': 10, 'busy_total': 100653604}
# Port 1:
#     Handshake util: 99.946% | Throughput: 3.952 GB/s
#     Avg gap len: 12058502 cycles, 48234011 ns | Busy util: 45.51%
#     {'cycles': 9129907, 'beats': 9124992, 'bytes': 145999872, 'pkts': 11, 'rdy_lo': 0, 'vld_lo': 4915, 'firsths': 105140}
#     {'gap_last': 12106076, 'gap_total': 120585028, 'gap_min': 11979180, 'gap_max': 12166275, 'gap_count': 10, 'busy_total': 100697654}
# Port 2:
#     Handshake util: 99.947% | Throughput: 3.909 GB/s
#     Avg gap len: 12058470 cycles, 48233881 ns | Busy util: 45.51%
#     {'cycles': 9129871, 'beats': 9124992, 'bytes': 145999872, 'pkts': 11, 'rdy_lo': 0, 'vld_lo': 4879, 'firsths': 207841}
#     {'gap_last': 12106222, 'gap_total': 120584704, 'gap_min': 11979462, 'gap_max': 12168807, 'gap_count': 10, 'busy_total': 100697501}
# Port 3:
#     Handshake util: 99.968% | Throughput: 3.867 GB/s
#     Avg gap len: 12060094 cycles, 48240376 ns | Busy util: 45.50%
#     {'cycles': 9127941, 'beats': 9124992, 'bytes': 145999872, 'pkts': 11, 'rdy_lo': 2445, 'vld_lo': 504, 'firsths': 310206}
#     {'gap_last': 12108031, 'gap_total': 120600942, 'gap_min': 11975905, 'gap_max': 12172516, 'gap_count': 10, 'busy_total': 100675211}
#
# Total throughput: 15.467 GB/s
# RTL SS time: 9438148 cycles -> 37.753 ms
# RTL SM time: 9439262 cycles -> 37.757 ms
# Python compute time: 61.802 ms
#
# ================================ Compute (11) ================================
# Row 0: Actual=4250.50210529565811157226562500000000 | Expected=4250.49385945867106784135103225708008
# Row 1: Actual=4216.93733721971511840820312500000000 | Expected=4216.94544537068577483296394348144531
# Row 2: Actual=4275.49207729101181030273437500000000 | Expected=4275.48418085025605250848457217216492
# Row 3: Actual=4283.28575313091278076171875000000000 | Expected=4283.28358455227953527355566620826721
# Row 4: Actual=4254.00884646177291870117187500000000 | Expected=4254.02182414436538238078355789184570
# Row 5: Actual=4261.79101175069808959960937500000000 | Expected=4261.78378512621202389709651470184326
# ...
# Row 17083: Actual=4273.12563282251358032226562500000000 | Expected=4273.13700897845410509034991264343262
# Row 17084: Actual=4299.71338564157485961914062500000000 | Expected=4299.71822519297711551189422607421875
# Row 17085: Actual=4286.27866160869598388671875000000000 | Expected=4286.28195848283939994871616363525391
# Row 17086: Actual=4316.56294614076614379882812500000000 | Expected=4316.54429732091739424504339694976807
# Row 17087: Actual=4250.84352046251296997070312500000000 | Expected=4250.84040138460113666951656341552734
#
# ============================== Performance (11) ==============================
#
# Port 0:
#     Handshake util: 99.799% | Throughput: 1.964 GB/s
#     Avg gap len: 12054685 cycles, 48218742 ns | Busy util: 45.30%
#     {'cycles': 9143411, 'beats': 9124992, 'bytes': 145999872, 'pkts': 12, 'rdy_lo': 17306, 'vld_lo': 1113, 'firsths': 9438148}
#     {'gap_last': 11978855, 'gap_total': 132601541, 'gap_min': 11977083, 'gap_max': 12175724, 'gap_count': 11, 'busy_total': 109797014}
# Port 1:
#     Handshake util: 99.739% | Throughput: 3.946 GB/s
#     Avg gap len: 12050608 cycles, 48202432 ns | Busy util: 45.32%
#     {'cycles': 9148862, 'beats': 9124992, 'bytes': 145999872, 'pkts': 12, 'rdy_lo': 0, 'vld_lo': 23870, 'firsths': 101812}
#     {'gap_last': 11971661, 'gap_total': 132556689, 'gap_min': 11971661, 'gap_max': 12166275, 'gap_count': 11, 'busy_total': 109846515}
# Port 2:
#     Handshake util: 99.739% | Throughput: 3.902 GB/s
#     Avg gap len: 12050549 cycles, 48202196 ns | Busy util: 45.32%
#     {'cycles': 9148837, 'beats': 9124992, 'bytes': 145999872, 'pkts': 12, 'rdy_lo': 0, 'vld_lo': 23845, 'firsths': 204152}
#     {'gap_last': 11971336, 'gap_total': 132556040, 'gap_min': 11971336, 'gap_max': 12168807, 'gap_count': 11, 'busy_total': 109846337}
# Port 3:
#     Handshake util: 99.763% | Throughput: 3.856 GB/s
#     Avg gap len: 12053410 cycles, 48213640 ns | Busy util: 45.30%
#     {'cycles': 9146702, 'beats': 9124992, 'bytes': 145999872, 'pkts': 12, 'rdy_lo': 21250, 'vld_lo': 460, 'firsths': 319819}
#     {'gap_last': 11986568, 'gap_total': 132587510, 'gap_min': 11975905, 'gap_max': 12172516, 'gap_count': 11, 'busy_total': 109821912}
#
# Total throughput: 15.421 GB/s
# RTL SS time: 9466522 cycles -> 37.866 ms
# RTL SM time: 9467636 cycles -> 37.871 ms
# Python compute time: 62.007 ms
#
# ================================ Compute (12) ================================
#
#
# Row 0: Actual=4250.50210529565811157226562500000000 | Expected=4250.49385945867106784135103225708008
# Row 1: Actual=4216.93733721971511840820312500000000 | Expected=4216.94544537068577483296394348144531
# Row 2: Actual=4275.49207729101181030273437500000000 | Expected=4275.48418085025605250848457217216492
# Row 3: Actual=4283.28575313091278076171875000000000 | Expected=4283.28358455227953527355566620826721
# Row 4: Actual=4254.00884646177291870117187500000000 | Expected=4254.02182414436538238078355789184570
# Row 5: Actual=4261.79101175069808959960937500000000 | Expected=4261.78378512621202389709651470184326
# ...
# Row 17083: Actual=4273.12563282251358032226562500000000 | Expected=4273.13700897845410509034991264343262
# Row 17084: Actual=4299.71338564157485961914062500000000 | Expected=4299.71822519297711551189422607421875
# Row 17085: Actual=4286.27866160869598388671875000000000 | Expected=4286.28195848283939994871616363525391
# Row 17086: Actual=4316.56294614076614379882812500000000 | Expected=4316.54429732091739424504339694976807
# Row 17087: Actual=4250.84352046251296997070312500000000 | Expected=4250.84040138460113666951656341552734
#
# ============================== Performance (12) ==============================
#
# Port 0:
#     Handshake util: 99.977% | Throughput: 1.963 GB/s
#     Avg gap len: 12059132 cycles, 48236530 ns | Busy util: 45.11%
#     {'cycles': 9127134, 'beats': 9124992, 'bytes': 145999872, 'pkts': 13, 'rdy_lo': 1030, 'vld_lo': 1112, 'firsths': 9466522}
#     {'gap_last': 12108049, 'gap_total': 144709590, 'gap_min': 11977083, 'gap_max': 12175724, 'gap_count': 12, 'busy_total': 118924147}
# Port 1:
#     Handshake util: 99.922% | Throughput: 3.953 GB/s
#     Avg gap len: 12054979 cycles, 48219918 ns | Busy util: 45.13%
#     {'cycles': 9132085, 'beats': 9124992, 'bytes': 145999872, 'pkts': 13, 'rdy_lo': 0, 'vld_lo': 7093, 'firsths': 102280}
#     {'gap_last': 12103066, 'gap_total': 144659755, 'gap_min': 11971661, 'gap_max': 12166275, 'gap_count': 12, 'busy_total': 118978599}
# Port 2:
#     Handshake util: 99.922% | Throughput: 3.909 GB/s
#     Avg gap len: 12054918 cycles, 48219674 ns | Busy util: 45.13%
#     {'cycles': 9132070, 'beats': 9124992, 'bytes': 145999872, 'pkts': 13, 'rdy_lo': 0, 'vld_lo': 7078, 'firsths': 204511}
#     {'gap_last': 12102982, 'gap_total': 144659022, 'gap_min': 11971336, 'gap_max': 12168807, 'gap_count': 12, 'busy_total': 118978406}
# Port 3:
#     Handshake util: 99.942% | Throughput: 3.868 GB/s
#     Avg gap len: 12056630 cycles, 48226522 ns | Busy util: 45.12%
#     {'cycles': 9130309, 'beats': 9124992, 'bytes': 145999872, 'pkts': 13, 'rdy_lo': 4805, 'vld_lo': 512, 'firsths': 307119}
#     {'gap_last': 12092058, 'gap_total': 144679568, 'gap_min': 11975905, 'gap_max': 12172516, 'gap_count': 12, 'busy_total': 118952220}
#
# Total throughput: 15.468 GB/s
# RTL SS time: 9437429 cycles -> 37.750 ms
# RTL SM time: 9438543 cycles -> 37.754 ms
# Python compute time: 61.979 ms
#
# ================================ Compute (13) ================================
#
#
# Row 0: Actual=4250.50210529565811157226562500000000 | Expected=4250.49385945867106784135103225708008
# Row 1: Actual=4216.93733721971511840820312500000000 | Expected=4216.94544537068577483296394348144531
# Row 2: Actual=4275.49207729101181030273437500000000 | Expected=4275.48418085025605250848457217216492
# Row 3: Actual=4283.28575313091278076171875000000000 | Expected=4283.28358455227953527355566620826721
# Row 4: Actual=4254.00884646177291870117187500000000 | Expected=4254.02182414436538238078355789184570
# Row 5: Actual=4261.79101175069808959960937500000000 | Expected=4261.78378512621202389709651470184326
# ...
# Row 17083: Actual=4273.12563282251358032226562500000000 | Expected=4273.13700897845410509034991264343262
# Row 17084: Actual=4299.71338564157485961914062500000000 | Expected=4299.71822519297711551189422607421875
# Row 17085: Actual=4286.27866160869598388671875000000000 | Expected=4286.28195848283939994871616363525391
# Row 17086: Actual=4316.56294614076614379882812500000000 | Expected=4316.54429732091739424504339694976807
# Row 17087: Actual=4250.84352046251296997070312500000000 | Expected=4250.84040138460113666951656341552734
#
# ============================== Performance (13) ==============================
#
# Port 0:
#     Handshake util: 99.515% | Throughput: 1.962 GB/s
#     Avg gap len: 12053162 cycles, 48212650 ns | Busy util: 44.98%
#     {'cycles': 9169503, 'beats': 9124992, 'bytes': 145999872, 'pkts': 14, 'rdy_lo': 44204, 'vld_lo': 307, 'firsths': 9437429}
#     {'gap_last': 11981525, 'gap_total': 156691115, 'gap_min': 11977083, 'gap_max': 12175724, 'gap_count': 13, 'busy_total': 128093649}
# Port 1:
#     Handshake util: 99.472% | Throughput: 3.935 GB/s
#     Avg gap len: 12048952 cycles, 48195808 ns | Busy util: 45.00%
#     {'cycles': 9173385, 'beats': 9124992, 'bytes': 145999872, 'pkts': 14, 'rdy_lo': 0, 'vld_lo': 48393, 'firsths': 102327}
#     {'gap_last': 11976621, 'gap_total': 156636376, 'gap_min': 11971661, 'gap_max': 12166275, 'gap_count': 13, 'busy_total': 128151983}
# Port 2:
#     Handshake util: 99.472% | Throughput: 3.892 GB/s
#     Avg gap len: 12048845 cycles, 48195381 ns | Busy util: 45.00%
#     {'cycles': 9173388, 'beats': 9124992, 'bytes': 145999872, 'pkts': 14, 'rdy_lo': 0, 'vld_lo': 48396, 'firsths': 203891}
#     {'gap_last': 11975969, 'gap_total': 156634991, 'gap_min': 11971336, 'gap_max': 12168807, 'gap_count': 13, 'busy_total': 128151793}
# Port 3:
#     Handshake util: 99.483% | Throughput: 3.851 GB/s
#     Avg gap len: 12050505 cycles, 48202023 ns | Busy util: 44.99%
#     {'cycles': 9172459, 'beats': 9124992, 'bytes': 145999872, 'pkts': 14, 'rdy_lo': 47300, 'vld_lo': 167, 'firsths': 305778}
#     {'gap_last': 11977009, 'gap_total': 156656577, 'gap_min': 11975905, 'gap_max': 12172516, 'gap_count': 13, 'busy_total': 128124678}
#
# Total throughput: 15.402 GB/s
# RTL SS time: 9478238 cycles -> 37.913 ms
# RTL SM time: 9479352 cycles -> 37.917 ms
# Python compute time: 62.034 ms
#
# ================================ Compute (14) ================================
#
#
# Row 0: Actual=4250.50210529565811157226562500000000 | Expected=4250.49385945867106784135103225708008
# Row 1: Actual=4216.93733721971511840820312500000000 | Expected=4216.94544537068577483296394348144531
# Row 2: Actual=4275.49207729101181030273437500000000 | Expected=4275.48418085025605250848457217216492
# Row 3: Actual=4283.28575313091278076171875000000000 | Expected=4283.28358455227953527355566620826721
# Row 4: Actual=4254.00884646177291870117187500000000 | Expected=4254.02182414436538238078355789184570
# Row 5: Actual=4261.79101175069808959960937500000000 | Expected=4261.78378512621202389709651470184326
# ...
# Row 17083: Actual=4273.12563282251358032226562500000000 | Expected=4273.13700897845410509034991264343262
# Row 17084: Actual=4299.71338564157485961914062500000000 | Expected=4299.71822519297711551189422607421875
# Row 17085: Actual=4286.27866160869598388671875000000000 | Expected=4286.28195848283939994871616363525391
# Row 17086: Actual=4316.56294614076614379882812500000000 | Expected=4316.54429732091739424504339694976807
# Row 17087: Actual=4250.84352046251296997070312500000000 | Expected=4250.84040138460113666951656341552734
#
# ============================== Performance (14) ==============================
#
# Port 0:
#     Handshake util: 99.946% | Throughput: 1.962 GB/s
#     Avg gap len: 12057799 cycles, 48231199 ns | Busy util: 44.84%
#     {'cycles': 9129920, 'beats': 9124992, 'bytes': 145999872, 'pkts': 15, 'rdy_lo': 4736, 'vld_lo': 192, 'firsths': 9478238}
#     {'gap_last': 12118082, 'gap_total': 168809197, 'gap_min': 11977083, 'gap_max': 12175724, 'gap_count': 14, 'busy_total': 137223568}
# Port 1:
#     Handshake util: 99.904% | Throughput: 3.952 GB/s
#     Avg gap len: 12053599 cycles, 48214399 ns | Busy util: 44.86%
#     {'cycles': 9133741, 'beats': 9124992, 'bytes': 145999872, 'pkts': 15, 'rdy_lo': 0, 'vld_lo': 8749, 'firsths': 102150}
#     {'gap_last': 12114023, 'gap_total': 168750399, 'gap_min': 11971661, 'gap_max': 12166275, 'gap_count': 14, 'busy_total': 137285723}
# Port 2:
#     Handshake util: 99.904% | Throughput: 3.909 GB/s
#     Avg gap len: 12053513 cycles, 48214053 ns | Busy util: 44.86%
#     {'cycles': 9133721, 'beats': 9124992, 'bytes': 145999872, 'pkts': 15, 'rdy_lo': 0, 'vld_lo': 8729, 'firsths': 203889}
#     {'gap_last': 12114195, 'gap_total': 168749186, 'gap_min': 11971336, 'gap_max': 12168807, 'gap_count': 14, 'busy_total': 137285513}
# Port 3:
#     Handshake util: 99.915% | Throughput: 3.867 GB/s
#     Avg gap len: 12055115 cycles, 48220460 ns | Busy util: 44.85%
#     {'cycles': 9132742, 'beats': 9124992, 'bytes': 145999872, 'pkts': 15, 'rdy_lo': 7513, 'vld_lo': 237, 'firsths': 305686}
#     {'gap_last': 12115034, 'gap_total': 168771611, 'gap_min': 11975905, 'gap_max': 12172516, 'gap_count': 14, 'busy_total': 137257419}
#
# Total throughput: 15.467 GB/s
# RTL SS time: 9438429 cycles -> 37.754 ms
# RTL SM time: 9439543 cycles -> 37.758 ms
# Python compute time: 61.807 ms
#
# ================================ Compute (15) ================================
# Row 0: Actual=4250.50210529565811157226562500000000 | Expected=4250.49385945867106784135103225708008
# Row 1: Actual=4216.93733721971511840820312500000000 | Expected=4216.94544537068577483296394348144531
# Row 2: Actual=4275.49207729101181030273437500000000 | Expected=4275.48418085025605250848457217216492
# Row 3: Actual=4283.28575313091278076171875000000000 | Expected=4283.28358455227953527355566620826721
# Row 4: Actual=4254.00884646177291870117187500000000 | Expected=4254.02182414436538238078355789184570
# Row 5: Actual=4261.79101175069808959960937500000000 | Expected=4261.78378512621202389709651470184326
# ...
# Row 17083: Actual=4273.12563282251358032226562500000000 | Expected=4273.13700897845410509034991264343262
# Row 17084: Actual=4299.71338564157485961914062500000000 | Expected=4299.71822519297711551189422607421875
# Row 17085: Actual=4286.27866160869598388671875000000000 | Expected=4286.28195848283939994871616363525391
# Row 17086: Actual=4316.56294614076614379882812500000000 | Expected=4316.54429732091739424504339694976807
# Row 17087: Actual=4250.84352046251296997070312500000000 | Expected=4250.84040138460113666951656341552734
#
# ============================== Performance (15) ==============================
#
# Port 0:
#     Handshake util: 98.878% | Throughput: 1.955 GB/s
#     Avg gap len: 12049557 cycles, 48198228 ns | Busy util: 44.76%
#     {'cycles': 9228511, 'beats': 9124992, 'bytes': 145999872, 'pkts': 16, 'rdy_lo': 102780, 'vld_lo': 739, 'firsths': 9438429}
#     {'gap_last': 11934160, 'gap_total': 180743357, 'gap_min': 11934160, 'gap_max': 12175724, 'gap_count': 15, 'busy_total': 146452078}
# Port 1:
#     Handshake util: 98.829% | Throughput: 3.910 GB/s
#     Avg gap len: 12045363 cycles, 48181453 ns | Busy util: 44.78%
#     {'cycles': 9233092, 'beats': 9124992, 'bytes': 145999872, 'pkts': 16, 'rdy_lo': 0, 'vld_lo': 108100, 'firsths': 101862}
#     {'gap_last': 11930051, 'gap_total': 180680450, 'gap_min': 11930051, 'gap_max': 12166275, 'gap_count': 15, 'busy_total': 146518814}
# Port 2:
#     Handshake util: 98.829% | Throughput: 3.868 GB/s
#     Avg gap len: 12045281 cycles, 48181125 ns | Busy util: 44.78%
#     {'cycles': 9233086, 'beats': 9124992, 'bytes': 145999872, 'pkts': 16, 'rdy_lo': 0, 'vld_lo': 108094, 'firsths': 203564}
#     {'gap_last': 11930034, 'gap_total': 180679220, 'gap_min': 11930034, 'gap_max': 12168807, 'gap_count': 15, 'busy_total': 146518598}
# Port 3:
#     Handshake util: 98.857% | Throughput: 3.826 GB/s
#     Avg gap len: 12047035 cycles, 48188141 ns | Busy util: 44.77%
#     {'cycles': 9230527, 'beats': 9124992, 'bytes': 145999872, 'pkts': 16, 'rdy_lo': 105407, 'vld_lo': 128, 'firsths': 308268}
#     {'gap_last': 11933920, 'gap_total': 180705531, 'gap_min': 11933920, 'gap_max': 12172516, 'gap_count': 15, 'busy_total': 146487945}
#
# Total throughput: 15.304 GB/s
# RTL SS time: 9538796 cycles -> 38.155 ms
# RTL SM time: 9539910 cycles -> 38.160 ms
# Python compute time: 62.414 ms
#
# =============================================================================

# %% [markdown]
# ### Cleanup

# %%
for buf in [full, vector, result]: 
    if buf is not None: buf.freebuffer()
